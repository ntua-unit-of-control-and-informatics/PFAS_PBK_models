# %%
# In case you want to change the deepxde default backend just run the following line and select the backend at the end of the line:
# source: https://www.kaggle.com/code/lucasscheink/tesis-2d

# !python /Users/vassilis/anaconda3/pkgs/deepxde-1.9.3-pyhd5b0024_0/site-packages/deepxde/backend/set_default_backend.py tensorflow

# %%
import deepxde as dde
import numpy as np
import pandas as pd
import scipy as sp
from math import exp
import tensorflow as tf
import tensorflow_probability as tfp
import matplotlib.pyplot as plt
import os
import re
# Out:
# Using backend: tensorflow
# Other supported backends: tensorflow.compat.v1, pytorch, jax, paddle.
# paddle supports more examples now and is recommended.

# %%
os.getcwd()
# Out:
# '/Users/vassilis/Documents/GitHub/PFAS_PBK_models/PFAS Rainbow trout PBK/PINN/DeepXDE_implementation'

# %% [markdown]
# Here we define the parameters that we want to estimate.

# %%
# Parameters to be estimated.

# P_liver = dde.Variable(1.0)
# P_muscle = dde.Variable(1.0)
# P_kidney = dde.Variable(1.0)
P_skin = dde.Variable(0.5)
# P_gills = dde.Variable(1.0)
# P_carcass = dde.Variable(1.0)
# P_viscera = dde.Variable(1.0)

# %% [markdown]
# Now we can begin by creating a TimeDomain class.

# %%
geom = dde.geometry.TimeDomain(0, 56*24)

# %%
# Function to estimate the constant parameters of the model
def create_params(substance, Texp):
    # Transform input temperature into Kelvin scale
    Texp = 273 + Texp  # K

    Tref = 273 + np.array([6, 12, 18])  # Reference Temperature K - Grech et al. 2018
    keep_ref_value = np.argmin(np.abs(Tref - Texp))

    # Cardiac output reference value at T = 6 C (Barron et al. 1987, Table II)
    F_card_ref_6 = 1.188  # ml/h/g
    # Cardiac output reference value at T = 12 C (Barron et al. 1987, Table II)
    F_card_ref_12 = 2.322  # ml/h/g
    # Cardiac output reference value at T = 18 C (Barron et al. 1987, Table II)
    F_card_ref_18 = 3.75  # ml/h/g
    F_card_ref_values = [F_card_ref_6, F_card_ref_12, F_card_ref_18]
    F_card_ref = F_card_ref_values[keep_ref_value]

    # Body weight reference value at T = 6 C (Barron et al. 1987, Table II)
    BW_ref_6 = 270.1  # g
    # Body weight reference value at T = 12 C (Barron et al. 1987, Table II)
    BW_ref_12 = 296.4  # g
    # Body weight reference value at T = 18 C (Barron et al. 1987, Table II)
    BW_ref_18 = 414.5  # g
    BW_ref_values = [BW_ref_6, BW_ref_12, BW_ref_18]
    BW_ref = BW_ref_values[keep_ref_value]

    # Arrhenius Temperature function
    TA = 6930  # Arrhenius Temperature K - Grech et al. 2018
    Tr = Tref[np.argmin(np.abs(Tref - Texp))]
    KT = exp(TA / Tr - TA / Texp)

    # Load the xlsx file with the physiological params of rainbow trout
    phys_params_sheet1 = pd.read_excel('/Users/vassilis/Documents/GitHub/PFAS_PBK_models/PFAS Rainbow trout PBK/Rainbow trout Physiological parameters/Rainbow trout Physiological parameters.xlsx', sheet_name=0)

    # Keep only the physiological parameters from the paper of Vidal et al. 2019
    fw = phys_params_sheet1.loc[phys_params_sheet1['Source'] == 'Vidal et al. 2019', ['Liver', 'Blood', 'Skin', 'Muscle', 'Gills', 'Kidney', 'Viscera']]
    fw_Liver = fw['Liver'].values[0]
    fw_Blood = fw['Blood'].values[0]
    fw_Skin = fw['Skin'].values[0]
    fw_Muscle = fw['Muscle'].values[0]
    fw_Gills = fw['Gills'].values[0]
    fw_Kidney = fw['Kidney'].values[0]
    fw_Viscera = fw['Viscera'].values[0]
    fw_lumen = 0.012

    # Load the xlsx file with the physiological params of rainbow trout
    phys_params_sheet2 = pd.read_excel('/Users/vassilis/Documents/GitHub/PFAS_PBK_models/PFAS Rainbow trout PBK/Rainbow trout Physiological parameters/Rainbow trout Physiological parameters.xlsx', sheet_name=1)

    # Keep only the physiological parameters from the paper of Vidal et al. 2019
    fb = phys_params_sheet2.loc[phys_params_sheet2['Source'] == 'Vidal et al. 2019', ['Liver', 'Skin', 'Muscle', 'Gills', 'Kidney', 'Viscera']]
    fb_Liver = fb['Liver'].values[0]
    fb_Skin = fb['Skin'].values[0]
    fb_Muscle = fb['Muscle'].values[0]
    fb_Gills = fb['Gills'].values[0]
    fb_Kidney = fb['Kidney'].values[0]
    fb_Viscera = fb['Viscera'].values[0]

    # Reabsorption coefficients from bile to intestine
    # estimated by Cao et al., 2022
    # K_urine = Cl_urine / f_reab_urine estimated by Ng et al., 2013 (unitless)
    if substance == 'PFOA':
        a = 0.138  # Sun et al., 2022, Goeritz et al. 2013
        f_reab_hep = 0.30  # Cao et al., 2022
        K_urine = 2.08
        Cl_urine = 0.029 * 3600  # 1/h (Sun et al., 2022)
    elif substance == 'PFNA':
        a = 0.522  # Sun et al., 2022, Goeritz et al. 2013
        f_reab_hep = 0.34  # Cao et al., 2022
        K_urine = 1.35
        Cl_urine = 0.050 * 3600  # 1/h (Sun et al., 2022)
    elif substance == 'PFBS':
        a = 0.0598  # Goeritz et al. 2013
        f_reab_hep = 0.23  # Cao et al., 2022
        K_urine = 5.88
        Cl_urine = 0.023 * 3600  # 1/h (Sun et al., 2022) # Assumed equal to PFHxS
    elif substance == 'PFHxS':
        a = 0.558  # Sun et al., 2022, Goeritz et al. 2013
        f_reab_hep = 0.30  # Cao et al., 2022
        K_urine = 5.88
        Cl_urine = 0.023 * 3600  # 1/h (Sun et al., 2022)
    elif substance == 'PFOS':
        a = 0.721  # Sun et al., 2022, Goeritz et al. 2013
        f_reab_hep = 0.42  # Cao et al., 2022
        K_urine = 1.35
        Cl_urine = 0.050 * 3600  # 1/h (Sun et al., 2022)

    # Bile flow coefficient
    Q_bile_coef = 7.5e-05  # ml/g BW/h Grosell et al., 2000
    Q_urine_coef = 2.755e-03  # ml/h/g of BW Urinary flow rate (Curtis et al., 1981)
    V_urine_coef = 2.2e-03  # ml/g of BW Urine volume inside urinary bladder (Curtis et al., 1981)

    a_skin = 0.9  # 90% of venous blood of skin was assumed to flow directly to kidney (Nichols et al. 1996)
    a_muscle = 0.6  # 60% of venous blood of muscle was assumed to flow directly to kidney (Nichols et al. 1996)

    plasma = 0.7
    
    return[F_card_ref, BW_ref, KT, fw_Liver, fw_Blood, fw_Skin, fw_Muscle, fw_Gills, fw_Kidney,
          fw_Viscera, fw_lumen, fb_Liver, fb_Skin, fb_Muscle, fb_Gills, fb_Kidney, fb_Viscera,
          a_skin, a_muscle, Q_bile_coef, Q_urine_coef, V_urine_coef, 
          K_urine, Cl_urine, f_reab_hep,plasma,a]

# %%
def fish_weight(time):
    x = tf.constant([0, 28 * 24, 56 * 24], dtype=tf.float32)
    y = tf.constant([314, 655, 808], dtype=tf.float32)

    w = tf.zeros([1,1])

    for time_i in tf.unstack(time):
        time_i = tf.cast(time_i, 'float32')
        condition_1 = tf.math.less_equal(time_i, tf.cast(x[0], 'float32'))
        condition_2 = tf.math.greater_equal(time_i, tf.cast(x[2], 'float32'))
        condition_3 = tf.math.logical_and(tf.math.greater_equal(time_i, tf.cast(x[0], 'float32')), tf.math.less(time_i, tf.cast(x[1], 'float32')))
        condition_4 = tf.math.logical_and(tf.math.greater_equal(time_i, tf.cast(x[1], 'float32')), tf.math.less(time_i, tf.cast(x[2], 'float32')))
        
        w_new = tf.cond(condition_1, lambda: y[0], 
                         lambda: tf.cond(condition_2, lambda: y[2], 
                                         lambda: tf.cond(condition_3, 
                                                         lambda: tfp.math.interp_regular_1d_grid(tf.cast(time_i, 'float32'), tf.cast(x[0], 'float32'),  
                                                                 tf.cast(x[1], 'float32'), tf.cast(y[0:2], 'float32')), 
                                                         lambda: tfp.math.interp_regular_1d_grid(tf.cast(time_i, 'float32'), tf.cast(x[1], 'float32'), 
                                                                    tf.cast(x[2], 'float32'), tf.cast(y[1:3], 'float32')) ))) 
        
        w_new = tf.reshape(w_new, [-1,1])
        w = tf.concat([w, w_new], axis=0)   
    w = w[1:]
    return (w)

# %% [markdown]
# Next, we create the PBK model to solve using the dde.grad.jacobian function.

# %%
def PBK_model(t, net_out, ex):
    # At this point we estimate the derivatives of the networks outputs to time    
    M_art, M_venous, M_gills, M_lumen, M_lumen_2, M_viscera, M_liver, M_kidney, \
    M_muscle, M_skin, M_carcass, M_storage, M_urine, M_feces, \
    C_gills, C_viscera, C_liver, C_kidney, C_muscle, C_skin, C_carcass, \
    C_lumen, C_art, C_venous, C_blood, C_storage= net_out[:, 0:1], net_out[:, 1:2], \
    net_out[:, 2:3], net_out[:, 3:4], net_out[:, 4:5], net_out[:, 5:6], net_out[:, 6:7], net_out[:, 7:8], \
    net_out[:, 8:9], net_out[:, 9:10], net_out[:, 10:11], net_out[:, 11:12], net_out[:, 12:13], net_out[:, 13:14],  \
    net_out[:, 14:15], net_out[:, 15:16], net_out[:, 16:17], net_out[:, 17:18], net_out[:, 18:19], net_out[:, 19:20], net_out[:, 20:21], \
    net_out[:, 21:22], net_out[:, 22:23], net_out[:, 23:24], net_out[:, 24:25], net_out[:, 25:26]
    
    dM_art_ls = dde.gradients.jacobian(net_out, t, i=0)
    dM_venous_ls = dde.gradients.jacobian(net_out, t, i=1)
    dM_gills_ls = dde.gradients.jacobian(net_out, t, i=2)
    dM_lumen_ls = dde.gradients.jacobian(net_out, t, i=3)
    dM_lumen_2_ls = dde.gradients.jacobian(net_out, t, i=4)
    dM_viscera_ls = dde.gradients.jacobian(net_out, t, i=5)
    dM_liver_ls = dde.gradients.jacobian(net_out, t, i=6)
    dM_kidney_ls = dde.gradients.jacobian(net_out, t, i=7)
    dM_muscle_ls = dde.gradients.jacobian(net_out, t, i=8)
    dM_skin_ls = dde.gradients.jacobian(net_out, t, i=9)
    dM_carcass_ls = dde.gradients.jacobian(net_out, t, i=10)
    dM_storage_ls = dde.gradients.jacobian(net_out, t, i=11)
    dM_urine_ls = dde.gradients.jacobian(net_out, t, i=12)
    dM_feces_ls = dde.gradients.jacobian(net_out, t, i=13)
    
    dC_gills_ls = dde.gradients.jacobian(net_out, t, i=14)
    dC_viscera_ls = dde.gradients.jacobian(net_out, t, i=15)
    dC_liver_ls = dde.gradients.jacobian(net_out, t, i=16)
    dC_kidney_ls = dde.gradients.jacobian(net_out, t, i=17)
    dC_muscle_ls = dde.gradients.jacobian(net_out, t, i=18)
    dC_skin_ls = dde.gradients.jacobian(net_out, t, i=19)
    dC_carcass_ls = dde.gradients.jacobian(net_out, t, i=20)
    dC_lumen_ls = dde.gradients.jacobian(net_out, t, i=21)
    dC_art_ls = dde.gradients.jacobian(net_out, t, i=22)
    dC_venous_ls = dde.gradients.jacobian(net_out, t, i=23)
    dC_blood_ls = dde.gradients.jacobian(net_out, t, i=24)
    dC_storage_ls = dde.gradients.jacobian(net_out, t, i=25)

    
    #------------------------------------------------------------
    # Estimate the derivatives based on the ODEs.
    
    # Estimation of constant parameters 
    (F_card_ref,BW_ref,KT,fw_Liver,fw_Blood,fw_Skin,fw_Muscle,fw_Gills,
     fw_Kidney, fw_Viscera, fw_lumen,fb_Liver,fb_Skin,fb_Muscle,fb_Gills,
     fb_Kidney,fb_Viscera,a_skin,a_muscle,Q_bile_coef,
     Q_urine_coef,V_urine_coef,K_urine,Cl_urine,f_reab_hep,plasma, a) = create_params('PFOS', 15)
    
    CLU_coef = 0.0005719031
    Ku = 1.4668919575
    Cl_feces = 1.3064647362
    
    P_liver = 1.5685318
    P_muscle = 0.11316576
    P_kidney = 0.4398762
    # P_skin = 0.2715996
    P_gills = 0.2291869
    P_carcass = 0.1074253
    P_viscera = 3.699111
    
    # Body weight - g
    BW = fish_weight(t)
    
    # Total cardiac output ml/h considered as plasma flow
    Q_total = F_card_ref*KT*(BW/BW_ref)**(-0.1)*BW*plasma  
    
    # Calculate the mass of each tissue - g
    w_blood = fw_Blood*BW*plasma     # Blood mass - g
    w_liver = fw_Liver*BW     # Liver mass - g
    w_skin = fw_Skin*BW       # Skin weight - g
    w_muscle = fw_Muscle*BW   # Muscle weight - g
    w_gills = fw_Gills*BW     # Gills weight - g
    w_kidney = fw_Kidney*BW   # Kidney weight - g
    w_viscera = fw_Viscera*BW # Viscera weight - g
    w_lumen = fw_lumen*BW
    w_art = 1/3*w_blood
    w_venous = 2/3*w_blood
    w_carcass = BW - (w_blood/plasma + w_liver + w_skin + w_muscle +
                         w_gills + w_kidney + w_viscera + w_lumen)
    
    # Calculate the regional blood flows - ml/h
    Q_liver = fb_Liver*Q_total     # Liver blood flow - ml/h
    Q_skin = fb_Skin*Q_total       # Skin blood flow - ml/h
    Q_muscle = fb_Muscle*Q_total   # Muscle blood flow - ml/h
    Q_gills = Q_total              # Gills blood flow - ml/h
    Q_kidney = fb_Kidney*Q_total   # Kidney blood flow - ml/h
    Q_viscera = fb_Viscera*Q_total # Viscera blood flow - ml/h
    Q_carcass = Q_total - (Q_liver + Q_skin + Q_muscle + 
                              Q_kidney + Q_viscera)
    
    # Calculate the absolute bile flow rate - ml/h
    Q_bile = Q_bile_coef*BW
    # Calculate Urinary flow rate - ml/h
    Q_urine = Q_urine_coef*BW
    
    # Calculate urine volume  - ml 
    v_urine = V_urine_coef*BW
    
    # Calculate f_reab_urine based on Cl_urine and K_urine - 1/h
    f_reab_urine = Cl_urine*CLU_coef/K_urine
    
    # Tissue concentrations ug PFAS/g tissue
    C_gills_rs = M_gills/w_gills
    C_viscera_rs = M_viscera/w_viscera
    C_liver_rs = M_liver/w_liver
    C_kidney_rs = M_kidney/w_kidney
    C_muscle_rs = M_muscle/w_muscle 
    C_skin_rs = M_skin/w_skin
    C_carcass_rs = M_carcass/w_carcass
    C_lumen_rs = (M_lumen+M_lumen_2)/w_lumen
    C_art_rs = M_art/w_art
    C_venous_rs = M_venous/w_venous
    C_blood_rs = (M_art + M_venous)/w_blood
    C_storage_rs = M_storage/v_urine
    
    # Arterial Blood
    dM_art_rs = Q_gills*C_gills/P_gills - \
                (Q_viscera + Q_liver + Q_kidney +
                 Q_muscle + Q_skin + Q_carcass)*C_art
    dC_art_rs = dM_art_rs/w_art
        
    # Venous blood    
    dM_venous_rs = - Q_total*C_venous + \
                    (Q_liver + Q_viscera)*C_liver/P_liver + \
                    (Q_kidney + a_muscle*Q_muscle + a_skin*Q_skin)*C_kidney/P_kidney + \
                    (1-a_muscle)*Q_muscle*C_muscle/P_muscle + \
                    (1-a_skin)*Q_skin*C_skin/P_skin + Q_carcass*C_carcass/P_carcass
    dC_venous_rs = dM_venous_rs/w_venous
    
    dC_blood_rs = (dM_art_rs + dM_venous_rs)*plasma/w_blood
    
    # Gills 
    dM_gills_rs = Q_gills*(C_venous - C_gills/P_gills) 
    dC_gills_rs = dM_gills_rs/w_gills 
    
    
    # Viscera Lumen - Available PFAS for absorption and elimination
    dM_lumen_rs = - Ku*a*M_lumen - Cl_feces*(1-a)*M_lumen + ex
    
    # Viscera Lumen 2 - Unavailable PFAS for absorption. Can be only eliminated.
    dM_lumen_2_rs = (1-f_reab_hep)*Q_bile*C_liver - Cl_feces*M_lumen_2 
    
    dC_lumen_rs = (dM_lumen_rs + dM_lumen_2_rs)/w_lumen
    
    
    # Viscera Tissue
    dM_viscera_rs = Q_viscera*(C_art - C_viscera/P_viscera) + Ku*a*M_lumen + \
                      f_reab_hep*Q_bile*C_liver
    dC_viscera_rs = dM_viscera_rs/w_viscera
    
    # Liver
    dM_liver_rs = Q_liver*C_art + Q_viscera*C_viscera/P_viscera -    \
                      (Q_liver + Q_viscera)*C_liver/P_liver - Q_bile*C_liver
    dC_liver_rs = dM_liver_rs/w_liver
        
    # Kidney
    dM_kidney_rs = Q_kidney*C_art -   \
                  (Q_kidney + a_muscle*Q_muscle + a_skin*Q_skin)*C_kidney/P_kidney + \
                  a_muscle*Q_muscle*C_muscle/P_muscle +   \
                  a_skin*Q_skin*C_skin/P_skin - Cl_urine*CLU_coef*M_kidney + f_reab_urine*M_storage
    
    dC_kidney_rs = dM_kidney_rs/w_kidney
                
    # Muscle 
    dM_muscle_rs = Q_muscle*(C_art - C_muscle/P_muscle)
    dC_muscle_rs = dM_muscle_rs/w_muscle

    # Skin
    dM_skin_rs = Q_skin*(C_art - C_skin/P_skin)
    dC_skin_rs = dM_skin_rs/w_skin
    
    # Carcass 
    dM_carcass_rs = Q_carcass*(C_art - C_carcass/P_carcass)
    dC_carcass_rs = dM_carcass_rs/w_carcass
    
    # Urine Storage
    dM_storage_rs = Cl_urine*CLU_coef*M_kidney - f_reab_urine*M_storage - Q_urine*C_storage
    dC_storage_rs = dM_storage_rs/v_urine
    
    # Urine
    dM_urine_rs = Q_urine*C_storage
    
    # Feces
    dM_feces_rs = Cl_feces*((1-a)*M_lumen + M_lumen_2)
    
    return [
        dM_art_ls - dM_art_rs,
        dM_venous_ls - dM_venous_rs,
        dM_gills_ls - dM_gills_rs,
        dM_lumen_ls - dM_lumen_rs,
        dM_lumen_2_ls - dM_lumen_2_rs,
        dM_viscera_ls - dM_viscera_rs,
        dM_liver_ls - dM_liver_rs,
        dM_kidney_ls - dM_kidney_rs,
        dM_muscle_ls - dM_muscle_rs,
        dM_skin_ls - dM_skin_rs,
        dM_carcass_ls - dM_carcass_rs,
        dM_storage_ls - dM_storage_rs,
        dM_urine_ls - dM_urine_rs,
        dM_feces_ls - dM_feces_rs,
        
        dC_gills_ls - dC_gills_rs,
        dC_viscera_ls - dC_viscera_rs,
        dC_liver_ls - dC_liver_rs,
        dC_kidney_ls - dC_kidney_rs,
        dC_muscle_ls - dC_muscle_rs,
        dC_skin_ls - dC_skin_rs,
        dC_carcass_ls - dC_carcass_rs,
        dC_lumen_ls - dC_lumen_rs,
        dC_art_ls - dC_art_rs,
        dC_venous_ls - dC_venous_rs,
        dC_blood_ls - dC_blood_rs,
        dC_storage_ls - dC_storage_rs,
        
        C_gills - C_gills_rs,
        C_viscera - C_viscera_rs,
        C_liver - C_liver_rs,
        C_kidney - C_kidney_rs,
        C_muscle - C_muscle_rs,
        C_skin - C_skin_rs,
        C_carcass - C_carcass_rs,
        C_lumen - C_lumen_rs,
        C_art - C_art_rs,
        C_venous - C_venous_rs,
        C_blood - C_blood_rs,
        C_storage - C_storage_rs
    ]

# %% [markdown]
# Next, we consider the initial conditions. We need to implement a function, which should return True for points inside the subdomain and False for the points outside.

# %%
def boundary(_, on_initial):
    return on_initial

# %%
# Initial conditions

ic1 = dde.icbc.IC(geom, lambda X: 0, boundary, component=0) # M_art
ic2 = dde.icbc.IC(geom, lambda X: 0, boundary, component=1) # M_venous
ic3 = dde.icbc.IC(geom, lambda X: 0, boundary, component=2) # M_gills
ic4 = dde.icbc.IC(geom, lambda X: 0, boundary, component=3) # M_lumen <<--- The initial added PFAS amount.
ic5 = dde.icbc.IC(geom, lambda X: 0, boundary, component=4) # M_lumen_2
ic6 = dde.icbc.IC(geom, lambda X: 0, boundary, component=5) # M_viscera
ic7 = dde.icbc.IC(geom, lambda X: 0, boundary, component=6) # M_liver
ic8 = dde.icbc.IC(geom, lambda X: 0, boundary, component=7) # M_kidney
ic9 = dde.icbc.IC(geom, lambda X: 0, boundary, component=8) # M_muscle
ic10 = dde.icbc.IC(geom, lambda X: 0, boundary, component=9) # M_skin
ic11 = dde.icbc.IC(geom, lambda X: 0, boundary, component=10) # M_carcass
ic12 = dde.icbc.IC(geom, lambda X: 0, boundary, component=11) # M_storage
ic13 = dde.icbc.IC(geom, lambda X: 0, boundary, component=12) # M_urine
ic14 = dde.icbc.IC(geom, lambda X: 0, boundary, component=13) # M_feces

ic15 = dde.icbc.IC(geom, lambda X: 0, boundary, component=14) # C_gills
ic16 = dde.icbc.IC(geom, lambda X: 0, boundary, component=15) # C_viscera
ic17 = dde.icbc.IC(geom, lambda X: 0, boundary, component=16) # C_liver
ic18 = dde.icbc.IC(geom, lambda X: 0, boundary, component=17) # C_kidney
ic19 = dde.icbc.IC(geom, lambda X: 0, boundary, component=18) # C_muscle
ic20 = dde.icbc.IC(geom, lambda X: 0, boundary, component=19) # C_skin
ic21 = dde.icbc.IC(geom, lambda X: 0, boundary, component=20) # C_carcass
ic22 = dde.icbc.IC(geom, lambda X: 0, boundary, component=21) # C_lumen
ic23 = dde.icbc.IC(geom, lambda X: 0, boundary, component=22) # C_art
ic24 = dde.icbc.IC(geom, lambda X: 0, boundary, component=23) # C_venous
ic25 = dde.icbc.IC(geom, lambda X: 0, boundary, component=24) # C_blood
ic26 = dde.icbc.IC(geom, lambda X: 0, boundary, component=25) # C_storage

# %%
def gen_traindata():
    #data = np.load('PFOS_dataset.npy')
    data = pd.read_csv('PFOS_dataset_2.csv')
    return np.vstack(data["Time"]), np.vstack(data["Liver"]), np.vstack(data["Blood"]), np.vstack(data["Skin"]), \
            np.vstack(data["Muscle"]), np.vstack(data["Gills"]), np.vstack(data["Kidney"]), np.vstack(data["Carcass"])

# %%
pd.read_csv('PFOS_dataset_2.csv')
# Out:
#    Column1 Substance  Time  Cumulative_added_PFAS  Feeding_period  \
# 0        2      PFOS   168               31.89875             168
# 1        3      PFOS   336               71.55525             336
# 2        4      PFOS   672              174.14150             672
# 3        5      PFOS   744              174.14150               0
# 4        6      PFOS   840              174.14150               0
# 5        7      PFOS  1008              174.14150               0
# 6        8      PFOS  1344              174.14150               0
#
#    Depuration_period     Liver     Blood      Skin    Muscle     Gills  \
# 0                  0  0.173413  0.110337  0.035337  0.028029  0.035337
# 1                  0  0.305289  0.145674  0.052982  0.028750  0.041827
# 2                  0  0.463269  0.237885  0.094808  0.052115  0.059038
# 3                 72  0.377864  0.200941  0.071326  0.026326  0.050556
# 4                168  0.337837  0.136683  0.074375  0.019375  0.054760
# 5                336  0.193942  0.090481  0.031634  0.012019  0.030481
# 6                672  0.186923  0.041923  0.017308  0.004231  0.021154
#
#      Kidney   Carcass
# 0  0.060721  0.014183
# 1  0.106827  0.019904
# 2  0.159808  0.038269
# 3  0.132095  0.026326
# 4  0.102453  0.030145
# 5  0.055481  0.013173
# 6  0.030001  0.006923

# %%
# data = pd.read_csv('PFOS_dataset_2.csv')
# data = data[["Time", 'Liver', 'Blood', 'Skin', 'Muscle', 'Gills', 'Kidney', 'Carcass']]
# data[['Time']] = (data[['Time']] - data[['Time']].min()) / (data[['Time']].max() - data[['Time']].min())
# data
# #data_norm = (data - data.min()) / (data.max() - data.min())
# #data_norm

# %%
observe_t, C_liver, C_blood, C_skin, C_muscle, C_gills, C_kidney, C_carcass = gen_traindata()
# observe_t, C_liver, C_blood, C_skin, C_muscle, C_gills, C_kidney, C_carcass = np.vstack(data["Time"]), np.vstack(data["Liver"]), np.vstack(data["Blood"]), np.vstack(data["Skin"]), \
#             np.vstack(data["Muscle"]), np.vstack(data["Gills"]), np.vstack(data["Kidney"]), np.vstack(data["Carcass"])

observe_Blood = dde.icbc.PointSetBC(observe_t, C_blood, component=24, shuffle=False) 
observe_Gills = dde.icbc.PointSetBC(observe_t, C_gills, component=14, shuffle=False)
observe_Liver = dde.icbc.PointSetBC(observe_t, C_liver, component=16, shuffle=False)
observe_Kidney = dde.icbc.PointSetBC(observe_t, C_kidney, component=17, shuffle=False)
observe_Muscle = dde.icbc.PointSetBC(observe_t, C_muscle, component=18, shuffle=False)
observe_Skin = dde.icbc.PointSetBC(observe_t, C_skin, component=19, shuffle=False)
observe_Carcass = dde.icbc.PointSetBC(observe_t, C_carcass, component=20,shuffle=False)

# %% [markdown]
# Import the data for events.

# %%
events_data = pd.read_csv('events_simplified.csv')
time_points = np.vstack(events_data['time'])
added_amount = np.vstack(events_data['value'])

# Create an interpolation function to approximate the events_data governing function

# def ex_func(t):
#     spline = sp.interpolate.RBFInterpolator(time_points, added_amount, kernel = 'thin_plate_spline')
#     return spline(t[:, 0:])

# def ex_func(t): 
#     added_pfas = []
#     for time_i in t:
#         if np.isin(time_i, time_points):
#             index = np.where(np.isin(time_points, time_i))
#             added_pfas.append(added_amount[index])
#         else:
#             added_pfas.append(0)
#     return(np.vstack(added_pfas))

def ex_func(t): 
    added_pfas = []
    for time_i in t:
        if time_i <= 648:
            added_pfas.append(6.449685/24)
        else:
            added_pfas.append(0)
    return(np.vstack(added_pfas))

# %%
print(events_data.shape)
print(time_points.shape)
print(added_amount.shape)
# Out:
# (28, 2)
# (28, 1)
# (28, 1)

# %%
# events_time_points = time_points

# anchors = np.concatenate((events_time_points, observe_t))
anchors = observe_t
anchors = np.sort(anchors, axis=0)
anchors = np.vstack(np.unique(anchors))

# %%
# Now that the problem is fully setup, we define the PDE as:
# ic1, ic2, ic3, ic4, ic5, ic6, ic7, ic8, ic9, ic10, ic11,
#            ic12, ic13, ic14, ic15, ic16, ic17, ic18, ic19, ic20, ic21,
#            ic22, ic23, ic24, ic25, ic26,
# data = dde.data.PDE(
#     geometry = geom, # Instance of Geometry
#     pde = PBK_model, # A global PDE or a list of PDEs. None if no global PDE.
#     bcs = [observe_Blood, observe_Gills, observe_Liver, observe_Kidney,
#            observe_Muscle, observe_Skin, observe_Carcass], #A boundary condition or a list of boundary conditions. Use [] if no boundary condition.
#     num_domain=1000, # The number of training points sampled inside the domain.
#     num_test= 100, 
#     num_boundary=2, # The number of training points sampled on the boundary.
#     train_distribution = 'uniform', # The distribution to sample training points.
#     anchors=anchors, # A Numpy array of training points, in addition to the num_domain and num_boundary sampled points.
#     auxiliary_var_function = ex_func)

data = dde.data.PDE(
    geometry = geom, # Instance of Geometry
    pde = PBK_model, # A global PDE or a list of PDEs. None if no global PDE.
    bcs = [observe_Skin], #A boundary condition or a list of boundary conditions. Use [] if no boundary condition.
    num_domain=500, # The number of training points sampled inside the domain.
    num_test= 100, 
    num_boundary=7, # The number of training points sampled on the boundary.
    #train_distribution = 'uniform', # The distribution to sample training points.
    anchors=anchors, # A Numpy array of training points, in addition to the num_domain and num_boundary sampled points.
    auxiliary_var_function = ex_func)

# %%
# data = dde.data.PDE(
#     geometry = geom, # Instance of Geometry
#     pde = PBK_model, # A global PDE or a list of PDEs. None if no global PDE.
#     bcs = [observe_Blood, observe_Gills, observe_Liver, observe_Kidney,
#            observe_Muscle, observe_Skin, observe_Carcass], #A boundary condition or a list of boundary conditions. Use [] if no boundary condition.
#     num_domain=50, # The number of training points sampled inside the domain.
#     num_boundary=2, # The number of training points sampled on the boundary.
#     train_distribution = 'uniform', # The distribution to sample training points.
#     anchors=anchors, # A Numpy array of training points, in addition to the num_domain and num_boundary sampled points.
#     auxiliary_var_function = ex_func)

# %%
def output_transform(t, netout):
    netout1 = netout[:, 0:1]
    netout2 = netout[:, 1:2]
    netout3 = netout[:, 2:3]
    netout4 = netout[:, 3:4]
    netout5 = netout[:, 4:5]
    netout6 = netout[:, 5:6]
    netout7 = netout[:, 6:7]
    netout8 = netout[:, 7:8]
    netout9 = netout[:, 8:9]
    netout10 = netout[:, 9:10]
    netout11 = netout[:, 10:11]
    netout12 = netout[:, 11:12]
    netout13 = netout[:, 12:13]
    netout14 = netout[:, 13:14]
    netout15 = netout[:, 14:15]
    netout16 = netout[:, 15:16]
    netout17 = netout[:, 16:17]
    netout18 = netout[:, 17:18]
    netout19 = netout[:, 18:19]
    netout20 = netout[:, 19:20]
    netout21 = netout[:, 20:21]
    netout22 = netout[:, 21:22]
    netout23 = netout[:, 22:23]
    netout24 = netout[:, 23:24]
    netout25 = netout[:, 24:25]
    netout26 = netout[:, 25:26]
    
    return tf.concat(
        [netout1 * tf.tanh(t) , netout2 * tf.tanh(t), netout3 * tf.tanh(t),
         netout4 * tf.tanh(t), 
         netout5 * tf.tanh(t), netout6 * tf.tanh(t),
         netout7 * tf.tanh(t) , netout8 * tf.tanh(t), netout9 * tf.tanh(t),
         netout10 * tf.tanh(t), netout11 * tf.tanh(t), netout12 * tf.tanh(t),
         netout13 * tf.tanh(t), netout14 * tf.tanh(t), netout15 * tf.tanh(t),
         netout16 * tf.tanh(t), netout17 * tf.tanh(t), netout18 * tf.tanh(t),
         netout19 * tf.tanh(t), netout20 * tf.tanh(t), netout21 * tf.tanh(t),
         netout22 * tf.tanh(t), netout23 * tf.tanh(t), netout24 * tf.tanh(t),
         netout25 * tf.tanh(t), netout26 * tf.tanh(t)
        ], axis=1
    )

# %%
# Next, we choose the network. 

initializer = tf.keras.initializers.GlorotNormal(seed = 1)
net = dde.nn.FNN([1] + [30] * 5 + [26], "tanh", initializer)
net.apply_output_transform(output_transform)


model = dde.Model(data, net)

external_trainable_variables=[P_skin]
fnamevar = "variables.dat"
variable = dde.callbacks.VariableValue(external_trainable_variables, period=1000, filename="variables.dat")

# %%
loss_weights = np.concatenate((np.repeat([0.1], 26), np.repeat([10],1)) )

# %%
optimizer = tf.keras.optimizers.Adam()
lr=0.01
loss = dde.losses.mean_squared_error

model.compile(optimizer = optimizer, lr=lr, loss = loss, #loss_weights = loss_weights.tolist(),
              external_trainable_variables=external_trainable_variables)
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# Compiling model...
# 'compile' took 0.000868 s

# %%
losshistory, train_state = model.train(iterations=40000, callbacks=[variable])
# Out:
# Training model...
# 2023-09-18 12:19:47.168566: W tensorflow/tsl/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# Step      Train loss                                                                                                                                                                                                                                                                                                                                                                                                Test loss                                                                                                                                                                                                                                                                                                                                                                                                 Test metric
# 0         [3.07e+06, 4.58e+04, 5.82e+06, 1.16e-01, 1.12e-01, 1.03e+03, 1.44e+01, 1.03e+07, 2.18e+07, 1.33e+04, 5.62e+05, 8.75e-02, 1.47e-01, 1.44e-01, 3.48e+04, 9.39e-01, 3.86e-01, 1.01e+05, 1.73e+02, 7.79e+00, 3.06e+01, 1.06e-02, 6.67e+04, 4.36e+02, 2.77e+03, 4.65e-02, 1.78e-01, 2.51e-02, 3.72e-02, 2.24e-01, 3.72e-01, 1.81e-01, 3.04e-01, 1.13e-02, 1.22e-01, 2.32e-02, 2.22e-02, 6.70e-02, 2.37e-01]    [3.08e+06, 4.54e+04, 5.84e+06, 1.17e-01, 1.13e-01, 1.03e+03, 1.44e+01, 1.03e+07, 2.18e+07, 1.34e+04, 5.64e+05, 8.78e-02, 1.48e-01, 1.45e-01, 3.50e+04, 9.46e-01, 3.82e-01, 1.02e+05, 1.74e+02, 7.83e+00, 3.08e+01, 1.07e-02, 6.72e+04, 4.24e+02, 2.80e+03, 4.69e-02, 1.79e-01, 2.52e-02, 3.76e-02, 2.26e-01, 3.75e-01, 1.82e-01, 3.06e-01, 1.14e-02, 1.22e-01, 2.33e-02, 2.23e-02, 6.76e-02, 2.37e-01]    []
# 2023-09-18 12:20:13.286718: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/gradients/fnn/strided_slice_grad/StridedSliceGrad_grad/StridedSlice/gradients/fnn/strided_slice_grad/StridedSliceGrad/strides' with dtype int32 and shape [2]
# 	 [[{{node gradients/gradients/fnn/strided_slice_grad/StridedSliceGrad_grad/StridedSlice/gradients/fnn/strided_slice_grad/StridedSliceGrad/strides}}]]
# 2023-09-18 12:20:13.287615: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/gradients/fnn/strided_slice_1_grad/StridedSliceGrad_grad/StridedSlice/gradients/fnn/strided_slice_1_grad/StridedSliceGrad/strides' with dtype int32 and shape [2]
# 	 [[{{node gradients/gradients/fnn/strided_slice_1_grad/StridedSliceGrad_grad/StridedSlice/gradients/fnn/strided_slice_1_grad/StridedSliceGrad/strides}}]]
# 2023-09-18 12:20:13.288202: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/gradients/fnn/strided_slice_2_grad/StridedSliceGrad_grad/StridedSlice/gradients/fnn/strided_slice_2_grad/StridedSliceGrad/strides' with dtype int32 and shape [2]
# 	 [[{{node gradients/gradients/fnn/strided_slice_2_grad/StridedSliceGrad_grad/StridedSlice/gradients/fnn/strided_slice_2_grad/StridedSliceGrad/strides}}]]
# 2023-09-18 12:20:13.288823: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/gradients/fnn/strided_slice_3_grad/StridedSliceGrad_grad/StridedSlice/gradients/fnn/strided_slice_3_grad/StridedSliceGrad/strides' with dtype int32 and shape [2]
# 	 [[{{node gradients/gradients/fnn/strided_slice_3_grad/StridedSliceGrad_grad/StridedSlice/gradients/fnn/strided_slice_3_grad/StridedSliceGrad/strides}}]]
# 2023-09-18 12:20:13.289466: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/gradients/fnn/strided_slice_4_grad/StridedSliceGrad_grad/StridedSlice/gradients/fnn/strided_slice_4_grad/StridedSliceGrad/strides' with dtype int32 and shape [2]
# 	 [[{{node gradients/gradients/fnn/strided_slice_4_grad/StridedSliceGrad_grad/StridedSlice/gradients/fnn/strided_slice_4_grad/StridedSliceGrad/strides}}]]
# 2023-09-18 12:20:13.290053: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/gradients/fnn/strided_slice_5_grad/StridedSliceGrad_grad/StridedSlice/gradients/fnn/strided_slice_5_grad/StridedSliceGrad/strides' with dtype int32 and shape [2]
# 	 [[{{node gradients/gradients/fnn/strided_slice_5_grad/StridedSliceGrad_grad/StridedSlice/gradients/fnn/strided_slice_5_grad/StridedSliceGrad/strides}}]]
# 2023-09-18 12:20:13.290633: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/gradients/fnn/strided_slice_6_grad/StridedSliceGrad_grad/StridedSlice/gradients/fnn/strided_slice_6_grad/StridedSliceGrad/strides' with dtype int32 and shape [2]
# 	 [[{{node gradients/gradients/fnn/strided_slice_6_grad/StridedSliceGrad_grad/StridedSlice/gradients/fnn/strided_slice_6_grad/StridedSliceGrad/strides}}]]
# 2023-09-18 12:20:13.291355: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/gradients/fnn/strided_slice_7_grad/StridedSliceGrad_grad/StridedSlice/gradients/fnn/strided_slice_7_grad/StridedSliceGrad/strides' with dtype int32 and shape [2]
# 	 [[{{node gradients/gradients/fnn/strided_slice_7_grad/StridedSliceGrad_grad/StridedSlice/gradients/fnn/strided_slice_7_grad/StridedSliceGrad/strides}}]]
# 2023-09-18 12:20:13.291914: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/gradients/fnn/strided_slice_8_grad/StridedSliceGrad_grad/StridedSlice/gradients/fnn/strided_slice_8_grad/StridedSliceGrad/strides' with dtype int32 and shape [2]
# 	 [[{{node gradients/gradients/fnn/strided_slice_8_grad/StridedSliceGrad_grad/StridedSlice/gradients/fnn/strided_slice_8_grad/StridedSliceGrad/strides}}]]
# 2023-09-18 12:20:13.292567: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/gradients/fnn/strided_slice_9_grad/StridedSliceGrad_grad/StridedSlice/gradients/fnn/strided_slice_9_grad/StridedSliceGrad/strides' with dtype int32 and shape [2]
# 	 [[{{node gradients/gradients/fnn/strided_slice_9_grad/StridedSliceGrad_grad/StridedSlice/gradients/fnn/strided_slice_9_grad/StridedSliceGrad/strides}}]]
# 2023-09-18 12:20:13.293166: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/gradients/fnn/strided_slice_10_grad/StridedSliceGrad_grad/StridedSlice/gradients/fnn/strided_slice_10_grad/StridedSliceGrad/strides' with dtype int32 and shape [2]
# 	 [[{{node gradients/gradients/fnn/strided_slice_10_grad/StridedSliceGrad_grad/StridedSlice/gradients/fnn/strided_slice_10_grad/StridedSliceGrad/strides}}]]
# 2023-09-18 12:20:13.293796: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/gradients/fnn/strided_slice_11_grad/StridedSliceGrad_grad/StridedSlice/gradients/fnn/strided_slice_11_grad/StridedSliceGrad/strides' with dtype int32 and shape [2]
# 	 [[{{node gradients/gradients/fnn/strided_slice_11_grad/StridedSliceGrad_grad/StridedSlice/gradients/fnn/strided_slice_11_grad/StridedSliceGrad/strides}}]]
# 2023-09-18 12:20:13.294421: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/gradients/fnn/strided_slice_12_grad/StridedSliceGrad_grad/StridedSlice/gradients/fnn/strided_slice_12_grad/StridedSliceGrad/strides' with dtype int32 and shape [2]
# 	 [[{{node gradients/gradients/fnn/strided_slice_12_grad/StridedSliceGrad_grad/StridedSlice/gradients/fnn/strided_slice_12_grad/StridedSliceGrad/strides}}]]
# 2023-09-18 12:20:13.295089: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/gradients/fnn/strided_slice_13_grad/StridedSliceGrad_grad/StridedSlice/gradients/fnn/strided_slice_13_grad/StridedSliceGrad/strides' with dtype int32 and shape [2]
# 	 [[{{node gradients/gradients/fnn/strided_slice_13_grad/StridedSliceGrad_grad/StridedSlice/gradients/fnn/strided_slice_13_grad/StridedSliceGrad/strides}}]]
# 2023-09-18 12:20:13.295675: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/gradients/fnn/strided_slice_14_grad/StridedSliceGrad_grad/StridedSlice/gradients/fnn/strided_slice_14_grad/StridedSliceGrad/strides' with dtype int32 and shape [2]
# 	 [[{{node gradients/gradients/fnn/strided_slice_14_grad/StridedSliceGrad_grad/StridedSlice/gradients/fnn/strided_slice_14_grad/StridedSliceGrad/strides}}]]
# 2023-09-18 12:20:13.296277: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/gradients/fnn/strided_slice_15_grad/StridedSliceGrad_grad/StridedSlice/gradients/fnn/strided_slice_15_grad/StridedSliceGrad/strides' with dtype int32 and shape [2]
# 	 [[{{node gradients/gradients/fnn/strided_slice_15_grad/StridedSliceGrad_grad/StridedSlice/gradients/fnn/strided_slice_15_grad/StridedSliceGrad/strides}}]]
# 2023-09-18 12:20:13.296861: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/gradients/fnn/strided_slice_16_grad/StridedSliceGrad_grad/StridedSlice/gradients/fnn/strided_slice_16_grad/StridedSliceGrad/strides' with dtype int32 and shape [2]
# 	 [[{{node gradients/gradients/fnn/strided_slice_16_grad/StridedSliceGrad_grad/StridedSlice/gradients/fnn/strided_slice_16_grad/StridedSliceGrad/strides}}]]
# 2023-09-18 12:20:13.297433: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/gradients/fnn/strided_slice_17_grad/StridedSliceGrad_grad/StridedSlice/gradients/fnn/strided_slice_17_grad/StridedSliceGrad/strides' with dtype int32 and shape [2]
# 	 [[{{node gradients/gradients/fnn/strided_slice_17_grad/StridedSliceGrad_grad/StridedSlice/gradients/fnn/strided_slice_17_grad/StridedSliceGrad/strides}}]]
# 2023-09-18 12:20:13.298054: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/gradients/fnn/strided_slice_18_grad/StridedSliceGrad_grad/StridedSlice/gradients/fnn/strided_slice_18_grad/StridedSliceGrad/strides' with dtype int32 and shape [2]
# 	 [[{{node gradients/gradients/fnn/strided_slice_18_grad/StridedSliceGrad_grad/StridedSlice/gradients/fnn/strided_slice_18_grad/StridedSliceGrad/strides}}]]
# 2023-09-18 12:20:13.298698: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/gradients/fnn/strided_slice_19_grad/StridedSliceGrad_grad/StridedSlice/gradients/fnn/strided_slice_19_grad/StridedSliceGrad/strides' with dtype int32 and shape [2]
# 	 [[{{node gradients/gradients/fnn/strided_slice_19_grad/StridedSliceGrad_grad/StridedSlice/gradients/fnn/strided_slice_19_grad/StridedSliceGrad/strides}}]]
# 2023-09-18 12:20:13.299296: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/gradients/fnn/strided_slice_20_grad/StridedSliceGrad_grad/StridedSlice/gradients/fnn/strided_slice_20_grad/StridedSliceGrad/strides' with dtype int32 and shape [2]
# 	 [[{{node gradients/gradients/fnn/strided_slice_20_grad/StridedSliceGrad_grad/StridedSlice/gradients/fnn/strided_slice_20_grad/StridedSliceGrad/strides}}]]
# 2023-09-18 12:20:13.299902: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/gradients/fnn/strided_slice_21_grad/StridedSliceGrad_grad/StridedSlice/gradients/fnn/strided_slice_21_grad/StridedSliceGrad/strides' with dtype int32 and shape [2]
# 	 [[{{node gradients/gradients/fnn/strided_slice_21_grad/StridedSliceGrad_grad/StridedSlice/gradients/fnn/strided_slice_21_grad/StridedSliceGrad/strides}}]]
# 2023-09-18 12:20:13.300553: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/gradients/fnn/strided_slice_22_grad/StridedSliceGrad_grad/StridedSlice/gradients/fnn/strided_slice_22_grad/StridedSliceGrad/strides' with dtype int32 and shape [2]
# 	 [[{{node gradients/gradients/fnn/strided_slice_22_grad/StridedSliceGrad_grad/StridedSlice/gradients/fnn/strided_slice_22_grad/StridedSliceGrad/strides}}]]
# 2023-09-18 12:20:13.301162: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/gradients/fnn/strided_slice_23_grad/StridedSliceGrad_grad/StridedSlice/gradients/fnn/strided_slice_23_grad/StridedSliceGrad/strides' with dtype int32 and shape [2]
# 	 [[{{node gradients/gradients/fnn/strided_slice_23_grad/StridedSliceGrad_grad/StridedSlice/gradients/fnn/strided_slice_23_grad/StridedSliceGrad/strides}}]]
# 2023-09-18 12:20:13.301801: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/gradients/fnn/strided_slice_24_grad/StridedSliceGrad_grad/StridedSlice/gradients/fnn/strided_slice_24_grad/StridedSliceGrad/strides' with dtype int32 and shape [2]
# 	 [[{{node gradients/gradients/fnn/strided_slice_24_grad/StridedSliceGrad_grad/StridedSlice/gradients/fnn/strided_slice_24_grad/StridedSliceGrad/strides}}]]
# 2023-09-18 12:20:13.302366: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/gradients/fnn/strided_slice_25_grad/StridedSliceGrad_grad/StridedSlice/gradients/fnn/strided_slice_25_grad/StridedSliceGrad/strides' with dtype int32 and shape [2]
# 	 [[{{node gradients/gradients/fnn/strided_slice_25_grad/StridedSliceGrad_grad/StridedSlice/gradients/fnn/strided_slice_25_grad/StridedSliceGrad/strides}}]]
# 2023-09-18 12:20:13.303009: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/gradients_1/fnn/strided_slice_grad/StridedSliceGrad_grad/StridedSlice/gradients_1/fnn/strided_slice_grad/StridedSliceGrad/strides' with dtype int32 and shape [2]
# 	 [[{{node gradients/gradients_1/fnn/strided_slice_grad/StridedSliceGrad_grad/StridedSlice/gradients_1/fnn/strided_slice_grad/StridedSliceGrad/strides}}]]
# 2023-09-18 12:20:13.303635: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/gradients_1/fnn/strided_slice_1_grad/StridedSliceGrad_grad/StridedSlice/gradients_1/fnn/strided_slice_1_grad/StridedSliceGrad/strides' with dtype int32 and shape [2]
# 	 [[{{node gradients/gradients_1/fnn/strided_slice_1_grad/StridedSliceGrad_grad/StridedSlice/gradients_1/fnn/strided_slice_1_grad/StridedSliceGrad/strides}}]]
# 2023-09-18 12:20:13.304248: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/gradients_1/fnn/strided_slice_2_grad/StridedSliceGrad_grad/StridedSlice/gradients_1/fnn/strided_slice_2_grad/StridedSliceGrad/strides' with dtype int32 and shape [2]
# 	 [[{{node gradients/gradients_1/fnn/strided_slice_2_grad/StridedSliceGrad_grad/StridedSlice/gradients_1/fnn/strided_slice_2_grad/StridedSliceGrad/strides}}]]
# 2023-09-18 12:20:13.305138: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/gradients_1/fnn/strided_slice_3_grad/StridedSliceGrad_grad/StridedSlice/gradients_1/fnn/strided_slice_3_grad/StridedSliceGrad/strides' with dtype int32 and shape [2]
# 	 [[{{node gradients/gradients_1/fnn/strided_slice_3_grad/StridedSliceGrad_grad/StridedSlice/gradients_1/fnn/strided_slice_3_grad/StridedSliceGrad/strides}}]]
# 2023-09-18 12:20:13.305677: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/gradients_1/fnn/strided_slice_4_grad/StridedSliceGrad_grad/StridedSlice/gradients_1/fnn/strided_slice_4_grad/StridedSliceGrad/strides' with dtype int32 and shape [2]
# 	 [[{{node gradients/gradients_1/fnn/strided_slice_4_grad/StridedSliceGrad_grad/StridedSlice/gradients_1/fnn/strided_slice_4_grad/StridedSliceGrad/strides}}]]
# 2023-09-18 12:20:13.306311: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/gradients_1/fnn/strided_slice_5_grad/StridedSliceGrad_grad/StridedSlice/gradients_1/fnn/strided_slice_5_grad/StridedSliceGrad/strides' with dtype int32 and shape [2]
# 	 [[{{node gradients/gradients_1/fnn/strided_slice_5_grad/StridedSliceGrad_grad/StridedSlice/gradients_1/fnn/strided_slice_5_grad/StridedSliceGrad/strides}}]]
# 2023-09-18 12:20:13.306941: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/gradients_1/fnn/strided_slice_6_grad/StridedSliceGrad_grad/StridedSlice/gradients_1/fnn/strided_slice_6_grad/StridedSliceGrad/strides' with dtype int32 and shape [2]
# 	 [[{{node gradients/gradients_1/fnn/strided_slice_6_grad/StridedSliceGrad_grad/StridedSlice/gradients_1/fnn/strided_slice_6_grad/StridedSliceGrad/strides}}]]
# 2023-09-18 12:20:13.307505: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/gradients_1/fnn/strided_slice_7_grad/StridedSliceGrad_grad/StridedSlice/gradients_1/fnn/strided_slice_7_grad/StridedSliceGrad/strides' with dtype int32 and shape [2]
# 	 [[{{node gradients/gradients_1/fnn/strided_slice_7_grad/StridedSliceGrad_grad/StridedSlice/gradients_1/fnn/strided_slice_7_grad/StridedSliceGrad/strides}}]]
# 2023-09-18 12:20:13.308120: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/gradients_1/fnn/strided_slice_8_grad/StridedSliceGrad_grad/StridedSlice/gradients_1/fnn/strided_slice_8_grad/StridedSliceGrad/strides' with dtype int32 and shape [2]
# 	 [[{{node gradients/gradients_1/fnn/strided_slice_8_grad/StridedSliceGrad_grad/StridedSlice/gradients_1/fnn/strided_slice_8_grad/StridedSliceGrad/strides}}]]
# 2023-09-18 12:20:13.308716: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/gradients_1/fnn/strided_slice_9_grad/StridedSliceGrad_grad/StridedSlice/gradients_1/fnn/strided_slice_9_grad/StridedSliceGrad/strides' with dtype int32 and shape [2]
# 	 [[{{node gradients/gradients_1/fnn/strided_slice_9_grad/StridedSliceGrad_grad/StridedSlice/gradients_1/fnn/strided_slice_9_grad/StridedSliceGrad/strides}}]]
# 2023-09-18 12:20:13.309295: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/gradients_1/fnn/strided_slice_10_grad/StridedSliceGrad_grad/StridedSlice/gradients_1/fnn/strided_slice_10_grad/StridedSliceGrad/strides' with dtype int32 and shape [2]
# 	 [[{{node gradients/gradients_1/fnn/strided_slice_10_grad/StridedSliceGrad_grad/StridedSlice/gradients_1/fnn/strided_slice_10_grad/StridedSliceGrad/strides}}]]
# 2023-09-18 12:20:13.309877: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/gradients_1/fnn/strided_slice_11_grad/StridedSliceGrad_grad/StridedSlice/gradients_1/fnn/strided_slice_11_grad/StridedSliceGrad/strides' with dtype int32 and shape [2]
# 	 [[{{node gradients/gradients_1/fnn/strided_slice_11_grad/StridedSliceGrad_grad/StridedSlice/gradients_1/fnn/strided_slice_11_grad/StridedSliceGrad/strides}}]]
# 2023-09-18 12:20:13.310451: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/gradients_1/fnn/strided_slice_12_grad/StridedSliceGrad_grad/StridedSlice/gradients_1/fnn/strided_slice_12_grad/StridedSliceGrad/strides' with dtype int32 and shape [2]
# 	 [[{{node gradients/gradients_1/fnn/strided_slice_12_grad/StridedSliceGrad_grad/StridedSlice/gradients_1/fnn/strided_slice_12_grad/StridedSliceGrad/strides}}]]
# 2023-09-18 12:20:13.311111: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/gradients_1/fnn/strided_slice_13_grad/StridedSliceGrad_grad/StridedSlice/gradients_1/fnn/strided_slice_13_grad/StridedSliceGrad/strides' with dtype int32 and shape [2]
# 	 [[{{node gradients/gradients_1/fnn/strided_slice_13_grad/StridedSliceGrad_grad/StridedSlice/gradients_1/fnn/strided_slice_13_grad/StridedSliceGrad/strides}}]]
# 2023-09-18 12:20:13.311700: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/gradients_1/fnn/strided_slice_14_grad/StridedSliceGrad_grad/StridedSlice/gradients_1/fnn/strided_slice_14_grad/StridedSliceGrad/strides' with dtype int32 and shape [2]
# 	 [[{{node gradients/gradients_1/fnn/strided_slice_14_grad/StridedSliceGrad_grad/StridedSlice/gradients_1/fnn/strided_slice_14_grad/StridedSliceGrad/strides}}]]
# 2023-09-18 12:20:13.312277: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/gradients_1/fnn/strided_slice_15_grad/StridedSliceGrad_grad/StridedSlice/gradients_1/fnn/strided_slice_15_grad/StridedSliceGrad/strides' with dtype int32 and shape [2]
# 	 [[{{node gradients/gradients_1/fnn/strided_slice_15_grad/StridedSliceGrad_grad/StridedSlice/gradients_1/fnn/strided_slice_15_grad/StridedSliceGrad/strides}}]]
# 2023-09-18 12:20:13.312857: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/gradients_1/fnn/strided_slice_16_grad/StridedSliceGrad_grad/StridedSlice/gradients_1/fnn/strided_slice_16_grad/StridedSliceGrad/strides' with dtype int32 and shape [2]
# 	 [[{{node gradients/gradients_1/fnn/strided_slice_16_grad/StridedSliceGrad_grad/StridedSlice/gradients_1/fnn/strided_slice_16_grad/StridedSliceGrad/strides}}]]
# 2023-09-18 12:20:13.313436: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/gradients_1/fnn/strided_slice_17_grad/StridedSliceGrad_grad/StridedSlice/gradients_1/fnn/strided_slice_17_grad/StridedSliceGrad/strides' with dtype int32 and shape [2]
# 	 [[{{node gradients/gradients_1/fnn/strided_slice_17_grad/StridedSliceGrad_grad/StridedSlice/gradients_1/fnn/strided_slice_17_grad/StridedSliceGrad/strides}}]]
# 2023-09-18 12:20:13.314025: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/gradients_1/fnn/strided_slice_18_grad/StridedSliceGrad_grad/StridedSlice/gradients_1/fnn/strided_slice_18_grad/StridedSliceGrad/strides' with dtype int32 and shape [2]
# 	 [[{{node gradients/gradients_1/fnn/strided_slice_18_grad/StridedSliceGrad_grad/StridedSlice/gradients_1/fnn/strided_slice_18_grad/StridedSliceGrad/strides}}]]
# 2023-09-18 12:20:13.314660: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/gradients_1/fnn/strided_slice_19_grad/StridedSliceGrad_grad/StridedSlice/gradients_1/fnn/strided_slice_19_grad/StridedSliceGrad/strides' with dtype int32 and shape [2]
# 	 [[{{node gradients/gradients_1/fnn/strided_slice_19_grad/StridedSliceGrad_grad/StridedSlice/gradients_1/fnn/strided_slice_19_grad/StridedSliceGrad/strides}}]]
# 2023-09-18 12:20:13.315231: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/gradients_1/fnn/strided_slice_20_grad/StridedSliceGrad_grad/StridedSlice/gradients_1/fnn/strided_slice_20_grad/StridedSliceGrad/strides' with dtype int32 and shape [2]
# 	 [[{{node gradients/gradients_1/fnn/strided_slice_20_grad/StridedSliceGrad_grad/StridedSlice/gradients_1/fnn/strided_slice_20_grad/StridedSliceGrad/strides}}]]
# 2023-09-18 12:20:13.315804: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/gradients_1/fnn/strided_slice_21_grad/StridedSliceGrad_grad/StridedSlice/gradients_1/fnn/strided_slice_21_grad/StridedSliceGrad/strides' with dtype int32 and shape [2]
# 	 [[{{node gradients/gradients_1/fnn/strided_slice_21_grad/StridedSliceGrad_grad/StridedSlice/gradients_1/fnn/strided_slice_21_grad/StridedSliceGrad/strides}}]]
# 2023-09-18 12:20:13.316403: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/gradients_1/fnn/strided_slice_22_grad/StridedSliceGrad_grad/StridedSlice/gradients_1/fnn/strided_slice_22_grad/StridedSliceGrad/strides' with dtype int32 and shape [2]
# 	 [[{{node gradients/gradients_1/fnn/strided_slice_22_grad/StridedSliceGrad_grad/StridedSlice/gradients_1/fnn/strided_slice_22_grad/StridedSliceGrad/strides}}]]
# 2023-09-18 12:20:13.316974: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/gradients_1/fnn/strided_slice_23_grad/StridedSliceGrad_grad/StridedSlice/gradients_1/fnn/strided_slice_23_grad/StridedSliceGrad/strides' with dtype int32 and shape [2]
# 	 [[{{node gradients/gradients_1/fnn/strided_slice_23_grad/StridedSliceGrad_grad/StridedSlice/gradients_1/fnn/strided_slice_23_grad/StridedSliceGrad/strides}}]]
# 2023-09-18 12:20:13.317552: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/gradients_1/fnn/strided_slice_24_grad/StridedSliceGrad_grad/StridedSlice/gradients_1/fnn/strided_slice_24_grad/StridedSliceGrad/strides' with dtype int32 and shape [2]
# 	 [[{{node gradients/gradients_1/fnn/strided_slice_24_grad/StridedSliceGrad_grad/StridedSlice/gradients_1/fnn/strided_slice_24_grad/StridedSliceGrad/strides}}]]
# 2023-09-18 12:20:13.318159: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/gradients_1/fnn/strided_slice_25_grad/StridedSliceGrad_grad/StridedSlice/gradients_1/fnn/strided_slice_25_grad/StridedSliceGrad/strides' with dtype int32 and shape [2]
# 	 [[{{node gradients/gradients_1/fnn/strided_slice_25_grad/StridedSliceGrad_grad/StridedSlice/gradients_1/fnn/strided_slice_25_grad/StridedSliceGrad/strides}}]]
# 2023-09-18 12:20:13.318756: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/gradients_2/fnn/strided_slice_grad/StridedSliceGrad_grad/StridedSlice/gradients_2/fnn/strided_slice_grad/StridedSliceGrad/strides' with dtype int32 and shape [2]
# 	 [[{{node gradients/gradients_2/fnn/strided_slice_grad/StridedSliceGrad_grad/StridedSlice/gradients_2/fnn/strided_slice_grad/StridedSliceGrad/strides}}]]
# 2023-09-18 12:20:13.319332: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/gradients_2/fnn/strided_slice_1_grad/StridedSliceGrad_grad/StridedSlice/gradients_2/fnn/strided_slice_1_grad/StridedSliceGrad/strides' with dtype int32 and shape [2]
# 	 [[{{node gradients/gradients_2/fnn/strided_slice_1_grad/StridedSliceGrad_grad/StridedSlice/gradients_2/fnn/strided_slice_1_grad/StridedSliceGrad/strides}}]]
# 2023-09-18 12:20:13.319884: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/gradients_2/fnn/strided_slice_2_grad/StridedSliceGrad_grad/StridedSlice/gradients_2/fnn/strided_slice_2_grad/StridedSliceGrad/strides' with dtype int32 and shape [2]
# 	 [[{{node gradients/gradients_2/fnn/strided_slice_2_grad/StridedSliceGrad_grad/StridedSlice/gradients_2/fnn/strided_slice_2_grad/StridedSliceGrad/strides}}]]
# 2023-09-18 12:20:13.320459: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/gradients_2/fnn/strided_slice_3_grad/StridedSliceGrad_grad/StridedSlice/gradients_2/fnn/strided_slice_3_grad/StridedSliceGrad/strides' with dtype int32 and shape [2]
# 	 [[{{node gradients/gradients_2/fnn/strided_slice_3_grad/StridedSliceGrad_grad/StridedSlice/gradients_2/fnn/strided_slice_3_grad/StridedSliceGrad/strides}}]]
# 2023-09-18 12:20:13.321038: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/gradients_2/fnn/strided_slice_4_grad/StridedSliceGrad_grad/StridedSlice/gradients_2/fnn/strided_slice_4_grad/StridedSliceGrad/strides' with dtype int32 and shape [2]
# 	 [[{{node gradients/gradients_2/fnn/strided_slice_4_grad/StridedSliceGrad_grad/StridedSlice/gradients_2/fnn/strided_slice_4_grad/StridedSliceGrad/strides}}]]
# 2023-09-18 12:20:13.321612: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/gradients_2/fnn/strided_slice_5_grad/StridedSliceGrad_grad/StridedSlice/gradients_2/fnn/strided_slice_5_grad/StridedSliceGrad/strides' with dtype int32 and shape [2]
# 	 [[{{node gradients/gradients_2/fnn/strided_slice_5_grad/StridedSliceGrad_grad/StridedSlice/gradients_2/fnn/strided_slice_5_grad/StridedSliceGrad/strides}}]]
# 2023-09-18 12:20:13.322168: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/gradients_2/fnn/strided_slice_6_grad/StridedSliceGrad_grad/StridedSlice/gradients_2/fnn/strided_slice_6_grad/StridedSliceGrad/strides' with dtype int32 and shape [2]
# 	 [[{{node gradients/gradients_2/fnn/strided_slice_6_grad/StridedSliceGrad_grad/StridedSlice/gradients_2/fnn/strided_slice_6_grad/StridedSliceGrad/strides}}]]
# 2023-09-18 12:20:13.322727: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/gradients_2/fnn/strided_slice_7_grad/StridedSliceGrad_grad/StridedSlice/gradients_2/fnn/strided_slice_7_grad/StridedSliceGrad/strides' with dtype int32 and shape [2]
# 	 [[{{node gradients/gradients_2/fnn/strided_slice_7_grad/StridedSliceGrad_grad/StridedSlice/gradients_2/fnn/strided_slice_7_grad/StridedSliceGrad/strides}}]]
# 2023-09-18 12:20:13.323260: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/gradients_2/fnn/strided_slice_8_grad/StridedSliceGrad_grad/StridedSlice/gradients_2/fnn/strided_slice_8_grad/StridedSliceGrad/strides' with dtype int32 and shape [2]
# 	 [[{{node gradients/gradients_2/fnn/strided_slice_8_grad/StridedSliceGrad_grad/StridedSlice/gradients_2/fnn/strided_slice_8_grad/StridedSliceGrad/strides}}]]
# 2023-09-18 12:20:13.323912: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/gradients_2/fnn/strided_slice_9_grad/StridedSliceGrad_grad/StridedSlice/gradients_2/fnn/strided_slice_9_grad/StridedSliceGrad/strides' with dtype int32 and shape [2]
# 	 [[{{node gradients/gradients_2/fnn/strided_slice_9_grad/StridedSliceGrad_grad/StridedSlice/gradients_2/fnn/strided_slice_9_grad/StridedSliceGrad/strides}}]]
# 2023-09-18 12:20:13.324507: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/gradients_2/fnn/strided_slice_10_grad/StridedSliceGrad_grad/StridedSlice/gradients_2/fnn/strided_slice_10_grad/StridedSliceGrad/strides' with dtype int32 and shape [2]
# 	 [[{{node gradients/gradients_2/fnn/strided_slice_10_grad/StridedSliceGrad_grad/StridedSlice/gradients_2/fnn/strided_slice_10_grad/StridedSliceGrad/strides}}]]
# 2023-09-18 12:20:13.325066: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/gradients_2/fnn/strided_slice_11_grad/StridedSliceGrad_grad/StridedSlice/gradients_2/fnn/strided_slice_11_grad/StridedSliceGrad/strides' with dtype int32 and shape [2]
# 	 [[{{node gradients/gradients_2/fnn/strided_slice_11_grad/StridedSliceGrad_grad/StridedSlice/gradients_2/fnn/strided_slice_11_grad/StridedSliceGrad/strides}}]]
# 2023-09-18 12:20:13.325641: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/gradients_2/fnn/strided_slice_12_grad/StridedSliceGrad_grad/StridedSlice/gradients_2/fnn/strided_slice_12_grad/StridedSliceGrad/strides' with dtype int32 and shape [2]
# 	 [[{{node gradients/gradients_2/fnn/strided_slice_12_grad/StridedSliceGrad_grad/StridedSlice/gradients_2/fnn/strided_slice_12_grad/StridedSliceGrad/strides}}]]
# 2023-09-18 12:20:13.326223: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/gradients_2/fnn/strided_slice_13_grad/StridedSliceGrad_grad/StridedSlice/gradients_2/fnn/strided_slice_13_grad/StridedSliceGrad/strides' with dtype int32 and shape [2]
# 	 [[{{node gradients/gradients_2/fnn/strided_slice_13_grad/StridedSliceGrad_grad/StridedSlice/gradients_2/fnn/strided_slice_13_grad/StridedSliceGrad/strides}}]]
# 2023-09-18 12:20:13.326805: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/gradients_2/fnn/strided_slice_14_grad/StridedSliceGrad_grad/StridedSlice/gradients_2/fnn/strided_slice_14_grad/StridedSliceGrad/strides' with dtype int32 and shape [2]
# 	 [[{{node gradients/gradients_2/fnn/strided_slice_14_grad/StridedSliceGrad_grad/StridedSlice/gradients_2/fnn/strided_slice_14_grad/StridedSliceGrad/strides}}]]
# 2023-09-18 12:20:13.327371: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/gradients_2/fnn/strided_slice_15_grad/StridedSliceGrad_grad/StridedSlice/gradients_2/fnn/strided_slice_15_grad/StridedSliceGrad/strides' with dtype int32 and shape [2]
# 	 [[{{node gradients/gradients_2/fnn/strided_slice_15_grad/StridedSliceGrad_grad/StridedSlice/gradients_2/fnn/strided_slice_15_grad/StridedSliceGrad/strides}}]]
# 2023-09-18 12:20:13.327929: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/gradients_2/fnn/strided_slice_16_grad/StridedSliceGrad_grad/StridedSlice/gradients_2/fnn/strided_slice_16_grad/StridedSliceGrad/strides' with dtype int32 and shape [2]
# 	 [[{{node gradients/gradients_2/fnn/strided_slice_16_grad/StridedSliceGrad_grad/StridedSlice/gradients_2/fnn/strided_slice_16_grad/StridedSliceGrad/strides}}]]
# 2023-09-18 12:20:13.328500: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/gradients_2/fnn/strided_slice_17_grad/StridedSliceGrad_grad/StridedSlice/gradients_2/fnn/strided_slice_17_grad/StridedSliceGrad/strides' with dtype int32 and shape [2]
# 	 [[{{node gradients/gradients_2/fnn/strided_slice_17_grad/StridedSliceGrad_grad/StridedSlice/gradients_2/fnn/strided_slice_17_grad/StridedSliceGrad/strides}}]]
# 2023-09-18 12:20:13.329064: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/gradients_2/fnn/strided_slice_18_grad/StridedSliceGrad_grad/StridedSlice/gradients_2/fnn/strided_slice_18_grad/StridedSliceGrad/strides' with dtype int32 and shape [2]
# 	 [[{{node gradients/gradients_2/fnn/strided_slice_18_grad/StridedSliceGrad_grad/StridedSlice/gradients_2/fnn/strided_slice_18_grad/StridedSliceGrad/strides}}]]
# 2023-09-18 12:20:13.329644: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/gradients_2/fnn/strided_slice_19_grad/StridedSliceGrad_grad/StridedSlice/gradients_2/fnn/strided_slice_19_grad/StridedSliceGrad/strides' with dtype int32 and shape [2]
# 	 [[{{node gradients/gradients_2/fnn/strided_slice_19_grad/StridedSliceGrad_grad/StridedSlice/gradients_2/fnn/strided_slice_19_grad/StridedSliceGrad/strides}}]]
# 2023-09-18 12:20:13.330237: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/gradients_2/fnn/strided_slice_20_grad/StridedSliceGrad_grad/StridedSlice/gradients_2/fnn/strided_slice_20_grad/StridedSliceGrad/strides' with dtype int32 and shape [2]
# 	 [[{{node gradients/gradients_2/fnn/strided_slice_20_grad/StridedSliceGrad_grad/StridedSlice/gradients_2/fnn/strided_slice_20_grad/StridedSliceGrad/strides}}]]
# 2023-09-18 12:20:13.330815: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/gradients_2/fnn/strided_slice_21_grad/StridedSliceGrad_grad/StridedSlice/gradients_2/fnn/strided_slice_21_grad/StridedSliceGrad/strides' with dtype int32 and shape [2]
# 	 [[{{node gradients/gradients_2/fnn/strided_slice_21_grad/StridedSliceGrad_grad/StridedSlice/gradients_2/fnn/strided_slice_21_grad/StridedSliceGrad/strides}}]]
# 2023-09-18 12:20:13.331421: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/gradients_2/fnn/strided_slice_22_grad/StridedSliceGrad_grad/StridedSlice/gradients_2/fnn/strided_slice_22_grad/StridedSliceGrad/strides' with dtype int32 and shape [2]
# 	 [[{{node gradients/gradients_2/fnn/strided_slice_22_grad/StridedSliceGrad_grad/StridedSlice/gradients_2/fnn/strided_slice_22_grad/StridedSliceGrad/strides}}]]
# 2023-09-18 12:20:13.331993: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/gradients_2/fnn/strided_slice_23_grad/StridedSliceGrad_grad/StridedSlice/gradients_2/fnn/strided_slice_23_grad/StridedSliceGrad/strides' with dtype int32 and shape [2]
# 	 [[{{node gradients/gradients_2/fnn/strided_slice_23_grad/StridedSliceGrad_grad/StridedSlice/gradients_2/fnn/strided_slice_23_grad/StridedSliceGrad/strides}}]]
# 2023-09-18 12:20:13.332567: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/gradients_2/fnn/strided_slice_24_grad/StridedSliceGrad_grad/StridedSlice/gradients_2/fnn/strided_slice_24_grad/StridedSliceGrad/strides' with dtype int32 and shape [2]
# 	 [[{{node gradients/gradients_2/fnn/strided_slice_24_grad/StridedSliceGrad_grad/StridedSlice/gradients_2/fnn/strided_slice_24_grad/StridedSliceGrad/strides}}]]
# ...
# 22000     [6.09e-02, 6.07e-02, 4.84e-02, 1.79e-02, 3.70e-04, 6.47e-03, 1.82e-03, 2.96e-02, 1.42e-01, 1.64e-03, 6.81e-03, 5.20e-04, 1.22e-03, 4.45e-04, 4.06e-04, 5.16e-04, 2.04e-04, 5.71e-04, 1.40e-06, 2.03e-04, 8.06e-06, 4.94e-04, 2.07e-03, 4.69e-04, 3.07e-04, 4.71e-04, 2.42e-04, 6.43e-02, 1.09e-02, 3.30e-03, 4.09e-04, 2.25e-03, 1.99e-04, 9.52e-06, 4.47e-03, 4.59e-03, 3.73e-03, 1.09e-04, 1.13e-02]    [5.73e-02, 5.86e-02, 4.79e-02, 1.78e-02, 3.71e-04, 3.69e-03, 7.60e-04, 3.02e-02, 1.37e-01, 8.93e-04, 6.10e-03, 5.22e-04, 1.22e-03, 4.41e-04, 3.84e-04, 2.08e-06, 4.38e-05, 4.99e-04, 1.21e-06, 3.65e-06, 9.64e-07, 4.96e-04, 1.38e-03, 3.90e-04, 2.78e-04, 4.77e-04, 2.38e-04, 6.43e-02, 1.07e-02, 3.30e-03, 4.12e-04, 2.08e-03, 2.01e-04, 7.61e-06, 4.47e-03, 4.60e-03, 3.72e-03, 1.12e-04, 1.13e-02]    []
# 23000     [1.44e-01, 4.44e-02, 1.95e-01, 1.80e-02, 3.80e-04, 4.90e-03, 1.23e-03, 7.39e-02, 2.22e-01, 9.25e-04, 5.66e-03, 5.36e-04, 1.23e-03, 4.47e-04, 1.27e-03, 4.82e-04, 1.61e-04, 9.38e-04, 1.87e-06, 1.95e-04, 5.37e-06, 4.95e-04, 3.90e-03, 3.48e-04, 4.37e-04, 4.85e-04, 2.29e-04, 6.15e-02, 1.04e-02, 2.99e-03, 3.97e-04, 2.14e-03, 1.28e-04, 1.05e-05, 4.23e-03, 4.44e-03, 3.66e-03, 9.80e-05, 1.09e-02]    [1.41e-01, 4.28e-02, 1.96e-01, 1.79e-02, 3.81e-04, 2.99e-03, 4.76e-04, 7.39e-02, 2.19e-01, 5.80e-04, 5.25e-03, 5.37e-04, 1.23e-03, 4.45e-04, 1.28e-03, 1.14e-06, 2.59e-05, 8.43e-04, 1.75e-06, 1.30e-06, 6.32e-07, 4.94e-04, 3.25e-03, 2.85e-04, 4.19e-04, 4.92e-04, 2.23e-04, 6.15e-02, 1.03e-02, 2.99e-03, 4.00e-04, 2.00e-03, 1.28e-04, 8.81e-06, 4.23e-03, 4.45e-03, 3.67e-03, 1.00e-04, 1.09e-02]    []
# 24000     [2.77e-03, 3.31e-01, 7.75e-03, 1.80e-02, 3.33e-04, 3.04e-03, 7.84e-04, 1.94e-01, 1.05e+00, 1.59e-03, 3.74e-03, 5.47e-04, 1.25e-03, 4.08e-04, 9.39e-05, 4.24e-04, 1.35e-04, 2.07e-03, 8.94e-06, 1.94e-04, 1.43e-06, 5.14e-04, 5.82e-04, 2.02e-03, 4.62e-04, 4.93e-04, 2.27e-04, 6.08e-02, 1.04e-02, 2.86e-03, 4.25e-04, 2.07e-03, 1.31e-04, 1.01e-05, 4.17e-03, 4.44e-03, 3.71e-03, 8.02e-05, 1.09e-02]    [7.42e-04, 3.31e-01, 7.78e-03, 1.79e-02, 3.35e-04, 1.62e-03, 1.70e-04, 1.95e-01, 1.05e+00, 1.46e-03, 3.08e-03, 5.49e-04, 1.25e-03, 4.08e-04, 8.63e-05, 8.10e-07, 1.39e-05, 2.00e-03, 8.86e-06, 1.36e-06, 2.54e-07, 5.14e-04, 5.30e-05, 2.00e-03, 4.52e-04, 5.01e-04, 2.21e-04, 6.08e-02, 1.03e-02, 2.86e-03, 4.28e-04, 1.99e-03, 1.32e-04, 8.64e-06, 4.17e-03, 4.45e-03, 3.74e-03, 8.19e-05, 1.09e-02]    []
# 25000     [2.97e+00, 6.06e+00, 1.16e+01, 1.91e-02, 6.52e-04, 8.82e-03, 1.34e-03, 1.09e+00, 1.50e+01, 5.38e-02, 1.07e+00, 5.73e-04, 1.12e-03, 6.20e-04, 7.59e-02, 4.00e-04, 1.41e-04, 1.13e-02, 1.21e-04, 2.26e-04, 6.17e-05, 4.00e-04, 7.07e-02, 3.58e-02, 7.19e-04, 4.97e-04, 2.20e-04, 5.64e-02, 9.62e-03, 2.53e-03, 3.88e-04, 1.92e-03, 7.34e-05, 1.68e-05, 3.86e-03, 4.12e-03, 3.51e-03, 8.76e-05, 9.88e-03]    [2.97e+00, 6.08e+00, 1.17e+01, 1.90e-02, 6.55e-04, 7.73e-03, 7.70e-04, 1.09e+00, 1.50e+01, 5.37e-02, 1.08e+00, 5.73e-04, 1.12e-03, 6.22e-04, 7.61e-02, 1.02e-05, 1.88e-05, 1.11e-02, 1.22e-04, 3.61e-05, 6.15e-05, 3.99e-04, 7.05e-02, 3.60e-02, 7.16e-04, 5.04e-04, 2.13e-04, 5.64e-02, 9.50e-03, 2.53e-03, 3.91e-04, 1.84e-03, 7.35e-05, 1.62e-05, 3.87e-03, 4.13e-03, 3.53e-03, 8.59e-05, 9.88e-03]    []
# 26000     [1.14e+01, 2.26e+00, 4.52e+00, 1.92e-02, 2.42e-04, 7.55e-03, 1.22e-03, 8.25e+00, 5.99e+00, 4.59e-03, 1.43e-02, 4.48e-04, 1.25e-03, 2.03e-04, 3.03e-02, 3.49e-04, 1.26e-04, 8.33e-02, 4.91e-05, 1.97e-04, 1.81e-06, 6.10e-04, 2.66e-01, 1.31e-02, 4.53e-03, 4.03e-04, 2.25e-04, 5.54e-02, 9.33e-03, 2.46e-03, 4.16e-04, 1.89e-03, 6.98e-05, 4.65e-06, 3.81e-03, 4.21e-03, 3.23e-03, 9.77e-05, 1.00e-02]    [1.14e+01, 2.27e+00, 4.54e+00, 1.95e-02, 2.43e-04, 6.48e-03, 7.87e-04, 8.28e+00, 6.02e+00, 4.17e-03, 1.34e-02, 4.50e-04, 1.25e-03, 2.02e-04, 3.04e-02, 5.29e-06, 1.99e-05, 8.41e-02, 4.95e-05, 7.53e-06, 1.22e-06, 6.19e-04, 2.68e-01, 1.32e-02, 4.54e-03, 4.07e-04, 2.21e-04, 5.54e-02, 9.23e-03, 2.46e-03, 4.19e-04, 1.86e-03, 6.99e-05, 4.04e-06, 3.81e-03, 4.21e-03, 3.24e-03, 9.47e-05, 1.00e-02]    []
# 27000     [5.41e+01, 4.49e+01, 1.10e+02, 1.73e-02, 3.56e-04, 1.38e-02, 9.58e-03, 1.10e+02, 3.90e+02, 1.07e-01, 1.10e-03, 4.15e-04, 1.36e-03, 4.99e-04, 7.14e-01, 3.10e-04, 2.71e-04, 1.12e+00, 3.18e-03, 2.46e-04, 2.80e-07, 4.44e-04, 1.28e+00, 2.66e-01, 5.52e-04, 3.74e-04, 1.94e-04, 5.27e-02, 8.93e-03, 2.32e-03, 4.98e-04, 1.80e-03, 6.13e-05, 9.98e-06, 3.53e-03, 4.02e-03, 3.01e-03, 5.29e-05, 9.72e-03]    [5.43e+01, 4.51e+01, 1.10e+02, 1.74e-02, 3.58e-04, 1.32e-02, 9.22e-03, 1.11e+02, 3.91e+02, 1.07e-01, 1.08e-03, 4.19e-04, 1.36e-03, 5.02e-04, 7.19e-01, 1.02e-05, 1.74e-04, 1.13e+00, 3.20e-03, 6.69e-05, 9.37e-08, 4.49e-04, 1.29e+00, 2.68e-01, 5.50e-04, 3.79e-04, 1.88e-04, 5.27e-02, 8.82e-03, 2.32e-03, 5.02e-04, 1.77e-03, 6.12e-05, 9.55e-06, 3.52e-03, 4.02e-03, 3.01e-03, 4.93e-05, 9.72e-03]    []
# 28000     [5.09e-04, 8.21e-03, 5.74e-04, 1.73e-02, 3.71e-04, 6.98e-03, 7.50e-03, 7.54e-03, 4.34e-03, 4.49e-03, 4.38e-03, 5.48e-04, 1.26e-03, 4.82e-04, 2.19e-05, 8.51e-05, 6.38e-04, 3.65e-04, 1.38e-07, 2.48e-04, 2.25e-06, 4.68e-04, 4.00e-04, 1.78e-04, 7.98e-05, 5.37e-04, 2.07e-04, 5.70e-02, 9.87e-03, 2.26e-03, 4.41e-04, 1.87e-03, 4.74e-05, 1.16e-05, 4.03e-03, 4.11e-03, 3.86e-03, 4.23e-05, 1.01e-02]    [3.28e-04, 6.67e-03, 5.27e-04, 1.75e-02, 3.68e-04, 4.34e-04, 1.29e-03, 8.89e-03, 4.30e-03, 4.46e-03, 4.09e-03, 5.53e-04, 1.25e-03, 4.40e-04, 1.32e-05, 4.86e-06, 8.73e-05, 3.30e-04, 1.35e-07, 1.28e-05, 7.29e-07, 4.73e-04, 2.39e-05, 1.34e-04, 2.56e-05, 5.28e-04, 2.00e-04, 5.70e-02, 9.49e-03, 2.26e-03, 4.45e-04, 1.82e-03, 4.65e-05, 1.16e-05, 3.99e-03, 4.09e-03, 3.38e-03, 4.06e-05, 1.01e-02]    []
# 29000     [1.63e-03, 3.07e-03, 4.26e-03, 1.73e-02, 3.62e-04, 4.78e-03, 3.38e-03, 1.59e-03, 8.10e-04, 1.62e-03, 5.82e-04, 5.22e-04, 1.19e-03, 4.42e-04, 8.43e-05, 9.44e-05, 3.24e-04, 1.38e-04, 3.84e-07, 2.03e-04, 8.14e-07, 4.67e-04, 4.21e-04, 6.49e-05, 6.26e-05, 5.20e-04, 2.01e-04, 5.50e-02, 9.35e-03, 2.23e-03, 4.10e-04, 1.81e-03, 5.00e-05, 8.90e-06, 3.84e-03, 3.94e-03, 3.31e-03, 3.96e-05, 9.68e-03]    [1.33e-03, 1.91e-03, 2.61e-03, 1.75e-02, 3.64e-04, 3.29e-04, 2.59e-04, 7.87e-04, 8.31e-04, 1.19e-03, 4.33e-04, 5.30e-04, 1.19e-03, 4.33e-04, 3.23e-05, 2.79e-06, 1.73e-05, 2.62e-05, 2.68e-08, 2.01e-06, 6.31e-08, 4.74e-04, 5.37e-05, 3.52e-05, 1.47e-05, 5.09e-04, 1.95e-04, 5.50e-02, 9.11e-03, 2.23e-03, 4.13e-04, 1.78e-03, 4.94e-05, 8.61e-06, 3.83e-03, 3.93e-03, 3.14e-03, 3.87e-05, 9.68e-03]    []
# 30000     [6.90e-04, 1.47e-02, 1.62e-03, 1.72e-02, 3.54e-04, 3.42e-03, 1.27e-03, 3.99e-02, 1.17e-01, 9.39e-04, 1.00e-03, 4.78e-04, 1.09e-03, 4.33e-04, 3.15e-05, 1.21e-04, 1.42e-04, 5.30e-04, 1.26e-06, 1.93e-04, 4.74e-07, 4.64e-04, 3.69e-04, 1.24e-04, 5.66e-05, 4.60e-04, 1.87e-04, 5.08e-02, 8.45e-03, 2.10e-03, 3.35e-04, 1.70e-03, 5.97e-05, 7.90e-06, 3.50e-03, 3.61e-03, 2.86e-03, 3.99e-05, 8.88e-03]    [7.23e-04, 1.38e-02, 1.43e-03, 1.74e-02, 3.56e-04, 3.21e-04, 1.23e-04, 3.87e-02, 1.18e-01, 5.10e-04, 6.61e-04, 4.82e-04, 1.09e-03, 4.26e-04, 1.87e-05, 2.61e-06, 2.94e-06, 4.17e-04, 9.87e-07, 2.66e-07, 8.05e-08, 4.72e-04, 3.27e-05, 9.81e-05, 2.41e-05, 4.49e-04, 1.82e-04, 5.08e-02, 8.34e-03, 2.10e-03, 3.38e-04, 1.68e-03, 5.94e-05, 7.88e-06, 3.50e-03, 3.61e-03, 2.84e-03, 3.96e-05, 8.88e-03]    []
# 31000     [1.61e-01, 1.02e+01, 1.82e+00, 3.07e-02, 1.73e-05, 2.28e-03, 1.72e-03, 1.72e+01, 6.72e+01, 8.30e-03, 2.28e-03, 3.71e-04, 1.20e-03, 7.79e-05, 1.19e-02, 1.25e-04, 1.53e-04, 1.76e-01, 5.49e-04, 2.08e-04, 3.95e-07, 1.00e-03, 4.09e-03, 6.05e-02, 1.01e-02, 3.67e-04, 1.71e-04, 4.54e-02, 7.56e-03, 1.70e-03, 2.60e-04, 1.57e-03, 4.49e-05, 1.43e-06, 3.16e-03, 3.20e-03, 2.60e-03, 1.49e-04, 7.70e-03]    [1.61e-01, 1.02e+01, 1.83e+00, 3.13e-02, 1.41e-05, 2.43e-04, 6.48e-04, 1.73e+01, 6.74e+01, 8.12e-03, 2.03e-03, 3.72e-04, 1.20e-03, 6.30e-05, 1.19e-02, 7.25e-07, 1.46e-05, 1.77e-01, 5.52e-04, 4.89e-06, 1.74e-07, 1.02e-03, 3.76e-03, 6.07e-02, 1.02e-02, 3.61e-04, 1.65e-04, 4.55e-02, 7.51e-03, 1.70e-03, 2.62e-04, 1.56e-03, 4.44e-05, 1.21e-06, 3.16e-03, 3.20e-03, 2.60e-03, 1.50e-04, 7.70e-03]    []
# 32000     [2.48e-01, 5.27e-02, 4.28e-01, 1.74e-02, 3.43e-04, 1.37e-03, 9.46e-04, 3.13e-03, 1.11e-01, 5.00e-04, 5.57e-03, 4.35e-04, 1.00e-03, 4.24e-04, 2.82e-03, 9.73e-05, 1.13e-04, 1.19e-04, 9.71e-07, 2.05e-04, 5.33e-07, 4.68e-04, 6.38e-03, 3.10e-04, 1.10e-04, 3.99e-04, 1.63e-04, 4.46e-02, 7.41e-03, 1.75e-03, 2.87e-04, 1.51e-03, 4.62e-05, 7.95e-06, 3.07e-03, 3.18e-03, 2.52e-03, 4.37e-05, 7.58e-03]    [2.49e-01, 5.27e-02, 4.30e-01, 1.75e-02, 3.45e-04, 3.24e-04, 1.66e-04, 2.47e-03, 1.11e-01, 1.33e-04, 5.44e-03, 4.36e-04, 1.01e-03, 4.21e-04, 2.86e-03, 2.26e-06, 4.70e-06, 4.72e-05, 8.80e-07, 3.63e-09, 3.65e-07, 4.72e-04, 6.03e-03, 3.06e-04, 1.04e-04, 4.03e-04, 1.58e-04, 4.46e-02, 7.37e-03, 1.76e-03, 2.89e-04, 1.50e-03, 4.58e-05, 7.96e-06, 3.07e-03, 3.18e-03, 2.53e-03, 4.39e-05, 7.58e-03]    []
# 33000     [1.23e+01, 7.80e-02, 1.58e+01, 1.77e-02, 3.16e-04, 1.04e-03, 8.58e-04, 8.91e+00, 1.27e+01, 9.24e-04, 6.19e-01, 3.75e-04, 1.01e-03, 3.29e-04, 1.03e-01, 7.19e-05, 7.60e-05, 9.08e-02, 1.04e-04, 2.12e-04, 3.59e-05, 5.13e-04, 2.91e-01, 4.58e-04, 1.84e-02, 3.48e-04, 1.56e-04, 4.13e-02, 6.85e-03, 1.51e-03, 2.65e-04, 1.40e-03, 3.82e-05, 6.45e-06, 2.84e-03, 2.97e-03, 2.33e-03, 1.18e-04, 6.89e-03]    [1.23e+01, 7.81e-02, 1.59e+01, 1.78e-02, 3.18e-04, 4.08e-04, 4.18e-04, 8.94e+00, 1.28e+01, 6.08e-04, 6.20e-01, 3.74e-04, 1.01e-03, 3.23e-04, 1.03e-01, 2.06e-06, 1.09e-05, 9.12e-02, 1.04e-04, 4.45e-07, 3.58e-05, 5.15e-04, 2.92e-01, 4.57e-04, 1.85e-02, 3.53e-04, 1.52e-04, 4.14e-02, 6.82e-03, 1.51e-03, 2.67e-04, 1.39e-03, 3.79e-05, 6.46e-06, 2.84e-03, 2.96e-03, 2.34e-03, 1.18e-04, 6.89e-03]    []
# 34000     [1.44e+00, 4.68e-01, 7.42e+00, 1.87e-02, 1.61e-04, 9.54e-03, 2.15e-03, 2.61e+01, 3.60e+01, 6.04e-04, 2.54e+00, 3.77e-04, 9.69e-04, 3.26e-04, 4.85e-02, 4.70e-05, 1.00e-04, 2.67e-01, 2.94e-04, 2.17e-04, 1.45e-04, 5.72e-04, 3.46e-02, 2.81e-03, 4.60e-03, 3.46e-04, 1.35e-04, 3.82e-02, 6.39e-03, 1.43e-03, 2.04e-04, 1.31e-03, 5.23e-05, 4.96e-06, 2.59e-03, 2.71e-03, 2.26e-03, 5.39e-05, 6.19e-03]    [1.44e+00, 4.67e-01, 7.45e+00, 1.89e-02, 1.61e-04, 9.21e-03, 1.81e-03, 2.62e+01, 3.61e+01, 2.43e-04, 2.55e+00, 3.76e-04, 9.71e-04, 3.22e-04, 4.87e-02, 7.92e-06, 4.34e-05, 2.68e-01, 2.96e-04, 1.41e-07, 1.45e-04, 5.75e-04, 3.44e-02, 2.78e-03, 4.61e-03, 3.51e-04, 1.32e-04, 3.83e-02, 6.38e-03, 1.43e-03, 2.05e-04, 1.32e-03, 5.22e-05, 4.85e-06, 2.59e-03, 2.70e-03, 2.28e-03, 5.46e-05, 6.19e-03]    []
# 35000     [4.73e-02, 1.73e-02, 5.01e-02, 1.75e-02, 3.21e-04, 5.62e-04, 8.38e-04, 8.51e-02, 1.22e-01, 6.01e-04, 1.20e-02, 3.71e-04, 8.92e-04, 3.93e-04, 3.58e-04, 1.87e-05, 8.72e-05, 9.34e-04, 1.09e-06, 2.20e-04, 1.64e-06, 4.77e-04, 1.51e-03, 1.22e-04, 2.75e-05, 3.38e-04, 1.26e-04, 3.50e-02, 5.84e-03, 1.23e-03, 2.00e-04, 1.24e-03, 3.03e-05, 8.63e-06, 2.41e-03, 2.54e-03, 2.01e-03, 4.57e-05, 5.59e-03]    [4.75e-02, 1.68e-02, 4.99e-02, 1.75e-02, 3.24e-04, 4.68e-04, 4.89e-04, 8.52e-02, 1.23e-01, 2.52e-04, 1.18e-02, 3.71e-04, 8.95e-04, 3.92e-04, 3.40e-04, 1.53e-06, 2.72e-05, 9.09e-04, 1.03e-06, 1.49e-07, 6.76e-07, 4.76e-04, 1.22e-03, 9.58e-05, 1.84e-05, 3.43e-04, 1.23e-04, 3.50e-02, 5.83e-03, 1.23e-03, 2.01e-04, 1.25e-03, 3.01e-05, 8.52e-06, 2.41e-03, 2.52e-03, 2.02e-03, 4.63e-05, 5.59e-03]    []
# 36000     [3.90e-03, 1.06e-03, 8.84e-04, 1.81e-02, 3.14e-04, 2.78e-03, 2.51e-03, 1.11e-03, 2.14e-03, 3.61e-03, 2.02e-03, 3.92e-04, 9.10e-04, 4.91e-04, 2.58e-05, 8.58e-06, 2.06e-04, 5.79e-05, 6.16e-06, 2.59e-04, 1.33e-06, 5.21e-04, 6.48e-04, 3.81e-05, 8.39e-05, 3.73e-04, 1.44e-04, 3.45e-02, 7.11e-03, 8.81e-04, 1.39e-04, 1.06e-03, 3.16e-05, 9.65e-06, 2.55e-03, 2.56e-03, 2.26e-03, 5.00e-05, 4.60e-03]    [1.42e-03, 6.80e-04, 1.45e-04, 1.80e-02, 3.16e-04, 1.09e-03, 2.83e-03, 9.47e-04, 1.09e-03, 1.23e-03, 1.64e-03, 3.94e-04, 8.97e-04, 4.12e-04, 2.75e-06, 1.97e-06, 1.50e-04, 3.24e-05, 2.69e-08, 1.77e-06, 3.43e-07, 5.18e-04, 1.32e-04, 1.30e-05, 1.46e-05, 3.72e-04, 1.37e-04, 3.35e-02, 6.18e-03, 8.80e-04, 1.40e-04, 1.06e-03, 2.94e-05, 9.51e-06, 2.42e-03, 2.44e-03, 1.90e-03, 3.20e-05, 4.60e-03]    []
# 37000     [1.61e-01, 5.08e-02, 1.94e-01, 1.79e-02, 3.11e-04, 2.00e-03, 1.88e-03, 1.33e-01, 4.15e-01, 1.28e-03, 6.34e-03, 3.35e-04, 7.13e-04, 4.07e-04, 1.27e-03, 1.05e-05, 1.86e-04, 1.45e-03, 1.11e-05, 2.81e-04, 2.32e-06, 5.11e-04, 4.31e-03, 3.51e-04, 5.33e-04, 3.17e-04, 1.29e-04, 3.19e-02, 6.22e-03, 9.65e-04, 1.05e-04, 9.68e-04, 4.07e-05, 9.04e-06, 2.32e-03, 2.35e-03, 1.92e-03, 2.76e-05, 4.17e-03]    [1.60e-01, 4.92e-02, 1.94e-01, 1.80e-02, 3.13e-04, 6.15e-04, 1.86e-03, 1.33e-01, 4.16e-01, 6.80e-04, 5.60e-03, 3.38e-04, 7.12e-04, 3.95e-04, 1.27e-03, 1.70e-06, 1.09e-04, 1.45e-03, 3.39e-06, 9.94e-07, 3.37e-07, 5.15e-04, 3.98e-03, 2.99e-04, 5.20e-04, 3.20e-04, 1.25e-04, 3.14e-02, 5.74e-03, 9.66e-04, 1.06e-04, 9.65e-04, 3.99e-05, 8.78e-06, 2.25e-03, 2.29e-03, 1.78e-03, 2.35e-05, 4.17e-03]    []
# 38000     [4.77e+01, 6.14e-02, 7.03e+01, 1.77e-02, 3.21e-04, 1.40e-03, 1.15e-03, 5.75e+00, 7.57e+00, 9.90e-04, 2.26e+00, 3.05e-04, 6.97e-04, 4.45e-04, 4.59e-01, 1.05e-05, 1.14e-04, 5.89e-02, 6.94e-05, 2.82e-04, 1.30e-04, 4.72e-04, 1.13e+00, 3.98e-04, 6.61e-02, 2.90e-04, 1.03e-04, 2.97e-02, 5.40e-03, 9.38e-04, 8.47e-05, 9.49e-04, 4.70e-05, 1.07e-05, 2.05e-03, 2.12e-03, 1.78e-03, 2.58e-05, 3.92e-03]    [4.79e+01, 6.09e-02, 7.05e+01, 1.78e-02, 3.24e-04, 8.77e-04, 1.10e-03, 5.77e+00, 7.61e+00, 8.15e-04, 2.27e+00, 3.08e-04, 6.95e-04, 4.43e-04, 4.61e-01, 1.30e-06, 3.27e-05, 5.92e-02, 6.22e-05, 1.17e-06, 1.30e-04, 4.79e-04, 1.14e+00, 3.71e-04, 6.64e-02, 2.93e-04, 1.01e-04, 2.94e-02, 5.24e-03, 9.39e-04, 8.51e-05, 9.49e-04, 4.68e-05, 9.95e-06, 2.03e-03, 2.10e-03, 1.76e-03, 2.54e-05, 3.92e-03]    []
# 39000     [6.42e+00, 9.42e+00, 5.25e+00, 2.02e-02, 1.04e-04, 1.99e-03, 1.15e-03, 6.48e+01, 5.86e+01, 3.05e-02, 9.45e+00, 3.19e-04, 6.74e-04, 2.75e-04, 3.44e-02, 1.43e-05, 9.11e-05, 6.61e-01, 4.88e-04, 2.96e-04, 5.39e-04, 6.54e-04, 1.52e-01, 5.54e-02, 4.03e-02, 3.04e-04, 1.07e-04, 2.80e-02, 4.75e-03, 9.31e-04, 6.36e-05, 9.04e-04, 7.27e-05, 4.86e-06, 1.90e-03, 1.98e-03, 1.63e-03, 1.80e-05, 3.48e-03]    [6.44e+00, 9.46e+00, 5.27e+00, 2.04e-02, 1.04e-04, 1.58e-03, 9.88e-04, 6.50e+01, 5.88e+01, 3.03e-02, 9.48e+00, 3.22e-04, 6.73e-04, 2.65e-04, 3.45e-02, 1.23e-06, 3.55e-05, 6.65e-01, 4.81e-04, 1.91e-05, 5.41e-04, 6.64e-04, 1.53e-01, 5.60e-02, 4.07e-02, 3.06e-04, 1.05e-04, 2.79e-02, 4.65e-03, 9.33e-04, 6.38e-05, 9.08e-04, 7.29e-05, 4.04e-06, 1.88e-03, 1.97e-03, 1.62e-03, 1.76e-05, 3.48e-03]    []
# 40000     [7.85e-02, 5.99e+00, 6.87e-01, 1.77e-02, 3.03e-04, 1.13e-03, 3.07e-04, 1.26e-01, 2.38e+00, 4.35e-04, 1.11e+00, 2.76e-04, 6.40e-04, 4.02e-04, 4.48e-03, 2.31e-05, 8.80e-05, 1.31e-03, 3.11e-05, 2.96e-04, 6.34e-05, 4.85e-04, 2.20e-03, 3.54e-02, 6.04e-03, 2.74e-04, 9.18e-05, 2.54e-02, 4.43e-03, 7.81e-04, 6.80e-05, 8.27e-04, 3.11e-05, 1.08e-05, 1.76e-03, 1.85e-03, 1.49e-03, 1.66e-05, 3.18e-03]    [7.87e-02, 6.01e+00, 6.90e-01, 1.79e-02, 3.05e-04, 9.92e-04, 1.72e-04, 1.27e-01, 2.39e+00, 4.41e-04, 1.11e+00, 2.78e-04, 6.41e-04, 4.01e-04, 4.51e-03, 7.13e-07, 1.17e-05, 1.31e-03, 1.95e-05, 6.70e-07, 6.33e-05, 4.92e-04, 1.86e-03, 3.56e-02, 6.09e-03, 2.75e-04, 9.05e-05, 2.52e-02, 4.32e-03, 7.82e-04, 6.83e-05, 8.29e-04, 3.09e-05, 9.62e-06, 1.74e-03, 1.84e-03, 1.45e-03, 1.52e-05, 3.18e-03]    []
#
# Best model at step 36000:
#   train loss: 9.83e-02
#   test loss: 8.57e-02
#   test metric: []
#
# 'train' took 1178.910926 s

# %%
dde.saveplot(losshistory, train_state, issave=True, isplot=True)
# Out:
# Saving loss history to /Users/vassilis/Documents/GitHub/PFAS_PBK_models/PFAS Rainbow trout PBK/PINN/DeepXDE_implementation/loss.dat ...
# Saving training data to /Users/vassilis/Documents/GitHub/PFAS_PBK_models/PFAS Rainbow trout PBK/PINN/DeepXDE_implementation/train.dat ...
# Saving test data to /Users/vassilis/Documents/GitHub/PFAS_PBK_models/PFAS Rainbow trout PBK/PINN/DeepXDE_implementation/test.dat ...

# %%
model.state_dict()
# Out:
# {'external_trainable_variable:0': <tf.Variable 'Variable:0' shape=() dtype=float32, numpy=0.6684276>,
#  'denses.0.kernel': <tf.Variable 'fnn/dense/kernel:0' shape=(1, 30) dtype=float32, numpy=
#  array([[ 0.06039709, -0.08787087,  0.09581082, -0.18302365, -0.05903233,
#          -0.05739836, -0.05116171,  0.12000835,  0.05594062, -0.42697135,
#           0.3240572 , -0.1887042 ,  0.08417027,  0.0861807 , -0.04056991,
#          -0.5138841 , -0.21480091, -0.09628475,  0.04993322, -0.09964344,
#           0.10922869,  0.05743807, -0.04608286,  0.27402303,  0.10079823,
#           0.18681778,  0.16568571,  0.07054561,  0.05542876, -0.7267485 ]],
#        dtype=float32)>,
#  'denses.0.bias': <tf.Variable 'fnn/dense/bias:0' shape=(30,) dtype=float32, numpy=
#  array([ 1.1250758e-01,  1.9469634e-01, -2.0243667e-01, -2.0147805e-01,
#          3.3336073e-01,  2.1029088e-01,  1.9613202e-01,  3.8409434e-02,
#          1.8616883e-01,  7.3072299e-02, -3.4770584e-01, -1.5974334e-01,
#          1.3685417e-02,  2.4962200e-02, -6.2712386e-02, -6.1269599e-01,
#         -3.5792136e-01, -3.9247627e-04,  1.4977328e-01, -2.3376834e-02,
#          5.6780983e-02,  6.6729911e-02,  1.0993146e-01, -2.8927052e-01,
#          1.3472173e-01,  5.7518319e-03,  1.3425088e-02,  1.0846717e-01,
#         -2.5857228e-01, -1.5217628e-01], dtype=float32)>,
#  'denses.1.kernel': <tf.Variable 'fnn/dense_1/kernel:0' shape=(30, 30) dtype=float32, numpy=
#  array([[ 8.07733983e-02, -1.22897208e-01,  1.06849633e-01,
#          -1.44205719e-01, -1.35267660e-01, -9.09074172e-02,
#           9.89947468e-03,  1.42589778e-01,  8.53175148e-02,
#          -2.84443349e-01,  3.65647048e-01, -3.15618366e-01,
#           7.40547776e-02,  1.00622818e-01, -8.29338282e-02,
#          -1.59166276e-01, -3.02841570e-02, -1.15263961e-01,
#           7.72284567e-02, -6.74966797e-02,  5.15957549e-02,
#          -1.00674748e-03, -9.45758168e-03,  2.29666889e-01,
#           8.90017599e-02,  2.58807927e-01,  6.23907521e-02,
#           1.16695233e-01, -1.01370448e-02, -2.77575731e-01],
#         [-9.15353447e-02,  2.47074366e-02,  1.37091383e-01,
#          -1.97325110e-01, -1.18662760e-01, -7.17260838e-02,
#          -2.33941495e-01, -2.25088120e-01, -2.14010522e-01,
#          -2.45629042e-01,  3.26524019e-01,  5.76517321e-02,
#           1.16059445e-01,  3.59190524e-01,  1.90229475e-01,
#          -1.09556681e-02,  1.49373710e-01, -1.56740680e-01,
#           9.29040927e-03, -5.80913685e-02,  6.98322132e-02,
#           1.09683506e-01, -3.24185729e-01, -9.94838178e-02,
#          -8.16674754e-02, -1.47706017e-01,  5.44425882e-02,
#          -7.46817365e-02, -2.39341572e-01,  9.19756591e-02],
#         [ 2.27554828e-01,  9.09826607e-02,  2.99358308e-01,
#          -4.81896242e-03, -3.53549570e-02,  2.12153271e-01,
#           2.17776358e-01, -5.11337183e-02,  2.11350575e-01,
#          -3.07187349e-01, -8.11393261e-02, -1.23719320e-01,
#          -4.00665224e-01, -1.73165619e-01, -7.54955634e-02,
#          -1.44696414e-01,  1.59537971e-01, -9.86730680e-02,
#          -2.84327239e-01,  3.97240855e-02, -3.00408483e-01,
#          -6.67741597e-02,  3.20067376e-01,  4.44078185e-02,
#           3.52116048e-01,  3.50174829e-02,  2.89708465e-01,
#           3.73511612e-02,  1.24268301e-01,  3.77422926e-04],
#         [-1.95288453e-02,  1.00995645e-01,  5.16599864e-02,
#          -2.02816650e-01, -2.38682061e-01, -4.91865762e-02,
#          -2.57079571e-01, -1.40448913e-01,  1.76530436e-01,
#          -8.14403221e-02,  1.15407899e-01,  6.07216582e-02,
#           3.81849051e-01,  2.18958795e-01,  6.66193292e-02,
#          -3.57294381e-01, -1.87064502e-02, -2.51867175e-01,
#          -2.46771082e-01,  6.44366518e-02,  4.77587841e-02,
#          -2.14964539e-01, -5.22793271e-02,  3.90233070e-01,
#           3.03855598e-01, -4.47995588e-03,  5.27221113e-02,
#           2.86915720e-01, -2.87607033e-03,  8.12229514e-02],
#         [-9.87112075e-02, -2.46297851e-01, -8.47080424e-02,
#           7.86052793e-02, -3.78010601e-01, -1.05528183e-01,
#           1.70269571e-02, -4.20368344e-01, -1.62926346e-01,
#           6.95280656e-02, -1.13050044e-02, -1.78175017e-01,
#          -1.83266506e-01,  2.36804739e-01,  2.14356869e-01,
#          -1.90637931e-01,  7.31161758e-02,  1.55735072e-02,
#           1.29029259e-01, -3.88382852e-01, -5.92798702e-02,
#           4.03498635e-02,  1.88747495e-01,  1.75590470e-01,
#          -5.92031889e-02, -1.26778781e-01,  1.89179167e-01,
#           6.01896159e-02,  2.41124392e-01,  1.85273513e-02],
#         [-2.15687871e-01, -2.08357513e-01,  1.87799416e-03,
#          -1.42757976e-02,  2.15997577e-01,  1.29197180e-01,
#          -3.49356771e-01,  1.68077573e-02, -4.57248017e-02,
#          -1.59096628e-01,  1.40875895e-02, -1.35259107e-01,
#           2.32755646e-01,  6.82214200e-02,  1.82224095e-01,
#          -8.76264647e-02, -1.75865874e-01,  1.26542989e-02,
#          -2.20197216e-01,  1.87364697e-01,  1.12084813e-01,
#           1.16115384e-01, -2.62746751e-01,  3.26829433e-01,
#           3.32374126e-01, -1.11155055e-01,  2.91329809e-02,
#           6.65819347e-02, -3.74261066e-02, -5.95318973e-02],
#         [ 1.01245366e-01,  1.48484647e-01, -2.16348097e-02,
#          -5.76340631e-02, -2.40597934e-01,  2.09953040e-01,
#          -2.39501610e-01, -1.72790229e-01, -1.84486672e-01,
#          -1.11734785e-01,  2.82246377e-02,  1.69773281e-01,
#          -5.73584326e-02,  1.22037448e-01, -1.32654002e-02,
#           3.79548877e-01, -2.49805134e-02,  2.59425472e-02,
#           1.40205637e-01, -1.50039032e-01,  2.35523120e-01,
#           1.59115985e-01, -3.24766278e-01,  2.23900884e-01,
#           2.30103046e-01,  9.31005999e-02,  1.95576504e-01,
#          -1.12601921e-01,  3.04369986e-01,  1.14595387e-02],
#         [-2.05211580e-01, -9.70649719e-02, -3.13943624e-02,
#           1.94884136e-01, -1.20716274e-01, -2.93177236e-02,
#           1.68142155e-01,  5.08478843e-02,  4.58804816e-01,
#           8.26531369e-03,  2.57283807e-01, -2.05158353e-01,
#           9.69293416e-02, -6.55738683e-03, -3.92897218e-01,
#          -2.32480705e-01, -1.69283345e-01, -1.40845552e-01,
#           1.99917987e-01, -7.97689259e-02, -5.37793003e-02,
#           8.35357457e-02,  3.32896262e-01, -2.32146066e-02,
#           4.06137966e-02,  2.57035762e-01, -3.88526060e-02,
#          -1.30681932e-01, -1.15456156e-01, -2.58127134e-02],
#         [-3.24995816e-01, -7.76706338e-02, -2.32979745e-01,
#           9.43938196e-02,  6.64362684e-02, -2.86162496e-02,
#          -2.58197874e-01,  7.44817033e-02,  2.99777389e-01,
#          -1.14719070e-01,  2.40962535e-01,  1.48249613e-02,
#          -7.37145022e-02, -2.86456496e-01,  2.27146640e-01,
#          -2.70168513e-01, -1.87212154e-02, -3.03243041e-01,
#           2.68530309e-01,  1.07910842e-01, -1.47090964e-02,
#           9.43081826e-02, -2.70371437e-01,  2.14818884e-02,
#           3.33682708e-02,  2.88952410e-01,  4.39368747e-02,
#           9.59161222e-02, -6.30248338e-02, -2.38034472e-01],
#         [ 8.40544924e-02, -8.36665779e-02,  2.52097368e-01,
#          -1.76378906e-01, -8.00799876e-02,  1.55067906e-01,
#          -1.77533939e-01, -8.28459933e-02, -3.58861357e-01,
#          -1.86796829e-01,  1.77044794e-01, -3.88514856e-03,
#          -1.27968220e-02, -8.66421405e-03,  1.61456481e-01,
#          -2.01199964e-01,  1.16592266e-01,  1.07237093e-01,
#          -2.74568588e-01, -4.79251742e-02,  1.13783732e-01,
#           3.29817116e-01,  2.52485245e-01,  2.77069867e-01,
#           9.57648605e-02,  1.25708744e-01,  4.32007574e-03,
#           3.97719115e-01,  5.11977933e-02,  2.89913893e-01],
#         [ 4.61799651e-02, -4.67184335e-02,  3.87184508e-02,
#          -2.57857472e-01,  2.00559214e-01,  7.24556446e-02,
#           4.39445972e-02,  1.16922624e-01,  4.88060042e-02,
#          -9.95342433e-02,  3.01275313e-01,  1.17298499e-01,
#           8.00709724e-02, -3.69633622e-02, -1.11733153e-01,
#          -2.52900720e-01,  1.40871480e-01,  5.44427410e-02,
#          -2.79321279e-02,  3.03827435e-01, -1.90996408e-01,
#          -3.25979292e-03,  3.57874572e-01,  1.13914713e-01,
#          -2.61188090e-01, -1.80717155e-01, -1.50563214e-02,
#          -3.27583075e-01,  1.78126141e-01,  2.44977370e-01],
#         [-1.87202275e-01, -2.40191892e-01, -1.85076296e-01,
#           1.37100115e-01,  9.22985896e-02, -2.02383637e-01,
#           1.30244330e-01, -1.28347471e-01, -7.19104856e-02,
#           5.69828525e-02, -1.30610481e-01, -1.61268383e-01,
#          -2.81330854e-01,  2.28483796e-01,  1.47603810e-01,
#           1.44246057e-01, -2.79432684e-01,  3.34425569e-01,
#           1.49895370e-01, -2.57824928e-01,  2.03512684e-01,
#           1.96663558e-01,  1.55626103e-01,  3.73234719e-01,
#           3.12152594e-01, -3.25428903e-01, -2.15516254e-01,
#          -1.63156182e-01,  1.45990312e-01, -1.29276216e-01],
#         [ 3.96276772e-01, -4.91138697e-02,  2.23979503e-01,
#          -2.26820886e-01,  2.15657637e-01,  6.03602566e-02,
#          -1.90494344e-01,  3.88843268e-02,  1.69945449e-01,
#           1.46741509e-01,  2.05485359e-01, -1.68463972e-03,
#           1.81968361e-01,  2.81093866e-01, -2.69610882e-02,
#          -3.41509163e-01,  3.52424360e-03,  5.23422435e-02,
#           1.00912504e-01,  3.03542316e-02, -4.62781042e-02,
#           6.77434728e-02, -2.05182537e-01,  1.85430318e-01,
#           1.34015143e-01,  2.69767195e-01,  2.02483550e-01,
#          -1.39158741e-01, -2.18939595e-02,  3.10733229e-01],
#         [ 5.20782284e-02, -3.60187709e-01,  1.11455649e-01,
#          -3.25153768e-01,  3.92478585e-01,  7.54011795e-02,
#           6.33229986e-02, -1.34207020e-02,  2.32203498e-01,
#           4.42913547e-02, -5.89440167e-02,  3.26483160e-01,
#          -1.12066716e-01, -6.12993725e-02,  9.09678638e-02,
#          -1.85299352e-01, -9.45044607e-02,  4.05098684e-02,
#           7.70983323e-02, -2.39119843e-01, -1.49051204e-01,
#          -1.91865280e-01,  6.21318780e-02, -9.92944837e-02,
#           1.26171380e-01,  1.11448683e-01, -2.15997219e-01,
#           4.38934714e-02, -3.70392412e-01, -1.06776170e-01],
#         [-6.33934513e-02,  7.99072534e-03,  6.27327487e-02,
#           1.75348401e-01, -2.05033049e-01,  2.97822177e-01,
#          -1.50297150e-01, -2.50812829e-01, -1.40768692e-01,
#          -7.12969750e-02, -2.03840926e-01,  8.74447674e-02,
#          -2.28540406e-01,  8.89004320e-02, -3.85544971e-02,
#           2.94876397e-01,  3.55007201e-01,  1.66228920e-01,
#          -3.94721419e-01,  1.46805823e-01,  9.26283747e-02,
#          -1.54561222e-01,  2.23261893e-01,  1.79138169e-01,
#          -6.32000193e-02, -2.83738792e-01, -1.30174793e-02,
#           1.23665348e-01,  8.34021270e-02, -3.44022185e-01],
#         [-2.05199853e-01,  1.27527878e-01,  1.49133012e-01,
#           3.09010059e-01, -7.10445573e-04,  1.29588559e-01,
#           1.49580494e-01, -2.43073985e-01, -4.22309548e-01,
#          -3.17444950e-02, -1.77555591e-01,  1.11875115e-02,
#           1.67960584e-01,  1.80006817e-01, -2.07155406e-01,
#          -1.23335451e-01, -1.92227364e-01, -1.03673153e-01,
#          -4.01886590e-02,  3.17953043e-02,  1.49209216e-01,
#          -3.79098117e-01, -1.86920613e-01,  1.77407742e-01,
#           2.02659965e-01, -3.09991091e-01,  1.54503778e-01,
#           1.37444168e-01,  2.64810860e-01,  6.15030453e-02],
#         [ 2.04902574e-01, -3.44274677e-02,  1.10909678e-01,
#          -2.04567358e-01, -1.22359671e-01,  2.70146579e-01,
#           8.64267573e-02, -6.08634204e-02, -7.71540180e-02,
#          -1.04507230e-01, -1.16194412e-01, -4.33412381e-02,
#           7.47171342e-02,  3.84188592e-01, -9.52135623e-02,
#           2.28204444e-01,  2.78486133e-01, -4.13700849e-01,
#          -4.73798662e-01,  2.00445041e-01, -2.44644791e-01,
#          -6.68098554e-02, -1.68089956e-01,  1.65570050e-01,
#          -1.47792041e-01,  2.91261785e-02,  2.66865045e-01,
#           3.82624656e-01,  7.58924857e-02,  6.42089322e-02],
#         [-4.53674078e-01,  4.60528508e-02,  1.40876904e-01,
#           9.90122631e-02, -1.16745323e-01, -1.58813484e-02,
#           3.01382124e-01, -9.54658464e-02,  3.13827723e-01,
#          -2.09358215e-01, -6.12337887e-02, -2.36026898e-01,
#          -2.07033157e-01, -3.31999600e-01,  1.61644444e-01,
#           1.54638335e-01, -3.56175341e-02,  1.11484401e-01,
#          -1.40385449e-01, -2.95687109e-01, -2.79515535e-01,
#           2.98189856e-02, -4.12265509e-01, -8.41255933e-02,
#           4.63312417e-02, -2.05945801e-02,  1.42247438e-01,
#           3.77036959e-01,  2.51484990e-01,  1.93863362e-01],
#         [-3.99213955e-02,  2.78115213e-01, -3.44240010e-01,
#           2.03782141e-01,  7.76856346e-03, -8.67405683e-02,
#          -2.81309634e-01,  7.20259920e-02,  6.31581023e-02,
#           1.45721227e-01,  5.39673232e-02, -2.16705129e-01,
#           5.85380383e-02, -2.92767733e-01, -2.13735268e-01,
#          -2.07569916e-02, -1.77119702e-01,  9.33242366e-02,
#           9.94322225e-02,  2.35928103e-01, -2.66485866e-02,
#           6.37160465e-02,  1.04489356e-01,  3.69851887e-01,
#          -3.92838567e-01, -1.45657420e-01,  3.53232294e-01,
#          -2.05955759e-04, -5.22221476e-02,  4.39614095e-02],
#         [-2.82553770e-02,  8.87005702e-02,  3.92302483e-01,
#          -3.43036741e-01, -2.00815469e-01, -1.08631246e-01,
#          -1.20799981e-01, -4.41325337e-01, -4.36774284e-01,
#           7.63503462e-02,  1.09560326e-01, -1.72325931e-02,
#           1.78196475e-01, -6.86562210e-02,  2.84818802e-02,
#          -9.40645263e-02,  1.55879200e-01, -1.89015165e-01,
#          -2.72030652e-01,  7.83390924e-02, -2.76596010e-01,
#           1.71224922e-01,  3.66192870e-02, -3.72543707e-02,
#           3.56505990e-01, -1.00696713e-01, -1.45313457e-01,
#           1.91053420e-01, -1.01764373e-01, -9.42491926e-03],
#         [-6.29743040e-02, -3.63637209e-02,  1.62037671e-01,
#           3.41759384e-01,  2.49600396e-01, -1.26276091e-01,
#           1.96831916e-02,  7.41596371e-02,  2.85644501e-01,
#          -9.62623209e-02,  4.16635484e-01, -2.53265381e-01,
#           7.98484012e-02,  5.20920791e-02,  1.03596933e-01,
#          -6.45981729e-02, -8.60075280e-03,  2.05742046e-01,
#          -2.19709218e-01,  2.85158932e-01,  3.30198370e-02,
#          -1.92207750e-02,  1.61660805e-01, -3.02841365e-01,
#          -2.59796143e-01, -1.32679150e-01,  2.54271001e-01,
#           3.20477039e-01, -2.83952683e-01, -1.71662480e-01],
#         [-7.98366207e-04,  2.06500739e-01, -2.64740080e-01,
#           1.75049946e-01, -5.21116294e-02,  1.35913998e-01,
#           2.95977175e-01,  2.97591627e-01, -9.89891216e-02,
#          -3.40720326e-01, -2.15659678e-01, -1.42702714e-01,
#          -1.71431020e-01,  1.09563172e-01, -9.49956328e-02,
#           1.21703699e-01,  1.67330697e-01,  1.24324717e-01,
#           2.09637895e-01, -2.72113502e-01, -1.59354553e-01,
#           1.97869673e-01, -1.70238800e-02, -6.54087514e-02,
#          -3.58622968e-01,  6.41672164e-02, -2.31415942e-01,
#          -3.69053125e-01,  2.60472670e-02,  8.44635591e-02],
#         [ 6.59461990e-02,  1.24779612e-01,  8.08350276e-03,
#           3.02443281e-03,  4.66585457e-02, -2.65456855e-01,
#           7.32637793e-02,  2.08504051e-01,  8.13220963e-02,
#           1.54724866e-01,  5.63800000e-02, -2.36724671e-02,
#           3.60405669e-02,  3.27179879e-01, -1.81635097e-01,
#           2.40275353e-01, -1.38263971e-01, -3.46355021e-01,
#          -1.69846192e-01,  3.27948749e-01, -1.37963206e-01,
#          -9.28864479e-02,  8.92098770e-02, -3.19726557e-01,
#          -1.25171607e-02, -2.70254254e-01, -4.30662856e-02,
#           3.68134409e-01, -2.82756180e-01, -1.70644864e-01],
#         [ 3.63192111e-01, -3.52992257e-03, -3.62660080e-01,
#           1.25014633e-01,  1.84007272e-01, -1.41599104e-01,
#          -6.62177354e-02, -6.42757118e-02,  2.08674878e-01,
#          -2.80925959e-01, -1.57070845e-01, -6.53184727e-02,
#          -2.06309795e-01,  1.22492880e-01,  8.77714455e-02,
#           2.53236532e-01, -9.90724340e-02,  1.79715469e-01,
#           2.35518828e-01, -1.65217787e-01, -4.29825634e-02,
#          -8.32278281e-02,  9.03476328e-02,  3.79114859e-02,
#          -8.03272277e-02, -3.42120565e-02,  8.37819204e-02,
#           1.27756549e-02, -5.42327464e-02,  8.15811902e-02],
#         [ 3.41911279e-02, -3.53984773e-01, -6.54962286e-02,
#          -8.60728696e-03,  2.50526845e-01, -8.19842592e-02,
#          -1.09735057e-01,  1.54565066e-01, -1.76537737e-01,
#           1.63265586e-01, -7.13422224e-02, -2.17794374e-01,
#          -4.09447029e-02,  2.32611418e-01,  2.12731250e-02,
#          -2.45001867e-01,  1.72490746e-01,  4.40128706e-02,
#          -2.83095310e-03, -4.37967092e-01,  2.17842489e-01,
#          -1.23255834e-01,  2.42674559e-01, -1.66148975e-01,
#           7.04726651e-02,  1.07605107e-01, -1.61746725e-01,
#          -2.32990742e-01,  2.82308012e-01,  3.41413617e-01],
#         [-5.53613231e-02,  1.78278666e-02, -3.73679638e-01,
#           2.37008169e-01,  2.23910481e-01, -3.77894156e-02,
#           1.57342926e-01,  1.38511077e-01,  8.97778198e-02,
#           4.38670302e-03,  2.14392170e-02, -3.27862114e-01,
#          -2.24506985e-02, -1.70062348e-01, -3.88903290e-01,
#          -2.22579062e-01, -4.59557306e-03, -2.05276936e-01,
#           9.26689059e-02, -2.06725016e-01,  9.83812660e-02,
#          -4.56478372e-02,  4.39521931e-02,  1.75497323e-01,
#          -2.37390511e-02,  1.13280378e-01, -1.76403552e-01,
#           1.61066473e-01,  1.71919972e-01,  1.64164975e-01],
#         [-1.13260768e-01,  1.87006876e-01,  1.89919099e-01,
#           3.68042476e-02,  6.31009042e-02,  3.66417915e-01,
#           3.25018078e-01, -1.47386119e-01, -2.59854913e-01,
#          -1.72950551e-01, -2.38562971e-01, -2.52528369e-01,
#           3.15666548e-05, -1.18322775e-01, -1.89650282e-01,
#          -1.49531841e-01,  6.42376952e-03, -2.17729300e-01,
#           1.99685559e-01,  6.99677914e-02, -4.67917556e-03,
#           9.98803694e-03, -8.98330286e-02,  3.47232521e-01,
#          -1.66663647e-01, -6.01227283e-02,  1.79485023e-01,
#          -8.93955678e-03, -2.29397699e-01, -7.84754902e-02],
#         [ 4.33840036e-01, -1.07580416e-01,  2.16647848e-01,
#          -6.98846579e-02,  6.91318512e-03,  4.03228868e-03,
#           2.28516147e-01, -1.07137449e-01,  2.82856971e-01,
#           1.72261186e-02, -1.42751440e-01, -7.37577379e-02,
#           3.79788071e-01, -3.64224494e-01, -9.87869799e-02,
#           7.43553787e-02,  3.67478162e-01, -7.42413029e-02,
#           3.05270404e-01, -4.92049530e-02,  1.19781107e-01,
#           1.62525505e-01,  1.34307006e-02, -1.72383741e-01,
#          -2.07109004e-01, -1.81969553e-02,  8.29154402e-02,
#          -1.84495121e-01, -2.07724601e-01, -4.07974184e-01],
#         [ 3.36222529e-01,  1.67908937e-01, -1.24165617e-01,
#          -1.61933810e-01, -1.70617819e-01,  1.52690977e-01,
#           4.24172223e-01, -1.51686549e-01,  1.04353167e-01,
#           1.59333885e-01,  1.48812793e-02, -1.67838484e-01,
#          -1.34335309e-01,  2.97545195e-01,  1.20443672e-01,
#           7.81104118e-02, -7.21511245e-02,  1.06127627e-01,
#          -1.39261931e-01,  7.99182579e-02,  1.71513185e-01,
#           1.02992021e-02,  4.35193209e-03, -1.95925757e-01,
#           2.98335887e-02,  1.36396095e-01,  3.41612309e-01,
#           1.52234837e-01,  1.61745548e-01,  9.42623690e-02],
#         [-3.50327969e-01, -1.87834546e-01,  1.80290192e-01,
#           1.21677257e-01, -7.01122731e-02, -1.81458183e-02,
#           2.33687922e-01,  1.86558113e-01,  2.32454672e-01,
#          -2.05930799e-01, -2.57981598e-01, -5.39912805e-02,
#          -1.21110126e-01, -2.02597640e-02,  9.17021036e-02,
#           3.84050578e-01,  6.18888140e-02,  2.54114091e-01,
#           1.93075359e-01, -1.26487657e-01, -5.12636006e-02,
#          -5.70033304e-02, -1.03622757e-01,  1.89713880e-01,
#           1.96356982e-01, -3.80388424e-02,  1.79693311e-01,
#           2.74986923e-02, -7.94236585e-02, -4.29415554e-02]], dtype=float32)>,
#  'denses.1.bias': <tf.Variable 'fnn/dense_1/bias:0' shape=(30,) dtype=float32, numpy=
#  array([ 0.05401159, -0.02017205, -0.02506872,  0.02023706,  0.05547512,
#         -0.00844456,  0.01819696,  0.05280168,  0.06198338,  0.00683269,
#          0.01087936, -0.02960558, -0.00363624, -0.04245887, -0.03474446,
#         -0.0481841 ,  0.00476303,  0.00619931,  0.08071207, -0.02365726,
#         -0.00935279, -0.00954618,  0.02592216, -0.01519407, -0.04963018,
#          0.03632504,  0.01027382, -0.03575083, -0.01750612, -0.00189012],
#        dtype=float32)>,
#  'denses.2.kernel': <tf.Variable 'fnn/dense_2/kernel:0' shape=(30, 30) dtype=float32, numpy=
#  array([[ 4.84296121e-02, -1.17096692e-01,  9.23960805e-02,
#          -1.66447267e-01, -2.09985465e-01, -7.64166787e-02,
#          -2.71919761e-02,  1.15571640e-01, -3.04155238e-03,
#          -2.78174073e-01,  3.21428955e-01, -2.78421819e-01,
#           3.04438416e-02,  1.27015918e-01, -3.76522057e-02,
#          -1.46368131e-01, -5.80177195e-02, -1.53282240e-01,
#           4.19816338e-02, -3.48344967e-02,  7.81564787e-02,
#           4.99897413e-02, -2.89166849e-02,  2.64564008e-01,
#           1.07478939e-01,  2.33449817e-01,  9.62655470e-02,
#           1.96623489e-01, -7.11210584e-03, -2.80146182e-01],
#         [ 1.03286818e-01,  3.73678468e-03,  3.35012041e-02,
#          -2.31206343e-02, -6.95963427e-02, -8.70840400e-02,
#          -1.82844520e-01, -2.70046383e-01, -6.49973154e-02,
#          -2.50947863e-01,  1.07847355e-01, -6.02437109e-02,
#           1.48463577e-01,  2.22092226e-01,  3.95509638e-02,
#           1.34116160e-02,  1.49565935e-01, -1.72527730e-01,
#           1.27686813e-01, -6.86559975e-02,  1.47130340e-01,
#          -4.97465953e-02, -1.55716732e-01, -1.37036711e-01,
#          -1.25744700e-01,  7.16494843e-02,  3.11490372e-02,
#           1.60223953e-02, -1.40963793e-01,  2.64068739e-03],
#         [ 1.64232999e-01,  1.57712042e-01,  3.77789438e-01,
#          -1.05214585e-02, -5.18211089e-02,  2.02620044e-01,
#           2.08353892e-01, -1.06750362e-01,  9.19137076e-02,
#          -3.37743610e-01, -6.65353835e-02, -1.17111593e-01,
#          -3.58137012e-01, -1.30361959e-01, -2.11825594e-02,
#          -6.71803504e-02,  1.90840691e-01, -5.66303432e-02,
#          -3.92951161e-01,  8.32525268e-02, -2.89947838e-01,
#          -7.78429210e-02,  2.95810729e-01,  5.18117100e-02,
#           4.29576844e-01, -6.55332729e-02,  2.47445613e-01,
#           4.31028716e-02,  1.67840913e-01,  2.37115398e-02],
#         [ 6.32454455e-02,  9.59877968e-02,  3.76685932e-02,
#          -1.88654795e-01, -1.54608518e-01, -1.08202048e-01,
#          -1.91742957e-01, -4.42110654e-03,  2.44789332e-01,
#          -1.14686623e-01,  1.17870927e-01, -2.48393193e-02,
#           3.79348367e-01,  1.20209232e-01, -8.02338589e-03,
#          -3.64487976e-01,  2.50415578e-02, -2.40613714e-01,
#          -1.32144481e-01,  1.84426438e-02, -1.39185722e-04,
#          -2.02392921e-01, -3.06406636e-02,  3.88933659e-01,
#           2.59992003e-01,  1.06804691e-01,  1.37008861e-01,
#           2.74978966e-01, -2.55265832e-02,  7.99658820e-02],
#         [-1.78014897e-02, -2.85822749e-01, -1.47504181e-01,
#           9.26200971e-02, -3.43842268e-01, -1.14738919e-01,
#           1.29290624e-02, -3.56107861e-01, -5.76534793e-02,
#           8.40037167e-02, -3.56719196e-02, -2.01471388e-01,
#          -2.35243395e-01,  1.76776677e-01,  1.79455712e-01,
#          -2.80355394e-01,  5.73682822e-02, -6.21583452e-03,
#           2.53722191e-01, -4.01176780e-01, -5.13154380e-02,
#           5.92673346e-02,  2.29765788e-01,  1.85547620e-01,
#          -1.47043273e-01, -5.07418588e-02,  2.43901432e-01,
#           7.18293488e-02,  2.11801559e-01,  1.38424868e-02],
#         [-8.42340216e-02, -2.22818568e-01, -4.81339470e-02,
#          -2.54277065e-02,  2.95772374e-01,  7.87421092e-02,
#          -3.09721857e-01,  2.09171902e-02,  6.32078573e-02,
#          -1.82121500e-01, -3.55371758e-02, -1.75006762e-01,
#           1.61121711e-01,  5.39164431e-03,  9.45331827e-02,
#          -7.30082989e-02, -1.55954897e-01,  1.87530257e-02,
#          -1.07131988e-01,  1.61427081e-01,  1.55952111e-01,
#           2.06928514e-02, -1.19251460e-01,  3.19173783e-01,
#           2.74101108e-01, -3.10838111e-02,  4.87895906e-02,
#           1.04497746e-01, -2.34563574e-02, -1.26665756e-01],
#         [ 1.92114666e-01,  1.10335633e-01, -7.80944675e-02,
#          -4.16632332e-02, -1.96929246e-01,  1.99318111e-01,
#          -2.49347299e-01, -1.01308890e-01, -8.34166557e-02,
#          -9.33099240e-02,  7.59603409e-03,  1.44386619e-01,
#          -1.02715880e-01,  6.23111986e-02, -4.41033542e-02,
#           2.82186180e-01, -2.96267718e-02,  8.60076677e-03,
#           2.64917105e-01, -1.62120491e-01,  2.44795635e-01,
#           2.01450601e-01, -2.84199685e-01,  2.30781823e-01,
#           1.50723025e-01,  1.63208500e-01,  2.47194514e-01,
#          -9.88648683e-02,  2.77401596e-01,  1.09930495e-02],
#         [-2.37168208e-01, -9.42322090e-02, -4.35988121e-02,
#           1.68853194e-01, -1.94902837e-01, -1.71826445e-02,
#           1.37126103e-01,  2.65840720e-02,  3.71681660e-01,
#           1.02220345e-02,  2.13001266e-01, -1.76249549e-01,
#           5.69337308e-02,  1.48361260e-02, -3.46782565e-01,
#          -2.18591526e-01, -1.95638523e-01, -1.80080637e-01,
#           1.67127654e-01, -5.22407815e-02, -2.63893064e-02,
#           1.34436563e-01,  3.13272893e-01,  1.26138730e-02,
#           5.87176383e-02,  2.32726157e-01, -3.37344455e-03,
#          -4.69034910e-02, -1.07501641e-01, -2.80839670e-02],
#         [-3.70646626e-01, -9.99767631e-02, -2.28627428e-01,
#           4.87940572e-02,  7.20012235e-03, -3.30172566e-04,
#          -3.09218794e-01,  2.71944124e-02,  2.00578436e-01,
#          -9.65796635e-02,  2.15280235e-01,  2.52802894e-02,
#          -1.01686768e-01, -2.82679617e-01,  2.90878624e-01,
#          -2.73397267e-01, -6.48918375e-02, -3.27119887e-01,
#           2.56668776e-01,  1.55297175e-01,  3.29340063e-02,
#           1.18490443e-01, -3.02533180e-01,  4.18967865e-02,
#           6.26059771e-02,  2.88806051e-01,  1.03658982e-01,
#           1.98544413e-01, -7.81751722e-02, -2.30317906e-01],
#         [ 1.55880854e-01, -1.11363053e-01,  1.93286389e-01,
#          -4.97860424e-02, -3.26255038e-02,  1.55097172e-01,
#          -1.19984068e-01, -7.82508552e-02, -2.00561464e-01,
#          -6.81046695e-02,  2.13412568e-01, -2.27348227e-02,
#          -1.66545399e-02,  1.70471314e-02,  7.10151196e-02,
#          -2.48960599e-01,  9.47896093e-02,  9.27464962e-02,
#          -1.68684170e-01, -1.02486305e-01,  5.08065633e-02,
#           2.55536795e-01,  2.02302560e-01,  2.71213919e-01,
#          -3.58632929e-03,  1.45863846e-01,  3.08781844e-02,
#           3.42731595e-01, -3.33557688e-02,  1.98040977e-01],
#         [ 1.69241149e-02, -5.53269722e-02,  1.27318110e-02,
#          -2.79440522e-01,  1.21270061e-01,  9.30711478e-02,
#           1.44288661e-02,  8.34546313e-02, -2.86082514e-02,
#          -9.50967148e-02,  2.58202851e-01,  1.60352618e-01,
#           4.30679657e-02, -1.31969396e-02, -6.99769780e-02,
#          -2.27648139e-01,  1.00580536e-01,  5.92455175e-03,
#          -7.06294626e-02,  3.18727344e-01, -1.75944060e-01,
#           3.71684805e-02,  3.25278491e-01,  1.40240148e-01,
#          -2.37880066e-01, -1.88640922e-01,  7.69625511e-03,
#          -2.42278412e-01,  1.71556234e-01,  2.38390654e-01],
#         [-1.50437653e-01, -2.26296961e-01, -1.73997775e-01,
#           1.71071738e-01,  1.59405485e-01, -2.05677405e-01,
#           1.68147922e-01, -9.74387452e-02, -3.72872432e-03,
#           6.12712055e-02, -8.73173177e-02, -1.99502677e-01,
#          -2.36380041e-01,  2.00833961e-01,  1.14087880e-01,
#           1.34762675e-01, -2.53326446e-01,  3.65838587e-01,
#           1.78146347e-01, -2.79362291e-01,  1.79892555e-01,
#           1.43963501e-01,  1.74056277e-01,  3.27161521e-01,
#           2.99369216e-01, -3.15113395e-01, -2.47125626e-01,
#          -2.47278154e-01,  1.40835658e-01, -1.34368151e-01],
#         [ 3.15990090e-01, -2.81237382e-02,  2.13518187e-01,
#          -1.37032136e-01,  1.19094133e-01,  1.06014870e-01,
#          -1.52170703e-01, -6.28176257e-02,  4.06164937e-02,
#           1.11102886e-01,  2.23150983e-01,  2.16850154e-02,
#           2.63405293e-01,  3.36610973e-01,  5.61252683e-02,
#          -1.76439226e-01, -3.31707112e-02,  1.12647619e-02,
#          -1.05171964e-01, -5.10543305e-03, -6.12849928e-02,
#          -2.30435804e-02, -2.43933931e-01,  1.06134675e-01,
#           2.42293790e-01,  2.00146616e-01,  8.85794908e-02,
#          -1.24709204e-01, -1.92547683e-02,  2.89514542e-01],
#         [-4.96847322e-03, -2.89445639e-01,  1.93856522e-01,
#          -3.35225284e-01,  3.79603773e-01,  6.35405108e-02,
#           5.31751290e-02, -6.32173121e-02,  1.24216296e-01,
#           1.72654111e-02, -5.31681105e-02,  3.26814443e-01,
#          -7.37600699e-02, -2.38645934e-02,  1.43692315e-01,
#          -1.14765421e-01, -5.67641370e-02,  8.32346976e-02,
#          -3.10067683e-02, -1.87351704e-01, -1.35699615e-01,
#          -1.98045522e-01,  4.34213653e-02, -9.13155228e-02,
#           2.04230502e-01,  1.78057626e-02, -2.51422733e-01,
#           4.76835966e-02, -3.20058346e-01, -8.61590579e-02],
#         [-2.35404763e-02,  8.53133854e-03,  7.85705149e-02,
#           1.90046445e-01, -1.22139484e-01,  2.77131408e-01,
#          -1.09704442e-01, -2.20637679e-01, -5.90307005e-02,
#          -7.79574886e-02, -1.58010036e-01,  5.56395985e-02,
#          -1.84593186e-01,  5.78469709e-02, -9.20891091e-02,
#           2.79607922e-01,  3.87192190e-01,  2.13199973e-01,
#          -3.53888035e-01,  1.16689697e-01,  6.20798990e-02,
#          -1.94019720e-01,  2.34475583e-01,  1.50851160e-01,
#          -7.40004703e-02, -2.51028687e-01, -4.99789417e-02,
#           4.71044257e-02,  7.94987157e-02, -3.30539197e-01],
#         [-1.74220532e-01,  1.32175058e-01,  1.64130062e-01,
#           3.33303988e-01,  7.53445178e-02,  1.17236868e-01,
#           1.86946020e-01, -2.09560543e-01, -3.64087313e-01,
#          -3.31756994e-02, -1.32966682e-01, -2.53036153e-02,
#           2.08460957e-01,  1.53806135e-01, -2.48476729e-01,
#          -1.35619491e-01, -1.62770227e-01, -6.49248734e-02,
#          -1.85796432e-03,  4.64855181e-03,  1.24714486e-01,
#          -4.26719129e-01, -1.68358356e-01,  1.41469806e-01,
#           1.86395809e-01, -2.99204171e-01,  1.23809941e-01,
#           5.39078712e-02,  2.62332946e-01,  6.40384629e-02],
#         [ 2.31277198e-01, -1.67609956e-02,  1.06671169e-01,
#          -2.25704238e-01, -2.15258021e-02,  2.55174726e-01,
#           1.09723747e-01,  2.52347421e-02,  2.41899583e-02,
#          -1.21131763e-01, -7.37497807e-02, -3.56085934e-02,
#           6.89988732e-02,  3.24813426e-01, -1.76831678e-01,
#           1.15236588e-01,  2.49310911e-01, -3.49430054e-01,
#          -3.22231114e-01,  1.46191880e-01, -1.28309503e-01,
#          -8.51104409e-02, -1.26778200e-01,  1.95507467e-01,
#          -1.70602232e-01,  1.78306885e-02,  1.91874638e-01,
#           2.66053349e-01, -1.62449274e-02,  1.08760454e-01],
#         [-4.78543073e-01, -7.21297115e-02,  7.63621703e-02,
#           4.90996987e-02, -1.31418273e-01,  3.13653201e-02,
#          -2.09170394e-02, -1.22637458e-01,  4.08446401e-01,
#          -1.12909012e-01,  2.94681955e-02, -1.20897397e-01,
#          -2.83876896e-01, -1.99660540e-01,  4.65165973e-02,
#           1.10141356e-02, -1.10720947e-01,  8.32488909e-02,
#          -5.82362935e-02, -1.36564493e-01, -2.37415850e-01,
#           3.20343897e-02, -1.99672043e-01, -1.28098339e-01,
#          -7.24351406e-02,  3.41424458e-02,  2.00373113e-01,
#           2.02820122e-01,  1.34845003e-01,  2.17383299e-02],
#         [-1.03788428e-01,  2.36324951e-01, -3.56766313e-01,
#           1.57425240e-01, -6.94302693e-02, -4.03741896e-02,
#          -3.23599696e-01,  1.40950242e-02, -3.31697948e-02,
#           1.78560272e-01,  4.05467898e-02, -1.89331874e-01,
#           3.98579538e-02, -2.71039993e-01, -1.62658364e-01,
#          -7.13330740e-03, -2.40640000e-01,  5.03908135e-02,
#           6.95536509e-02,  2.51123697e-01,  4.62569902e-03,
#           7.15469792e-02,  5.53176031e-02,  3.74059141e-01,
#          -3.61424744e-01, -1.34603143e-01,  3.97969097e-01,
#           8.50359723e-02, -8.03240016e-02,  3.76677848e-02],
#         [ 8.09426904e-02,  1.26390224e-02,  3.98216665e-01,
#          -1.49621785e-01, -9.76332352e-02, -1.19863808e-01,
#          -9.20626000e-02, -4.01237100e-01, -1.77537099e-01,
#           9.10541192e-02,  5.86572699e-02, -2.85199191e-02,
#           1.40847191e-01, -8.81956518e-02, -7.78482407e-02,
#          -1.14331052e-01,  1.66924700e-01, -1.25073299e-01,
#          -1.29558474e-01,  2.87413597e-02, -2.46133372e-01,
#           6.59231395e-02,  1.04280725e-01, -1.54085532e-02,
#           2.33479813e-01, -1.99875813e-02, -1.27966821e-01,
#           1.17004670e-01, -1.26641437e-01, -2.21835077e-02],
#         [-1.50120839e-01, -3.81945521e-02,  1.84107080e-01,
#           2.94731855e-01,  1.93270043e-01, -1.15057215e-01,
#           2.12635882e-02,  6.76847482e-03,  1.44464076e-01,
#          -1.44971803e-01,  4.09164429e-01, -1.94633767e-01,
#           8.26752260e-02,  8.90750587e-02,  1.56147376e-01,
#           5.41016310e-02, -3.79780605e-02,  2.06866294e-01,
#          -3.26302499e-01,  2.53797740e-01,  1.16094714e-02,
#          -5.28945811e-02,  9.28134024e-02, -3.04478198e-01,
#          -1.95655942e-01, -1.89848348e-01,  1.81728229e-01,
#           3.55116248e-01, -2.68271536e-01, -1.40728593e-01],
#         [-2.24254336e-02,  2.14428499e-01, -2.84112394e-01,
#           1.07039720e-01, -1.41065598e-01,  2.03108728e-01,
#           1.64815739e-01,  5.88326752e-02, -1.13612965e-01,
#          -2.89769083e-01, -2.84914583e-01, -9.05657485e-02,
#          -2.01177090e-01,  1.46421254e-01, -1.17357202e-01,
#           1.65756375e-01,  1.13662578e-01,  1.02815129e-01,
#           1.24253809e-01, -1.22498482e-01, -9.93728638e-02,
#           9.76816639e-02, -6.12491257e-02, -6.48081154e-02,
#          -2.30965391e-01,  1.64494470e-01, -2.52865821e-01,
#          -2.47308865e-01,  1.10378958e-01,  4.08728141e-03],
#         [ 1.50133207e-01,  8.49973410e-02, -5.13480566e-02,
#           1.76415797e-02,  8.50448608e-02, -2.71954268e-01,
#           6.62518665e-02,  2.79027641e-01,  1.77766711e-01,
#           1.71915367e-01,  3.05551477e-02, -4.49386984e-02,
#          -1.21931508e-02,  2.69394100e-01, -2.12501675e-01,
#           1.45055249e-01, -1.49320811e-01, -3.66226614e-01,
#          -4.62682694e-02,  3.13553005e-01, -1.28587097e-01,
#          -5.69616780e-02,  1.28562734e-01, -3.11969489e-01,
#          -9.61003080e-02, -2.02194497e-01,  9.66338161e-03,
#           3.78843248e-01, -3.09121728e-01, -1.71740562e-01],
#         [ 2.87489861e-01,  3.57207991e-02, -2.97007471e-01,
#           1.08625829e-01,  1.51763931e-01, -1.35753885e-01,
#          -6.60734922e-02, -1.29544586e-01,  1.23106673e-01,
#          -2.91017741e-01, -1.33148372e-01, -4.45235297e-02,
#          -1.54614940e-01,  1.77780688e-01,  1.24757387e-01,
#           3.36473286e-01, -7.88354501e-02,  2.01139972e-01,
#           1.09437101e-01, -1.45298183e-01, -4.87584434e-02,
#          -1.02684014e-01,  5.46239875e-02,  2.90810633e-02,
#           5.05369296e-03, -1.04714401e-01,  3.21292989e-02,
#          -1.63883890e-03, -2.14354955e-02,  8.50058571e-02],
#         [-4.13592719e-02, -3.10379058e-01, -4.50640451e-03,
#          -2.41578091e-02,  2.17498526e-01, -7.64075071e-02,
#          -1.06558606e-01,  8.23895186e-02, -2.65402734e-01,
#           1.47606894e-01, -4.39726226e-02, -1.92803651e-01,
#           8.43875110e-03,  2.88297445e-01,  5.28099984e-02,
#          -1.53685331e-01,  1.89355284e-01,  6.76262379e-02,
#          -1.28579229e-01, -4.19436634e-01,  2.08552644e-01,
#          -1.50861263e-01,  2.03258678e-01, -1.74721807e-01,
#           1.61971599e-01,  4.05682065e-02, -2.19102308e-01,
#          -2.42233425e-01,  3.10104579e-01,  3.48660976e-01],
#         [-8.72151256e-02,  1.75212882e-02, -3.88402075e-01,
#           2.13242322e-01,  1.49290636e-01, -2.26080958e-02,
#           1.22298658e-01,  1.10351212e-01,  8.45409743e-03,
#           7.24288868e-03, -2.22043116e-02, -2.91033655e-01,
#          -6.32301122e-02, -1.43313989e-01, -3.43235552e-01,
#          -2.09591061e-01, -3.38504165e-02, -2.44801447e-01,
#           5.58428094e-02, -1.77628443e-01,  1.24903679e-01,
#           7.17329187e-03,  2.50455029e-02,  2.09653512e-01,
#          -5.63241402e-03,  9.08356011e-02, -1.44430310e-01,
#           2.40800157e-01,  1.75063536e-01,  1.61171019e-01],
#         [-1.85771361e-01,  1.31941170e-01,  1.75384432e-01,
#           9.00833122e-03, -2.68423408e-02,  3.89133304e-01,
#           2.87952900e-01, -1.81475639e-01, -2.92167753e-01,
#          -1.60215825e-01, -2.80910969e-01, -1.98034942e-01,
#          -3.93178836e-02, -5.51666990e-02, -1.65593684e-01,
#          -1.30135223e-01, -2.48581562e-02, -2.62381822e-01,
#           1.46365732e-01,  6.90173656e-02,  7.69822020e-03,
#           4.40001450e-02, -1.02215089e-01,  3.67687464e-01,
#          -1.58204421e-01, -6.13526106e-02,  1.99995741e-01,
#           3.74597721e-02, -2.13378385e-01, -1.03801355e-01],
#         [ 3.57591182e-01, -6.97063431e-02,  2.77508348e-01,
#          -8.68694931e-02, -2.67450623e-02,  9.56280343e-03,
#           2.31427088e-01, -1.78349361e-01,  1.96547255e-01,
#           1.13417790e-03, -1.17863677e-01, -4.82302196e-02,
#           4.27396774e-01, -3.08533520e-01, -6.65334836e-02,
#           1.64277777e-01,  3.83593112e-01, -5.19223586e-02,
#           1.79931700e-01, -3.36645581e-02,  1.09638073e-01,
#           1.37394533e-01, -2.57064402e-02, -1.80573508e-01,
#          -1.18901931e-01, -8.24405923e-02,  2.66345460e-02,
#          -1.93680540e-01, -1.79528281e-01, -4.01087731e-01],
#         [ 2.58254826e-01,  2.13920876e-01, -5.31402268e-02,
#          -1.80393428e-01, -1.92823738e-01,  1.48114175e-01,
#           4.28910226e-01, -2.10819870e-01,  2.51297140e-03,
#           1.39648259e-01,  3.78680117e-02, -1.50324017e-01,
#          -8.59132707e-02,  3.50711852e-01,  1.48306638e-01,
#           1.64901063e-01, -4.59516682e-02,  1.38643369e-01,
#          -2.52362818e-01,  9.85103995e-02,  1.66569233e-01,
#          -8.03198945e-03, -3.22796851e-02, -1.95151970e-01,
#           1.17838532e-01,  6.35253489e-02,  2.93815166e-01,
#           1.44703805e-01,  1.97865024e-01,  1.03422664e-01],
#         [-3.58410716e-01, -1.65811166e-01,  6.70884922e-02,
#           9.22731310e-02, -1.17276773e-01,  3.92122753e-02,
#           9.29919779e-02,  8.82963836e-02,  1.39013439e-01,
#          -4.78769802e-02, -1.90627605e-01, -7.23028556e-02,
#          -1.32796660e-01,  8.96755755e-02,  5.04185520e-02,
#           3.12902391e-01, -7.31186010e-03,  1.64008722e-01,
#           1.41641676e-01,  6.12286665e-03,  3.58393714e-02,
#          -1.30401418e-01, -2.14391365e-03,  4.55537029e-02,
#           1.53030679e-01, -1.15913659e-01,  1.32338926e-01,
#          -8.42612907e-02, -6.04700781e-02, -2.34609708e-01]], dtype=float32)>,
#  'denses.2.bias': <tf.Variable 'fnn/dense_2/bias:0' shape=(30,) dtype=float32, numpy=
#  array([ 0.02144715, -0.01898668, -0.03757823, -0.00356767, -0.020596  ,
#          0.00410272, -0.02096981,  0.02011034,  0.00491224,  0.00850066,
#         -0.03549714,  0.00573078, -0.04435427, -0.01478845,  0.00485102,
#         -0.03810437, -0.02230358, -0.02980309,  0.04419532,  0.00768718,
#          0.01803002,  0.03671833,  0.01075874,  0.02134374, -0.03478903,
#          0.0236485 ,  0.04369327,  0.04516869, -0.01239076, -0.00433268],
#        dtype=float32)>,
#  'denses.3.kernel': <tf.Variable 'fnn/dense_3/kernel:0' shape=(30, 30) dtype=float32, numpy=
#  array([[ 2.04158612e-02, -1.43343776e-01,  1.77140474e-01,
#          -1.53201953e-01, -1.73715398e-01, -9.61589739e-02,
#          -1.84061378e-02,  1.25243872e-01, -6.58659171e-03,
#          -2.86285371e-01,  3.78147244e-01, -2.80251324e-01,
#           5.66225126e-02,  1.59195855e-01, -4.11491729e-02,
#          -1.21089630e-01, -4.15496528e-02, -1.35132521e-01,
#          -3.63113694e-02, -4.68393192e-02,  5.43012023e-02,
#          -2.89562019e-03, -9.85770524e-02,  2.46234387e-01,
#           1.80483311e-01,  2.17550874e-01,  6.39976785e-02,
#           9.44966674e-02,  4.85334657e-02, -2.68241823e-01],
#         [-1.36499573e-02,  3.27790044e-02,  3.91054377e-02,
#          -1.55066490e-01, -4.86829914e-02, -3.90817523e-02,
#          -1.99357808e-01, -1.56434953e-01, -1.02118671e-01,
#          -1.91008121e-01,  2.69421369e-01,  3.14589292e-02,
#           1.07201062e-01,  2.75369585e-01,  1.48704275e-01,
#          -8.16733688e-02,  9.66715589e-02, -6.13017306e-02,
#           1.44143835e-01, -6.53516650e-02,  5.82304411e-02,
#           1.35055214e-01, -2.68566906e-01, -9.51582044e-02,
#          -1.61034271e-01, -6.89207539e-02,  4.66904640e-02,
#           7.13493791e-04, -2.86751926e-01,  7.06758127e-02],
#         [ 1.69735417e-01,  6.81831390e-02,  3.86665434e-01,
#          -1.17605347e-02, -6.60222620e-02,  2.09562123e-01,
#           2.05879316e-01, -5.86008094e-02,  1.07132576e-01,
#          -3.07671636e-01, -5.49584441e-02, -7.54952878e-02,
#          -3.99037659e-01, -1.21947773e-01, -2.34199073e-02,
#          -1.08981244e-01,  1.40983954e-01, -1.12419605e-01,
#          -3.99264097e-01,  6.76724166e-02, -2.83132225e-01,
#          -8.33226442e-02,  2.17323005e-01,  6.67790249e-02,
#           4.51999247e-01, -2.12812684e-02,  2.80752569e-01,
#           5.58044529e-03,  1.86835989e-01,  1.04642501e-02],
#         [-2.39594076e-02,  1.38581008e-01, -1.23910166e-01,
#          -2.55091459e-01, -1.15008280e-01, -7.67474622e-02,
#          -2.25576013e-01,  4.34085540e-02,  2.30241045e-01,
#          -4.01378646e-02, -1.11826472e-02, -7.44551569e-02,
#           1.93246335e-01,  2.77551323e-01, -2.47362349e-02,
#          -3.16576689e-01,  4.23194915e-02, -1.05381504e-01,
#          -1.72613859e-01,  4.04480798e-03, -7.79492632e-02,
#          -3.14870700e-02, -4.06353213e-02,  2.67528027e-01,
#           2.50026137e-01,  1.20189965e-01,  1.06341027e-01,
#           1.83710873e-01, -1.19692720e-01,  1.86874811e-02],
#         [-4.05213907e-02, -2.96444893e-01, -3.72112282e-02,
#           1.22171447e-01, -3.11738253e-01, -1.17253833e-01,
#           3.32160071e-02, -3.41253817e-01, -5.87427989e-02,
#           8.36861953e-02,  3.19242068e-02, -1.82728335e-01,
#          -1.92274183e-01,  2.18158975e-01,  2.00026542e-01,
#          -2.62632340e-01,  6.42035529e-02,  7.73450127e-03,
#           1.52389750e-01, -3.88971448e-01, -5.23987599e-02,
#          -1.37984771e-02,  1.43052757e-01,  1.77567124e-01,
#          -5.24570160e-02, -8.17361102e-02,  1.90564811e-01,
#          -5.09718657e-02,  2.56257534e-01,  2.57198494e-02],
#         [-1.59776554e-01, -2.92427778e-01,  9.08048172e-03,
#           3.43093392e-03,  3.00249010e-01,  8.62884521e-02,
#          -3.50504786e-01,  9.52023566e-02,  3.30550969e-02,
#          -1.37748659e-01,  5.45945168e-02, -1.67635992e-01,
#           1.94022328e-01,  2.56514195e-02,  1.29023790e-01,
#          -1.49231806e-01, -1.72163382e-01,  4.25412413e-03,
#          -1.53744355e-01,  1.39740929e-01,  7.74510503e-02,
#           9.19506475e-02, -2.81747788e-01,  3.02096009e-01,
#           2.96033382e-01, -6.75084665e-02,  7.58432895e-02,
#          -1.44197838e-02,  2.08030734e-03, -6.02855049e-02],
#         [ 1.59498125e-01,  8.91595110e-02,  3.32955969e-04,
#          -3.14222462e-02, -1.68221995e-01,  1.88076362e-01,
#          -2.34226018e-01, -9.99672785e-02, -9.08502117e-02,
#          -9.89010036e-02,  5.71348853e-02,  1.50384411e-01,
#          -8.80282819e-02,  1.05887651e-01, -4.43213545e-02,
#           3.09368461e-01, -1.85509957e-02,  2.41916142e-02,
#           1.72101378e-01, -1.73828036e-01,  2.16102675e-01,
#           1.52111471e-01, -3.66718739e-01,  2.04745680e-01,
#           2.26498768e-01,  1.50267005e-01,  2.13722661e-01,
#          -1.95965618e-01,  3.22021097e-01,  2.07711309e-02],
#         [-2.48537913e-01, -3.36767137e-02, -4.33322750e-02,
#           1.68759808e-01, -1.85357362e-01, -1.93188665e-03,
#           1.70242026e-01, -2.35950388e-02,  3.74694943e-01,
#          -4.82879812e-03,  2.27861390e-01, -1.75557092e-01,
#           1.29988134e-01,  1.46006551e-02, -3.47578108e-01,
#          -1.64225146e-01, -1.70242518e-01, -1.28804430e-01,
#           1.50988847e-01, -4.88650575e-02, -3.11592110e-02,
#           1.06893644e-01,  3.61313641e-01, -3.22784320e-03,
#           6.05529100e-02,  2.02416867e-01, -6.85637966e-02,
#          -4.05428074e-02, -1.42778128e-01, -2.79098712e-02],
#         [-3.51907223e-01, -3.82429212e-02, -1.77031875e-01,
#           6.90465346e-02, -6.64576609e-03,  2.57851463e-02,
#          -2.51744688e-01,  2.06343606e-02,  1.92446947e-01,
#          -9.32421535e-02,  2.52517551e-01,  2.01497152e-02,
#           1.89478677e-02, -2.62119383e-01,  2.79459774e-01,
#          -1.71167567e-01, -1.11369081e-02, -2.75570989e-01,
#           2.32229754e-01,  1.58393741e-01,  4.35843840e-02,
#           5.78909814e-02, -2.34426513e-01, -7.07135827e-04,
#           7.03299046e-02,  2.49646664e-01,  3.73813882e-02,
#           1.48737729e-01, -1.01083204e-01, -1.48743302e-01],
#         [ 6.74889460e-02, -1.42772019e-01,  2.46217474e-01,
#          -1.05200946e-01, -3.64275202e-02,  1.71616510e-01,
#          -1.46734953e-01, -5.90836024e-03, -2.22703174e-01,
#          -2.04901993e-01,  1.66694775e-01, -9.19761583e-02,
#           3.65657322e-02, -3.87623198e-02,  9.49546024e-02,
#          -1.30345315e-01,  9.41520557e-02,  7.17634112e-02,
#          -1.54903084e-01, -1.01535425e-01,  1.24622501e-01,
#           2.53913134e-01,  2.71218926e-01,  1.86586231e-01,
#           1.62018351e-02,  1.28093883e-01,  2.48259827e-02,
#           2.87430882e-01,  6.69250414e-02,  3.04205179e-01],
#         [ 2.62059481e-03,  1.44058978e-02,  1.60993338e-02,
#          -2.85015076e-01,  1.33896217e-01,  9.53174457e-02,
#           3.68502326e-02,  3.98605131e-02, -2.41651386e-02,
#          -1.10822201e-01,  2.66249418e-01,  1.40665546e-01,
#           1.04282267e-01, -1.75425764e-02, -7.77974948e-02,
#          -1.86637789e-01,  1.41332954e-01,  5.79348989e-02,
#          -7.26324618e-02,  3.28367740e-01, -1.76084265e-01,
#           2.58653592e-02,  3.90262216e-01,  1.25990480e-01,
#          -2.45777592e-01, -2.27022141e-01, -3.74255106e-02,
#          -2.32826337e-01,  1.53472841e-01,  2.40298182e-01],
#         [-1.35450020e-01, -3.03993374e-01, -1.64952710e-01,
#           1.64443552e-01,  1.50205582e-01, -2.24223539e-01,
#           1.23999737e-01, -5.67188933e-02,  1.08296622e-03,
#           6.93482831e-02, -9.21515673e-02, -1.95096195e-01,
#          -3.08613539e-01,  2.14668751e-01,  1.01539209e-01,
#           8.25675577e-02, -2.67481089e-01,  3.14205259e-01,
#           1.97856650e-01, -2.92054921e-01,  1.81850210e-01,
#           1.68249786e-01,  1.36303723e-01,  3.50835532e-01,
#           2.89277554e-01, -2.77582318e-01, -1.82970583e-01,
#          -2.61965632e-01,  1.73123494e-01, -1.17995158e-01],
#         [ 2.52579302e-01, -7.11340234e-02,  1.91381693e-01,
#          -1.93401769e-01,  1.23266429e-01,  5.50469048e-02,
#          -1.72219634e-01, -2.29197256e-02,  1.05236866e-01,
#           1.03004664e-01,  1.33452430e-01,  3.08325682e-02,
#           1.43396154e-01,  2.57211357e-01,  7.34097809e-02,
#          -2.03751966e-01, -1.20401561e-01,  1.15503208e-03,
#           5.13803512e-02,  8.26896355e-02, -3.86589058e-02,
#           8.47510472e-02, -2.27779433e-01,  1.32713675e-01,
#           1.89267159e-01,  1.20240688e-01,  1.69963658e-01,
#          -2.76552234e-02, -9.77833103e-03,  1.17665902e-01],
#         [-1.25923962e-03, -3.76682699e-01,  1.70006111e-01,
#          -3.58338207e-01,  3.26416284e-01,  4.90715466e-02,
#           5.08413352e-02, -5.71399294e-02,  1.50946572e-01,
#           2.14150492e-02, -5.72410077e-02,  3.29494894e-01,
#          -1.38299972e-01,  1.81872565e-02,  9.92774591e-02,
#          -1.09121285e-01, -6.80576786e-02, -1.48300035e-02,
#          -4.35219891e-02, -2.51899779e-01, -1.70301914e-01,
#          -1.81004435e-01, -2.11406704e-02, -1.19714625e-01,
#           1.89276859e-01,  8.48042294e-02, -1.82762906e-01,
#           2.55865976e-02, -3.14580977e-01, -8.40801001e-02],
#         [-1.96219720e-02, -7.11007714e-02,  8.35617706e-02,
#           1.87693596e-01, -1.20770968e-01,  2.53580868e-01,
#          -1.43255144e-01, -1.80751085e-01, -7.46968389e-02,
#          -6.16818666e-02, -1.64568856e-01,  6.61979839e-02,
#          -2.48070359e-01,  5.01465946e-02, -8.65296051e-02,
#           2.33430415e-01,  3.62225801e-01,  1.62744910e-01,
#          -3.36017072e-01,  1.08596161e-01,  6.84543997e-02,
#          -1.80566385e-01,  1.83232993e-01,  1.57437265e-01,
#          -8.66107717e-02, -2.40730897e-01,  2.05123480e-02,
#           3.32376100e-02,  1.27064630e-01, -3.37625593e-01],
#         [-1.59529835e-01,  6.62816986e-02,  1.64718121e-01,
#           3.32286447e-01,  6.50416687e-02,  1.06112644e-01,
#           1.56812981e-01, -1.65810034e-01, -3.61897439e-01,
# ...
#           3.33815278e-03, -5.89984991e-02,  4.09168564e-02,
#           4.83867019e-01, -3.23020816e-02,  1.66601896e-01,
#           6.71015739e-01,  5.02003014e-01],
#         [ 3.38013083e-01, -8.65487680e-02,  2.76883543e-01,
#          -8.24811161e-02, -6.22496456e-02,  1.41974616e+00,
#           7.13162899e-01, -1.20576650e-01,  2.91975856e-01,
#          -1.73917338e-01, -4.71910924e-01, -2.04814389e-01,
#           4.15200084e-01,  1.46205652e+00,  3.32924008e-01,
#          -5.85106015e-03,  5.98559491e-02,  2.97209859e-01,
#           1.40772909e-01, -1.80280693e-02,  1.34350702e-01,
#          -1.42248660e-01,  9.92763117e-02, -4.19869944e-02,
#          -8.44414383e-02,  1.11366294e-01],
#         [-1.46441662e+00, -7.92241395e-01,  1.19440429e-01,
#           1.52500629e-01,  7.93742537e-02, -1.33411779e+01,
#          -3.81574607e+00,  4.60450277e-02, -2.49119490e-01,
#          -1.98044527e+00, -6.90962672e-02, -2.36498727e-03,
#          -4.66898298e+00, -7.01451397e+00,  1.99618861e-01,
#          -4.71175201e-02,  1.61668241e-01, -2.91973233e-01,
#          -8.41973126e-02, -1.20346799e-01, -3.57295394e-01,
#          -1.13281399e-01, -2.70377509e-02, -1.20416276e-01,
#           7.37853944e-01, -1.11456802e-02],
#         [ 4.93798780e+00,  6.57978725e+00,  3.29147863e+00,
#          -5.79438508e-01,  1.64641008e-01,  1.79563503e+01,
#           9.78754044e+00, -1.67619333e-01,  3.59340334e+00,
#          -1.06866379e+01,  6.26416445e+00,  6.86055645e-02,
#           1.06002836e+01,  9.95365047e+00, -4.37753312e-02,
#          -2.55980372e-01, -8.62758160e-02, -1.09762691e-01,
#          -1.07856534e-01, -1.01494957e-02,  2.70976782e-01,
#          -2.64872193e-01,  3.66805308e-02,  4.54928800e-02,
#          -1.33016276e+00, -4.33296412e-01],
#         [-1.97122544e-01, -6.86613023e-01,  2.70292222e-01,
#          -1.49101451e-01, -2.45678976e-01, -2.30435896e+00,
#           1.95320976e+00, -3.35595280e-01, -6.12996459e-01,
#           1.66243041e+00, -1.20564127e+00,  7.06894249e-02,
#           1.92092490e+00,  4.12711525e+00, -1.69357527e-02,
#          -4.38500009e-02,  2.98611820e-02, -2.24703625e-01,
#          -7.70359486e-02,  4.48881984e-02, -2.73642302e-01,
#          -2.18244985e-01,  7.15787942e-03, -4.31087434e-01,
#          -3.55502427e-01, -4.79296297e-02],
#         [-5.95771015e-01, -8.29407513e-01, -7.31050372e-01,
#           1.60648212e-01,  1.51727378e-01, -4.16399384e+00,
#          -1.40795839e+00, -7.56629556e-03, -5.10197639e-01,
#           6.01633263e+00, -1.59349859e+00,  1.52323823e-02,
#           1.14029968e+00,  1.55736756e+00, -1.12172350e-01,
#          -8.10882449e-02,  2.18416169e-01,  6.36174679e-02,
#           2.12395579e-01, -5.71962968e-02, -1.65914461e-01,
#          -3.47017795e-01,  5.45682712e-03, -7.50398217e-03,
#           2.49180019e-01,  5.19541875e-02],
#         [-1.30525544e-01,  1.33793223e+00, -2.99725562e-01,
#          -2.64204890e-01,  2.86090896e-02,  2.36991882e+00,
#           2.08256197e+00,  1.45734735e-02,  3.19254756e-01,
#          -5.97397232e+00,  1.05994368e+00,  1.37512311e-02,
#           1.83318508e+00,  2.08144855e+00,  1.01216562e-01,
#           6.83494136e-02, -2.26240784e-01,  3.57466251e-01,
#           2.69690633e-01, -1.37859985e-01,  3.83192822e-02,
#           5.63029572e-02, -1.64237060e-02, -6.90627620e-02,
#          -8.47278535e-02,  8.92976522e-02],
#         [-5.63243866e-01,  4.17586178e-01, -5.44700444e-01,
#           3.15707684e-01, -1.80562735e-01, -1.41194546e+00,
#           2.87240833e-01, -4.06722389e-02,  1.06535316e+00,
#          -6.85256147e+00,  5.91545105e-01,  5.89455962e-02,
#          -4.59068680e+00, -5.67086172e+00, -1.49392420e-02,
#           3.60922404e-02,  1.99300095e-01, -1.91038296e-01,
#           2.23431498e-01,  2.20254630e-01, -3.16655517e-01,
#           3.67153376e-01,  1.84780240e-01,  1.63420767e-01,
#           4.64275926e-01, -5.24716787e-02],
#         [ 2.03294492e+00,  1.96299541e+00,  2.54301929e+00,
#          -4.92429674e-01, -1.25317603e-01,  1.61484032e+01,
#           3.80788040e+00, -1.29903361e-01,  2.24623203e-01,
#          -9.34847355e-01,  6.27627659e+00,  5.32930754e-02,
#           5.39301252e+00,  4.26935768e+00,  6.93133175e-02,
#          -1.00281788e-02, -2.88958907e-01, -1.95315182e-01,
#          -1.24054819e-01, -1.61559790e-01,  1.42479628e-01,
#           5.68686351e-02, -6.45999238e-02,  9.46016610e-02,
#           3.44851255e-01, -1.53326273e-01],
#         [-4.10377160e-02, -4.75296831e+00, -8.84400532e-02,
#           5.20124733e-01,  1.32993102e-01, -1.74343739e+01,
#          -3.07363629e+00, -1.86654925e-01, -6.32709920e-01,
#          -3.44915462e+00,  1.68897748e-01,  5.52850738e-02,
#          -4.06563234e+00, -6.93076372e+00, -7.87265599e-03,
#          -5.83902448e-02,  1.47811577e-01, -8.53271261e-02,
#          -1.10464450e-02, -2.02500373e-01,  1.32197544e-01,
#           1.37482941e-01, -4.87441989e-03, -9.06496421e-02,
#           6.81861937e-01,  3.25625032e-01],
#         [-1.47498846e-01, -1.68680493e-02,  2.62209028e-01,
#           7.77440071e-02,  1.45899832e-01, -2.08407968e-01,
#           3.98596749e-04,  1.80068001e-01,  6.77675247e-01,
#          -2.50420213e+00,  3.44498426e-01, -1.00090705e-01,
#          -1.68635511e+00, -3.85756779e+00, -3.11108977e-02,
#           1.75622314e-01, -1.75210059e-01, -6.76796958e-02,
#          -2.78852105e-01, -1.08331420e-01,  1.98119789e-01,
#           4.18602079e-02, -4.83904220e-02, -4.05433029e-02,
#           3.02614450e-01, -1.73815593e-01],
#         [-3.59607413e-02, -2.30609989e+00,  1.03981507e+00,
#           1.84871435e-01, -2.60558426e-01, -1.04939613e+01,
#          -6.51727915e-01, -1.03731103e-01, -5.44954121e-01,
#          -4.71103859e+00,  3.59976321e-01,  1.26895413e-01,
#          -3.12005019e+00, -3.72076368e+00,  6.95667416e-03,
#          -4.65525299e-01, -2.24657416e-01, -8.70617107e-02,
#           8.25550966e-03, -3.03137787e-02, -3.60312723e-02,
#           3.84813219e-01,  1.27609894e-01, -9.96131599e-02,
#           1.38034248e+00,  3.67794156e-01],
#         [ 7.43793130e-01, -4.50906605e-01, -1.22198924e-01,
#          -1.69324353e-01,  1.15493208e-01,  3.29448652e+00,
#           2.21727633e+00,  3.69755358e-01, -5.57171226e-01,
#           1.02746172e+01, -1.90677059e+00,  1.33051917e-01,
#           4.53789043e+00,  4.98648071e+00, -1.82807539e-02,
#          -3.87625128e-01,  1.59427702e-01,  2.31618524e-01,
#          -1.31741837e-01, -2.26447985e-01, -2.14158952e-01,
#          -2.07980815e-02,  1.15657240e-01, -2.07487002e-01,
#          -7.01069713e-01, -1.54781431e-01],
#         [ 7.79130697e-01,  9.03715491e-01, -9.08096850e-01,
#          -3.63046706e-01, -1.16144232e-01,  5.49960375e-01,
#           5.94128788e-01,  1.47421777e-01,  9.04130042e-02,
#           1.25588751e+00, -9.85525548e-02, -2.62178510e-01,
#           2.84010434e+00,  3.46158600e+00,  1.70300618e-01,
#           4.57697451e-01,  2.92897075e-01, -3.01721632e-01,
#          -1.67842045e-01, -1.22631244e-01,  1.69716522e-01,
#          -1.15280256e-01,  3.10777426e-01, -2.47053225e-02,
#          -2.22531423e-01, -1.53207242e-01],
#         [-1.85696304e-01, -8.06160033e-01,  1.44885480e-01,
#           1.26532058e-03,  5.30834123e-02, -2.54416800e+00,
#          -2.56408429e+00, -6.38764501e-02, -5.72750926e-01,
#           4.99717569e+00,  6.89162232e-04, -2.63782173e-01,
#          -4.37734175e+00, -3.48684287e+00,  1.87336951e-02,
#           9.59286615e-02,  3.50931007e-03,  1.01339579e-01,
#          -2.15215355e-01,  1.49812698e-01,  2.09055379e-01,
#           1.51236862e-01,  1.89480722e-01, -1.26809865e-01,
#           6.64615393e-01,  3.12676311e-01],
#         [-2.01390266e+00,  1.26937914e+00, -2.61674619e+00,
#          -1.12127803e-01,  1.58879936e-01, -6.38940048e+00,
#          -7.09979415e-01,  2.04783827e-01,  3.66254544e+00,
#          -9.21818066e+00,  2.41658163e+00,  4.14321363e-01,
#          -5.36761141e+00, -5.74906492e+00,  1.25181777e-02,
#          -6.39281631e-01, -2.09131837e-01,  5.88821992e-02,
#           1.73990820e-02, -8.62502530e-02, -1.35789007e-01,
#           2.48355150e-01,  1.28236860e-01, -1.25829503e-02,
#           9.84904230e-01,  8.14055383e-01],
#         [-1.40389800e+00, -1.52448261e+00, -3.19616020e-01,
#           2.90880240e-02, -5.15316315e-02, -9.75806618e+00,
#          -2.62366557e+00,  1.33318394e-01, -1.36616731e+00,
#           7.49101210e+00, -2.23750138e+00, -1.86057866e-01,
#          -2.02109963e-01,  9.89436448e-01, -1.55165046e-01,
#           2.53429618e-02, -2.24244297e-01,  5.76721206e-02,
#          -7.70555884e-02,  2.10046768e-01,  3.81033152e-01,
#           1.69340506e-01, -3.41016501e-01,  7.93451592e-02,
#           2.77414531e-01, -1.60554647e-01],
#         [-3.91456991e-01, -2.34362986e-02, -1.53073215e+00,
#          -2.52235681e-01, -6.70335367e-02, -7.49407387e+00,
#          -1.88203931e+00, -4.52739596e-01, -1.22171223e+00,
#           1.99172366e+00, -2.99124169e+00,  3.88543755e-01,
#          -4.70810056e-01,  2.12687755e+00,  1.36175662e-01,
#          -2.40282923e-01, -3.25605273e-01, -3.02307494e-02,
#          -1.35437146e-01, -6.64186403e-02,  1.76454768e-01,
#          -1.36330053e-01, -2.51116961e-01, -1.71714187e-01,
#          -4.48193938e-01, -1.97234631e-01],
#         [ 4.76526588e-01,  6.52455628e-01,  3.26914966e-01,
#          -4.20034975e-01, -1.96638271e-01,  5.70075703e+00,
#           2.39738894e+00, -2.30285838e-01,  3.51275504e-01,
#          -9.34287608e-01,  1.13451727e-01,  4.48447466e-02,
#           4.16259289e+00,  3.89347982e+00,  8.46675113e-02,
#          -2.38574401e-01, -1.11476995e-01,  2.30332613e-01,
#           1.00171916e-01,  4.89119329e-02, -1.76224522e-02,
#          -9.68907773e-02, -1.13910832e-01, -5.09310775e-02,
#          -4.09220695e-01,  3.26438963e-01],
#         [ 9.81037766e-02, -1.68405402e+00,  1.55779076e+00,
#          -1.85359672e-01, -3.64451110e-01,  5.26638508e-01,
#           1.47179753e-01, -3.15398425e-02, -1.54538304e-01,
#           7.33988476e+00, -3.77055317e-01,  4.42934707e-02,
#          -1.19612291e-02, -8.81795108e-01,  5.46071157e-02,
#           6.61363751e-02, -4.62506860e-01,  2.00890414e-02,
#           1.03656597e-01,  1.51322484e-01, -8.07972327e-02,
#           1.17187224e-01,  3.23381692e-01, -1.63690336e-02,
#           6.55014217e-01, -1.34507090e-01],
#         [-3.65535617e-01, -5.07726192e-01, -1.01045859e+00,
#          -2.69512266e-01,  1.08743355e-01, -1.01499462e+01,
#          -8.06156397e-01,  5.04136197e-02, -2.56827563e-01,
#          -7.00804424e+00, -9.08889890e-01,  2.61104070e-02,
#          -1.42131412e+00, -3.54065704e+00, -2.24211048e-02,
#           2.24681105e-02,  1.52274281e-01,  3.64582419e-01,
#           2.35586494e-01,  1.25606939e-01, -1.42401919e-01,
#           1.41689822e-01, -2.90454745e-01,  1.88142210e-01,
#          -6.68648630e-02, -1.45089626e-01],
#         [-1.50911152e+00, -9.21023667e-01, -9.27754045e-01,
#           2.59284467e-01,  1.10644735e-01, -7.78969479e+00,
#          -1.91634679e+00, -2.72730470e-01,  1.14472069e-01,
#           2.96081018e+00, -2.18054867e+00,  1.21363081e-01,
#          -5.25760651e+00, -4.83024359e+00,  8.54036398e-03,
#           9.09111649e-02,  5.73948994e-02,  3.36306036e-01,
#          -3.14146876e-01, -9.46662053e-02,  3.88609022e-01,
#           1.06734306e-01, -9.02708620e-02,  5.91774695e-02,
#           3.65894258e-01,  1.86706319e-01],
#         [ 4.37564790e-01, -6.69259906e-01, -1.67408228e-01,
#          -2.22096860e-01, -1.19836032e-01, -1.42185509e+00,
#           8.31816852e-01,  6.06868882e-03, -5.35161853e-01,
#           5.50197315e+00, -1.45255733e+00, -8.40838104e-02,
#           3.11109209e+00,  1.94061935e+00,  1.61305279e-01,
#          -2.20238835e-01, -1.54487073e-01,  7.89894462e-02,
#          -2.73181260e-01,  9.72813070e-02,  8.01308379e-02,
#          -1.28404915e-01,  3.13651145e-01, -7.40088448e-02,
#          -5.73359728e-01,  9.92519408e-02],
#         [-5.64953029e-01, -5.79506159e-01,  1.52333125e-01,
#           2.77859032e-01,  2.24696964e-01,  6.64621067e+00,
#          -3.96258116e+00, -1.05606996e-01, -8.24234307e-01,
#           9.27247334e+00, -1.92158771e+00, -1.83966950e-01,
#          -1.59817612e+00,  5.31083047e-01,  3.66953434e-03,
#           3.14764023e-01,  2.54498601e-01,  5.02725616e-02,
#           4.26070904e-03,  2.70006746e-01, -5.55411577e-02,
#           4.87224489e-01,  5.26706092e-02, -1.67966150e-02,
#           1.41039181e+00,  3.18226576e-01],
#         [-6.23601377e-02,  3.08787934e-02,  1.01709999e-01,
#           4.70265090e-01, -2.97425508e-01,  1.92884123e+00,
#           1.83281136e+00,  1.82349682e-01, -2.35494182e-01,
#          -7.35015345e+00,  1.52319431e+00,  1.63617179e-01,
#          -9.56711590e-01, -2.05892777e+00, -1.76859707e-01,
#          -3.30688804e-01, -1.84477583e-01, -8.12588483e-02,
#          -1.65345624e-01,  1.16110556e-01, -2.73061227e-02,
#           2.67869204e-01,  1.60214037e-01,  7.91387260e-02,
#           3.74812633e-01, -2.77915299e-01],
#         [-5.23965502e+00, -2.37820983e+00, -2.52637863e+00,
#           7.04208672e-01, -2.15615287e-01, -1.45516777e+01,
#          -1.36808834e+01, -3.02269936e-01, -8.53045881e-01,
#           9.92801952e+00, -3.44594383e+00,  2.51348317e-01,
#          -6.35751915e+00, -9.13030148e+00,  6.91416189e-02,
#           3.60621363e-01, -5.86078651e-02,  1.55463204e-01,
#           3.08615956e-02,  2.13548005e-01,  8.00614804e-02,
#           3.03401083e-01,  2.38749921e-01,  3.45164746e-01,
#           1.49520993e+00,  7.77464449e-01],
#         [ 5.70420742e-01, -2.77490467e-01,  1.50883687e+00,
#           1.23839878e-01, -1.89002559e-01,  9.46290302e+00,
#           9.89678741e-01, -3.97791713e-01, -5.22292018e-01,
#           7.18405962e+00,  1.84536886e+00,  3.37779015e-01,
#           2.46048331e+00,  2.99934626e+00,  2.30299115e-01,
#           3.72276828e-02, -3.65154356e-01,  1.19224302e-01,
#           1.15882039e-01, -2.34320983e-01, -1.30084455e-01,
#          -1.42229065e-01,  2.10143447e-01, -2.14276329e-01,
#          -8.29182118e-02, -1.37086630e-01],
#         [-1.49654639e+00,  8.86002034e-02, -6.07168615e-01,
#           1.63897481e-02, -4.32205416e-05, -5.05857706e+00,
#          -4.92983198e+00,  7.59929568e-02,  2.04100180e+00,
#          -8.42013645e+00,  2.99368262e+00,  1.59104228e-01,
#          -4.25137949e+00, -6.38323689e+00,  2.84887245e-03,
#           4.86242890e-01,  5.48552126e-02,  1.18175834e-01,
#           1.55557217e-02, -3.22161704e-01,  3.59758213e-02,
#          -8.44917968e-02,  1.61260262e-01, -2.73131463e-03,
#           1.36052024e+00,  4.55652922e-01],
#         [-5.16920447e-01,  6.64707661e-01, -1.96904615e-01,
#          -1.84741728e-02, -8.51372182e-02,  1.07734430e+00,
#           1.78951454e+00, -2.73983926e-01,  2.09754258e-01,
#          -9.98365974e+00,  1.43020582e+00, -4.07706469e-01,
#          -1.44017398e+00, -4.89487290e-01,  2.00403407e-01,
#          -2.16105491e-01,  1.53573081e-01,  8.01214129e-02,
#          -1.70549914e-01, -2.49793753e-01,  3.05668950e-01,
#           4.50480521e-01, -8.78772885e-02,  4.03445922e-02,
#          -8.16198438e-02,  2.00161293e-01],
#         [ 8.98897946e-01, -3.46782476e-01,  6.02360740e-02,
#          -3.27621192e-01, -7.50883743e-02,  9.58243752e+00,
#           7.51101553e-01, -2.22244412e-01, -5.23015976e-01,
#           1.30805645e+01, -2.57289815e+00, -2.03608215e-01,
#           2.89934802e+00,  4.81256723e+00,  2.09122873e-03,
#          -1.08612947e-01,  8.57575014e-02, -1.68690551e-02,
#          -1.18200236e-03,  2.06485078e-01,  2.24486794e-02,
#          -1.06210768e-01, -1.89140722e-01,  2.26978675e-01,
#          -2.80188233e-01,  4.16707434e-02]], dtype=float32)>,
#  'denses.5.bias': <tf.Variable 'fnn/dense_5/bias:0' shape=(26,) dtype=float32, numpy=
#  array([-5.0694025e-01,  2.0892723e+00, -1.5712838e+00,  1.5812854e-01,
#         -6.0394194e-02,  4.9632797e-01, -7.2602969e-01,  8.4106466e-03,
#         -3.2852048e-01, -9.8097754e+00,  3.7325640e+00, -5.3979559e-03,
#          6.5004021e-01,  8.9430654e-01, -2.3793785e-03, -6.4202085e-02,
#         -1.8027782e-02, -3.1673741e-02,  9.8664844e-03,  7.1004800e-02,
#         -2.6267711e-03,  1.0031597e-02, -2.1741882e-02,  1.3393785e-02,
#          1.6566691e-01, -1.2261815e-02], dtype=float32)>}

# %%
model.predict(time_points)
# Out:
# array([[ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00],
#        [ 7.65911400e-01,  1.55396330e+00,  3.23631912e-01,
#          1.03248067e-01, -9.24383290e-03,  1.45467987e+01,
#          1.42245686e+00,  4.10057485e-01,  3.22253513e+00,
#          3.60449314e+00,  1.51545322e+00,  1.59028992e-02,
#          1.43546253e-01, -1.35879850e+00,  3.56733464e-02,
#          5.85698426e-01,  2.45571852e-01,  6.93741888e-02,
#          1.78503394e-02,  1.05106823e-01,  1.74745694e-02,
#          1.74460299e-02,  1.55832246e-01,  1.56251535e-01,
#          1.46777868e-01,  1.55013055e-02],
#        [ 8.37765872e-01,  1.63898146e+00,  3.57398659e-01,
#          8.76924172e-02, -8.14972259e-03,  1.50646248e+01,
#          1.54221117e+00,  4.06553864e-01,  3.25895882e+00,
#          3.55657864e+00,  1.61308777e+00,  1.75807774e-02,
#          2.59279907e-01, -1.20830691e+00,  3.57662216e-02,
#          5.83523095e-01,  2.47261584e-01,  6.95392638e-02,
#          1.78977735e-02,  1.04629286e-01,  1.75263453e-02,
#          1.25099355e-02,  1.56257048e-01,  1.56715229e-01,
#          1.38334185e-01,  1.53263435e-02],
#        [ 8.48568499e-01,  1.64654076e+00,  3.65220577e-01,
#          8.56047645e-02, -8.25788639e-03,  1.51175776e+01,
#          1.56250751e+00,  4.06018227e-01,  3.26265287e+00,
#          3.55022049e+00,  1.62891757e+00,  1.82064474e-02,
#          2.79116362e-01, -1.18873656e+00,  3.57199982e-02,
#          5.82460463e-01,  2.46654093e-01,  6.94969296e-02,
#          1.78827308e-02,  1.04301564e-01,  1.74956210e-02,
#          1.15384553e-02,  1.56085536e-01,  1.56534225e-01,
#          1.36442170e-01,  1.48763303e-02],
#        [ 8.50084484e-01,  1.64746201e+00,  3.66559178e-01,
#          8.52912143e-02, -8.30318592e-03,  1.51242228e+01,
#          1.56573498e+00,  4.05961275e-01,  3.26313043e+00,
#          3.54934597e+00,  1.63147366e+00,  1.83292776e-02,
#          2.82190055e-01, -1.18602407e+00,  3.57093662e-02,
#          5.82251847e-01,  2.46483237e-01,  6.94857538e-02,
#          1.78789236e-02,  1.04233496e-01,  1.74899008e-02,
#          1.13741877e-02,  1.56041369e-01,  1.56493828e-01,
#          1.36126190e-01,  1.47680491e-02],
#        [ 8.50296795e-01,  1.64759839e+00,  3.66765171e-01,
#          8.52430984e-02, -8.31231661e-03,  1.51251678e+01,
#          1.56623137e+00,  4.05956089e-01,  3.26320076e+00,
#          3.54920101e+00,  1.63187325e+00,  1.83494613e-02,
#          2.82646298e-01, -1.18564069e+00,  3.57074738e-02,
#          5.82217455e-01,  2.46451944e-01,  6.94839060e-02,
#          1.78783815e-02,  1.04222208e-01,  1.74890663e-02,
#          1.13487262e-02,  1.56033412e-01,  1.56487644e-01,
#          1.36077821e-01,  1.47490427e-02],
#        [ 8.50326002e-01,  1.64761877e+00,  3.66795570e-01,
#          8.52361172e-02, -8.31379928e-03,  1.51253052e+01,
#          1.56630337e+00,  4.05955583e-01,  3.26321101e+00,
#          3.54917908e+00,  1.63193262e+00,  1.83525942e-02,
#          2.82711536e-01, -1.18558681e+00,  3.57072055e-02,
#          5.82212210e-01,  2.46446818e-01,  6.94836378e-02,
#          1.78783089e-02,  1.04220591e-01,  1.74890663e-02,
#          1.13451919e-02,  1.56032220e-01,  1.56486779e-01,
#          1.36070997e-01,  1.47461593e-02],
#        [ 8.50329816e-01,  1.64762032e+00,  3.66799504e-01,
#          8.52351785e-02, -8.31418671e-03,  1.51253185e+01,
#          1.56631243e+00,  4.05955344e-01,  3.26321173e+00,
#          3.54917812e+00,  1.63194048e+00,  1.83530524e-02,
#          2.82718986e-01, -1.18558013e+00,  3.57072167e-02,
#          5.82211196e-01,  2.46445984e-01,  6.94834739e-02,
#          1.78781785e-02,  1.04220346e-01,  1.74891856e-02,
#          1.13448640e-02,  1.56032026e-01,  1.56486809e-01,
#          1.36070237e-01,  1.47459712e-02],
#        [ 8.50329936e-01,  1.64762020e+00,  3.66799384e-01,
#          8.52349475e-02, -8.31427239e-03,  1.51253176e+01,
#          1.56631362e+00,  4.05955464e-01,  3.26321125e+00,
#          3.54918480e+00,  1.63193977e+00,  1.83530785e-02,
#          2.82720983e-01, -1.18557823e+00,  3.57072502e-02,
#          5.82211137e-01,  2.46446043e-01,  6.94834888e-02,
#          1.78781897e-02,  1.04220405e-01,  1.74890347e-02,
#          1.13446591e-02,  1.56031951e-01,  1.56486705e-01,
#          1.36069939e-01,  1.47458240e-02],
#        [ 8.50330174e-01,  1.64762080e+00,  3.66799265e-01,
#          8.52348059e-02, -8.31421278e-03,  1.51253195e+01,
#          1.56631410e+00,  4.05955434e-01,  3.26321125e+00,
#          3.54918194e+00,  1.63194096e+00,  1.83531307e-02,
#          2.82721162e-01, -1.18557823e+00,  3.57072800e-02,
#          5.82211137e-01,  2.46445924e-01,  6.94835186e-02,
#          1.78781971e-02,  1.04220308e-01,  1.74890477e-02,
#          1.13445502e-02,  1.56031892e-01,  1.56486645e-01,
#          1.36069760e-01,  1.47457458e-02],
#        [ 8.50330174e-01,  1.64762080e+00,  3.66799265e-01,
#          8.52348059e-02, -8.31421278e-03,  1.51253195e+01,
#          1.56631410e+00,  4.05955434e-01,  3.26321125e+00,
#          3.54918194e+00,  1.63194096e+00,  1.83531307e-02,
#          2.82721162e-01, -1.18557823e+00,  3.57072800e-02,
#          5.82211137e-01,  2.46445924e-01,  6.94835186e-02,
#          1.78781971e-02,  1.04220308e-01,  1.74890477e-02,
#          1.13445502e-02,  1.56031892e-01,  1.56486645e-01,
#          1.36069760e-01,  1.47457458e-02],
#        [ 8.50330174e-01,  1.64762080e+00,  3.66799265e-01,
#          8.52348059e-02, -8.31421278e-03,  1.51253195e+01,
#          1.56631410e+00,  4.05955434e-01,  3.26321125e+00,
#          3.54918194e+00,  1.63194096e+00,  1.83531307e-02,
#          2.82721162e-01, -1.18557823e+00,  3.57072800e-02,
#          5.82211137e-01,  2.46445924e-01,  6.94835186e-02,
#          1.78781971e-02,  1.04220308e-01,  1.74890477e-02,
#          1.13445502e-02,  1.56031892e-01,  1.56486645e-01,
#          1.36069760e-01,  1.47457458e-02],
#        [ 8.50330174e-01,  1.64762080e+00,  3.66799265e-01,
#          8.52348059e-02, -8.31421278e-03,  1.51253195e+01,
#          1.56631410e+00,  4.05955434e-01,  3.26321125e+00,
#          3.54918194e+00,  1.63194096e+00,  1.83531307e-02,
#          2.82721162e-01, -1.18557823e+00,  3.57072800e-02,
#          5.82211137e-01,  2.46445924e-01,  6.94835186e-02,
#          1.78781971e-02,  1.04220308e-01,  1.74890477e-02,
#          1.13445502e-02,  1.56031892e-01,  1.56486645e-01,
#          1.36069760e-01,  1.47457458e-02],
#        [ 8.50330174e-01,  1.64762080e+00,  3.66799265e-01,
#          8.52348059e-02, -8.31421278e-03,  1.51253195e+01,
#          1.56631410e+00,  4.05955434e-01,  3.26321125e+00,
#          3.54918194e+00,  1.63194096e+00,  1.83531307e-02,
#          2.82721162e-01, -1.18557823e+00,  3.57072800e-02,
#          5.82211137e-01,  2.46445924e-01,  6.94835186e-02,
#          1.78781971e-02,  1.04220308e-01,  1.74890477e-02,
#          1.13445502e-02,  1.56031892e-01,  1.56486645e-01,
#          1.36069760e-01,  1.47457458e-02],
#        [ 8.50330174e-01,  1.64762080e+00,  3.66799265e-01,
#          8.52348059e-02, -8.31421278e-03,  1.51253195e+01,
#          1.56631410e+00,  4.05955434e-01,  3.26321125e+00,
#          3.54918194e+00,  1.63194096e+00,  1.83531307e-02,
#          2.82721162e-01, -1.18557823e+00,  3.57072800e-02,
#          5.82211137e-01,  2.46445924e-01,  6.94835186e-02,
#          1.78781971e-02,  1.04220308e-01,  1.74890477e-02,
#          1.13445502e-02,  1.56031892e-01,  1.56486645e-01,
#          1.36069760e-01,  1.47457458e-02],
#        [ 8.50330174e-01,  1.64762080e+00,  3.66799265e-01,
#          8.52348059e-02, -8.31421278e-03,  1.51253195e+01,
#          1.56631410e+00,  4.05955434e-01,  3.26321125e+00,
#          3.54918194e+00,  1.63194096e+00,  1.83531307e-02,
#          2.82721162e-01, -1.18557823e+00,  3.57072800e-02,
#          5.82211137e-01,  2.46445924e-01,  6.94835186e-02,
#          1.78781971e-02,  1.04220308e-01,  1.74890477e-02,
#          1.13445502e-02,  1.56031892e-01,  1.56486645e-01,
#          1.36069760e-01,  1.47457458e-02],
#        [ 8.50330174e-01,  1.64762080e+00,  3.66799265e-01,
#          8.52348059e-02, -8.31421278e-03,  1.51253195e+01,
#          1.56631410e+00,  4.05955434e-01,  3.26321125e+00,
#          3.54918194e+00,  1.63194096e+00,  1.83531307e-02,
#          2.82721162e-01, -1.18557823e+00,  3.57072800e-02,
#          5.82211137e-01,  2.46445924e-01,  6.94835186e-02,
#          1.78781971e-02,  1.04220308e-01,  1.74890477e-02,
#          1.13445502e-02,  1.56031892e-01,  1.56486645e-01,
#          1.36069760e-01,  1.47457458e-02],
#        [ 8.50330174e-01,  1.64762080e+00,  3.66799265e-01,
#          8.52348059e-02, -8.31421278e-03,  1.51253195e+01,
#          1.56631410e+00,  4.05955434e-01,  3.26321125e+00,
#          3.54918194e+00,  1.63194096e+00,  1.83531307e-02,
#          2.82721162e-01, -1.18557823e+00,  3.57072800e-02,
#          5.82211137e-01,  2.46445924e-01,  6.94835186e-02,
#          1.78781971e-02,  1.04220308e-01,  1.74890477e-02,
#          1.13445502e-02,  1.56031892e-01,  1.56486645e-01,
#          1.36069760e-01,  1.47457458e-02],
#        [ 8.50330174e-01,  1.64762080e+00,  3.66799265e-01,
#          8.52348059e-02, -8.31421278e-03,  1.51253195e+01,
#          1.56631410e+00,  4.05955434e-01,  3.26321125e+00,
#          3.54918194e+00,  1.63194096e+00,  1.83531307e-02,
#          2.82721162e-01, -1.18557823e+00,  3.57072800e-02,
#          5.82211137e-01,  2.46445924e-01,  6.94835186e-02,
#          1.78781971e-02,  1.04220308e-01,  1.74890477e-02,
#          1.13445502e-02,  1.56031892e-01,  1.56486645e-01,
#          1.36069760e-01,  1.47457458e-02],
#        [ 8.50330174e-01,  1.64762080e+00,  3.66799265e-01,
#          8.52348059e-02, -8.31421278e-03,  1.51253195e+01,
#          1.56631410e+00,  4.05955434e-01,  3.26321125e+00,
#          3.54918194e+00,  1.63194096e+00,  1.83531307e-02,
#          2.82721162e-01, -1.18557823e+00,  3.57072800e-02,
#          5.82211137e-01,  2.46445924e-01,  6.94835186e-02,
#          1.78781971e-02,  1.04220308e-01,  1.74890477e-02,
#          1.13445502e-02,  1.56031892e-01,  1.56486645e-01,
#          1.36069760e-01,  1.47457458e-02],
#        [ 8.50330174e-01,  1.64762080e+00,  3.66799265e-01,
#          8.52348059e-02, -8.31421278e-03,  1.51253195e+01,
#          1.56631410e+00,  4.05955434e-01,  3.26321125e+00,
#          3.54918194e+00,  1.63194096e+00,  1.83531307e-02,
#          2.82721162e-01, -1.18557823e+00,  3.57072800e-02,
#          5.82211137e-01,  2.46445924e-01,  6.94835186e-02,
#          1.78781971e-02,  1.04220308e-01,  1.74890477e-02,
#          1.13445502e-02,  1.56031892e-01,  1.56486645e-01,
#          1.36069760e-01,  1.47457458e-02],
#        [ 8.50330174e-01,  1.64762080e+00,  3.66799265e-01,
#          8.52348059e-02, -8.31421278e-03,  1.51253195e+01,
#          1.56631410e+00,  4.05955434e-01,  3.26321125e+00,
#          3.54918194e+00,  1.63194096e+00,  1.83531307e-02,
#          2.82721162e-01, -1.18557823e+00,  3.57072800e-02,
#          5.82211137e-01,  2.46445924e-01,  6.94835186e-02,
#          1.78781971e-02,  1.04220308e-01,  1.74890477e-02,
#          1.13445502e-02,  1.56031892e-01,  1.56486645e-01,
#          1.36069760e-01,  1.47457458e-02],
#        [ 8.50330174e-01,  1.64762080e+00,  3.66799265e-01,
#          8.52348059e-02, -8.31421278e-03,  1.51253195e+01,
#          1.56631410e+00,  4.05955434e-01,  3.26321125e+00,
#          3.54918194e+00,  1.63194096e+00,  1.83531307e-02,
#          2.82721162e-01, -1.18557823e+00,  3.57072800e-02,
#          5.82211137e-01,  2.46445924e-01,  6.94835186e-02,
#          1.78781971e-02,  1.04220308e-01,  1.74890477e-02,
#          1.13445502e-02,  1.56031892e-01,  1.56486645e-01,
#          1.36069760e-01,  1.47457458e-02],
#        [ 8.50330174e-01,  1.64762080e+00,  3.66799265e-01,
#          8.52348059e-02, -8.31421278e-03,  1.51253195e+01,
#          1.56631410e+00,  4.05955434e-01,  3.26321125e+00,
#          3.54918194e+00,  1.63194096e+00,  1.83531307e-02,
#          2.82721162e-01, -1.18557823e+00,  3.57072800e-02,
#          5.82211137e-01,  2.46445924e-01,  6.94835186e-02,
#          1.78781971e-02,  1.04220308e-01,  1.74890477e-02,
#          1.13445502e-02,  1.56031892e-01,  1.56486645e-01,
#          1.36069760e-01,  1.47457458e-02],
#        [ 8.50330293e-01,  1.64762127e+00,  3.66799742e-01,
#          8.52347687e-02, -8.31420161e-03,  1.51253223e+01,
#          1.56631529e+00,  4.05955464e-01,  3.26321149e+00,
#          3.54918003e+00,  1.63194144e+00,  1.83531195e-02,
#          2.82723188e-01, -1.18557513e+00,  3.57072763e-02,
#          5.82211018e-01,  2.46445775e-01,  6.94835484e-02,
#          1.78782828e-02,  1.04220249e-01,  1.74890961e-02,
#          1.13445399e-02,  1.56031922e-01,  1.56486630e-01,
#          1.36069670e-01,  1.47457607e-02],
#        [ 8.50330293e-01,  1.64762127e+00,  3.66799742e-01,
#          8.52347687e-02, -8.31420161e-03,  1.51253223e+01,
#          1.56631529e+00,  4.05955464e-01,  3.26321149e+00,
#          3.54918003e+00,  1.63194144e+00,  1.83531195e-02,
#          2.82723188e-01, -1.18557513e+00,  3.57072763e-02,
#          5.82211018e-01,  2.46445775e-01,  6.94835484e-02,
#          1.78782828e-02,  1.04220249e-01,  1.74890961e-02,
#          1.13445399e-02,  1.56031922e-01,  1.56486630e-01,
#          1.36069670e-01,  1.47457607e-02],
#        [ 8.50330293e-01,  1.64762127e+00,  3.66799742e-01,
#          8.52347687e-02, -8.31420161e-03,  1.51253223e+01,
#          1.56631529e+00,  4.05955464e-01,  3.26321149e+00,
#          3.54918003e+00,  1.63194144e+00,  1.83531195e-02,
#          2.82723188e-01, -1.18557513e+00,  3.57072763e-02,
#          5.82211018e-01,  2.46445775e-01,  6.94835484e-02,
#          1.78782828e-02,  1.04220249e-01,  1.74890961e-02,
#          1.13445399e-02,  1.56031922e-01,  1.56486630e-01,
#          1.36069670e-01,  1.47457607e-02],
#        [ 8.50330293e-01,  1.64762127e+00,  3.66799742e-01,
#          8.52347687e-02, -8.31420161e-03,  1.51253223e+01,
#          1.56631529e+00,  4.05955464e-01,  3.26321149e+00,
#          3.54918003e+00,  1.63194144e+00,  1.83531195e-02,
#          2.82723188e-01, -1.18557513e+00,  3.57072763e-02,
#          5.82211018e-01,  2.46445775e-01,  6.94835484e-02,
#          1.78782828e-02,  1.04220249e-01,  1.74890961e-02,
#          1.13445399e-02,  1.56031922e-01,  1.56486630e-01,
#          1.36069670e-01,  1.47457607e-02]], dtype=float32)

# %%
test_data = np.genfromtxt('test.dat',
                     skip_header=0,
                     skip_footer=0,
                     names=None,
                     dtype=None,
                     delimiter=' ')
test_data

# %%
columns_names=['Time', 'M_art', 'M_venous', 'M_gills', 'M_lumen', 'M_lumen_2', 'M_viscera', 'M_liver', 'M_kidney', \
    'M_muscle', 'M_skin', 'M_carcass', 'M_storage', 'M_urine', 'M_feces', \
    'C_gills', 'C_viscera', 'C_liver', 'C_kidney', 'C_muscle', 'C_skin', 'C_carcass', \
    'C_lumen', 'C_art', 'C_venous', 'C_blood', 'C_storage']
test_df = pd.DataFrame(test_data, columns = columns_names)
test_df
