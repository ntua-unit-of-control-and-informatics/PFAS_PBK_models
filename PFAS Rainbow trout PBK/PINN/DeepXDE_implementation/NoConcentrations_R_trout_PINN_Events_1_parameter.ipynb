# %%
# In case you want to change the deepxde default backend just run the following line and select the backend at the end of the line:
# source: https://www.kaggle.com/code/lucasscheink/tesis-2d

# !python /Users/vassilis/anaconda3/pkgs/deepxde-1.9.3-pyhd5b0024_0/site-packages/deepxde/backend/set_default_backend.py tensorflow

# %%
import deepxde as dde
import numpy as np
import pandas as pd
import scipy as sp
from math import exp
#import tensorflow as tf
from deepxde.backend import tf
import tensorflow_probability as tfp
import matplotlib.pyplot as plt
import os
import re
# Out:
# Using backend: tensorflow
# Other supported backends: tensorflow.compat.v1, pytorch, jax, paddle.
# paddle supports more examples now and is recommended.

# %%
os.getcwd()
# Out:
# '/Users/vassilis/Documents/GitHub/PFAS_PBK_models/PFAS Rainbow trout PBK/PINN/DeepXDE_implementation'

# %% [markdown]
# Here we define the parameters that we want to estimate.

# %%
# Parameters to be estimated.

P_liver = dde.Variable(0.5)
P_muscle = dde.Variable(0.5)
P_kidney = dde.Variable(0.5)
P_skin = dde.Variable(0.5)
P_gills = dde.Variable(0.5)
P_carcass = dde.Variable(0.5)
P_viscera = dde.Variable(0.5)

# %% [markdown]
# Now we can begin by creating a TimeDomain class.

# %%
geom = dde.geometry.TimeDomain(0, 56*24)

# %%
# Function to estimate the constant parameters of the model
def create_params(substance, Texp):
    # Transform input temperature into Kelvin scale
    Texp = 273 + Texp  # K

    Tref = 273 + np.array([6, 12, 18])  # Reference Temperature K - Grech et al. 2018
    keep_ref_value = np.argmin(np.abs(Tref - Texp))

    # Cardiac output reference value at T = 6 C (Barron et al. 1987, Table II)
    F_card_ref_6 = 1.188  # ml/h/g
    # Cardiac output reference value at T = 12 C (Barron et al. 1987, Table II)
    F_card_ref_12 = 2.322  # ml/h/g
    # Cardiac output reference value at T = 18 C (Barron et al. 1987, Table II)
    F_card_ref_18 = 3.75  # ml/h/g
    F_card_ref_values = [F_card_ref_6, F_card_ref_12, F_card_ref_18]
    F_card_ref = F_card_ref_values[keep_ref_value]

    # Body weight reference value at T = 6 C (Barron et al. 1987, Table II)
    BW_ref_6 = 270.1  # g
    # Body weight reference value at T = 12 C (Barron et al. 1987, Table II)
    BW_ref_12 = 296.4  # g
    # Body weight reference value at T = 18 C (Barron et al. 1987, Table II)
    BW_ref_18 = 414.5  # g
    BW_ref_values = [BW_ref_6, BW_ref_12, BW_ref_18]
    BW_ref = BW_ref_values[keep_ref_value]

    # Arrhenius Temperature function
    TA = 6930  # Arrhenius Temperature K - Grech et al. 2018
    Tr = Tref[np.argmin(np.abs(Tref - Texp))]
    KT = exp(TA / Tr - TA / Texp)

    # Load the xlsx file with the physiological params of rainbow trout
    phys_params_sheet1 = pd.read_excel('/Users/vassilis/Documents/GitHub/PFAS_PBK_models/PFAS Rainbow trout PBK/Rainbow trout Physiological parameters/Rainbow trout Physiological parameters.xlsx', sheet_name=0)

    # Keep only the physiological parameters from the paper of Vidal et al. 2019
    fw = phys_params_sheet1.loc[phys_params_sheet1['Source'] == 'Vidal et al. 2019', ['Liver', 'Blood', 'Skin', 'Muscle', 'Gills', 'Kidney', 'Viscera']]
    fw_Liver = fw['Liver'].values[0]
    fw_Blood = fw['Blood'].values[0]
    fw_Skin = fw['Skin'].values[0]
    fw_Muscle = fw['Muscle'].values[0]
    fw_Gills = fw['Gills'].values[0]
    fw_Kidney = fw['Kidney'].values[0]
    fw_Viscera = fw['Viscera'].values[0]
    fw_lumen = 0.012

    # Load the xlsx file with the physiological params of rainbow trout
    phys_params_sheet2 = pd.read_excel('/Users/vassilis/Documents/GitHub/PFAS_PBK_models/PFAS Rainbow trout PBK/Rainbow trout Physiological parameters/Rainbow trout Physiological parameters.xlsx', sheet_name=1)

    # Keep only the physiological parameters from the paper of Vidal et al. 2019
    fb = phys_params_sheet2.loc[phys_params_sheet2['Source'] == 'Vidal et al. 2019', ['Liver', 'Skin', 'Muscle', 'Gills', 'Kidney', 'Viscera']]
    fb_Liver = fb['Liver'].values[0]
    fb_Skin = fb['Skin'].values[0]
    fb_Muscle = fb['Muscle'].values[0]
    fb_Gills = fb['Gills'].values[0]
    fb_Kidney = fb['Kidney'].values[0]
    fb_Viscera = fb['Viscera'].values[0]

    # Reabsorption coefficients from bile to intestine
    # estimated by Cao et al., 2022
    # K_urine = Cl_urine / f_reab_urine estimated by Ng et al., 2013 (unitless)
    if substance == 'PFOA':
        a = 0.138  # Sun et al., 2022, Goeritz et al. 2013
        f_reab_hep = 0.30  # Cao et al., 2022
        K_urine = 2.08
        Cl_urine = 0.029 * 3600  # 1/h (Sun et al., 2022)
    elif substance == 'PFNA':
        a = 0.522  # Sun et al., 2022, Goeritz et al. 2013
        f_reab_hep = 0.34  # Cao et al., 2022
        K_urine = 1.35
        Cl_urine = 0.050 * 3600  # 1/h (Sun et al., 2022)
    elif substance == 'PFBS':
        a = 0.0598  # Goeritz et al. 2013
        f_reab_hep = 0.23  # Cao et al., 2022
        K_urine = 5.88
        Cl_urine = 0.023 * 3600  # 1/h (Sun et al., 2022) # Assumed equal to PFHxS
    elif substance == 'PFHxS':
        a = 0.558  # Sun et al., 2022, Goeritz et al. 2013
        f_reab_hep = 0.30  # Cao et al., 2022
        K_urine = 5.88
        Cl_urine = 0.023 * 3600  # 1/h (Sun et al., 2022)
    elif substance == 'PFOS':
        a = 0.721  # Sun et al., 2022, Goeritz et al. 2013
        f_reab_hep = 0.42  # Cao et al., 2022
        K_urine = 1.35
        Cl_urine = 0.050 * 3600  # 1/h (Sun et al., 2022)

    # Bile flow coefficient
    Q_bile_coef = 7.5e-05  # ml/g BW/h Grosell et al., 2000
    Q_urine_coef = 2.755e-03  # ml/h/g of BW Urinary flow rate (Curtis et al., 1981)
    V_urine_coef = 2.2e-03  # ml/g of BW Urine volume inside urinary bladder (Curtis et al., 1981)

    a_skin = 0.9  # 90% of venous blood of skin was assumed to flow directly to kidney (Nichols et al. 1996)
    a_muscle = 0.6  # 60% of venous blood of muscle was assumed to flow directly to kidney (Nichols et al. 1996)

    plasma = 0.7
    
    return[F_card_ref, BW_ref, KT, fw_Liver, fw_Blood, fw_Skin, fw_Muscle, fw_Gills, fw_Kidney,
          fw_Viscera, fw_lumen, fb_Liver, fb_Skin, fb_Muscle, fb_Gills, fb_Kidney, fb_Viscera,
          a_skin, a_muscle, Q_bile_coef, Q_urine_coef, V_urine_coef, 
          K_urine, Cl_urine, f_reab_hep,plasma,a]

# %%
def fish_weight(time):
    x = tf.constant([0, 28 * 24, 56 * 24], dtype=tf.float32)
    y = tf.constant([314, 655, 808], dtype=tf.float32)

    w = tf.zeros([1,1])

    for time_i in tf.unstack(time):
        time_i = tf.cast(time_i, 'float32')
        condition_1 = tf.math.less_equal(time_i, tf.cast(x[0], 'float32'))
        condition_2 = tf.math.greater_equal(time_i, tf.cast(x[2], 'float32'))
        condition_3 = tf.math.logical_and(tf.math.greater_equal(time_i, tf.cast(x[0], 'float32')), tf.math.less(time_i, tf.cast(x[1], 'float32')))
        condition_4 = tf.math.logical_and(tf.math.greater_equal(time_i, tf.cast(x[1], 'float32')), tf.math.less(time_i, tf.cast(x[2], 'float32')))
        
        w_new = tf.cond(condition_1, lambda: y[0], 
                         lambda: tf.cond(condition_2, lambda: y[2], 
                                         lambda: tf.cond(condition_3, 
                                                         lambda: tfp.math.interp_regular_1d_grid(tf.cast(time_i, 'float32'), tf.cast(x[0], 'float32'),  
                                                                 tf.cast(x[1], 'float32'), tf.cast(y[0:2], 'float32')), 
                                                         lambda: tfp.math.interp_regular_1d_grid(tf.cast(time_i, 'float32'), tf.cast(x[1], 'float32'), 
                                                                    tf.cast(x[2], 'float32'), tf.cast(y[1:3], 'float32')) ))) 
        
        w_new = tf.reshape(w_new, [-1,1])
        w = tf.concat([w, w_new], axis=0)   
    w = w[1:]
    return (w)

# %% [markdown]
# Next, we create the PBK model to solve using the dde.grad.jacobian function.

# %%
def PBK_model(t, net_out, ex):
    # At this point we estimate the derivatives of the networks outputs to time    
    M_art, M_venous, M_gills, M_lumen, M_lumen_2, M_viscera, M_liver, M_kidney, \
    M_muscle, M_skin, M_carcass, M_storage, M_urine, M_feces, M_blood = net_out[:, 0:1], net_out[:, 1:2], \
    net_out[:, 2:3], net_out[:, 3:4], net_out[:, 4:5], net_out[:, 5:6], net_out[:, 6:7], net_out[:, 7:8], \
    net_out[:, 8:9], net_out[:, 9:10], net_out[:, 10:11], net_out[:, 11:12], net_out[:, 12:13], net_out[:, 13:14], net_out[:, 14:15]
    
    dM_art_ls = dde.gradients.jacobian(net_out, t, i=0)
    dM_venous_ls = dde.gradients.jacobian(net_out, t, i=1)
    dM_gills_ls = dde.gradients.jacobian(net_out, t, i=2)
    dM_lumen_ls = dde.gradients.jacobian(net_out, t, i=3)
    dM_lumen_2_ls = dde.gradients.jacobian(net_out, t, i=4)
    dM_viscera_ls = dde.gradients.jacobian(net_out, t, i=5)
    dM_liver_ls = dde.gradients.jacobian(net_out, t, i=6)
    dM_kidney_ls = dde.gradients.jacobian(net_out, t, i=7)
    dM_muscle_ls = dde.gradients.jacobian(net_out, t, i=8)
    dM_skin_ls = dde.gradients.jacobian(net_out, t, i=9)
    dM_carcass_ls = dde.gradients.jacobian(net_out, t, i=10)
    dM_storage_ls = dde.gradients.jacobian(net_out, t, i=11)
    dM_urine_ls = dde.gradients.jacobian(net_out, t, i=12)
    dM_feces_ls = dde.gradients.jacobian(net_out, t, i=13)
    dM_blood_ls = dde.gradients.jacobian(net_out, t, i=14)

    
    #------------------------------------------------------------
    # Estimate the derivatives based on the ODEs.
    
    # Estimation of constant parameters 
    (F_card_ref,BW_ref,KT,fw_Liver,fw_Blood,fw_Skin,fw_Muscle,fw_Gills,
     fw_Kidney, fw_Viscera, fw_lumen,fb_Liver,fb_Skin,fb_Muscle,fb_Gills,
     fb_Kidney,fb_Viscera,a_skin,a_muscle,Q_bile_coef,
     Q_urine_coef,V_urine_coef,K_urine,Cl_urine,f_reab_hep,plasma, a) = create_params('PFOS', 15)
    
    CLU_coef = 0.0005719031
    Ku = 1.4668919575
    Cl_feces = 1.3064647362
    
    # P_liver = 1.5685318
    # P_muscle = 0.11316576
    # P_kidney = 0.4398762
    # P_skin = 0.2715996
    # P_gills = 0.2291869
    # P_carcass = 0.1074253
    # P_viscera = 3.699111
    
    # Body weight - g
    BW = fish_weight(t)
    
    # Total cardiac output ml/h considered as plasma flow
    Q_total = F_card_ref*KT*(BW/BW_ref)**(-0.1)*BW*plasma  
    
    # Calculate the mass of each tissue - g
    w_blood = fw_Blood*BW*plasma     # Blood mass - g
    w_liver = fw_Liver*BW     # Liver mass - g
    w_skin = fw_Skin*BW       # Skin weight - g
    w_muscle = fw_Muscle*BW   # Muscle weight - g
    w_gills = fw_Gills*BW     # Gills weight - g
    w_kidney = fw_Kidney*BW   # Kidney weight - g
    w_viscera = fw_Viscera*BW # Viscera weight - g
    w_lumen = fw_lumen*BW
    w_art = 1/3*w_blood
    w_venous = 2/3*w_blood
    w_carcass = BW - (w_blood/plasma + w_liver + w_skin + w_muscle +
                         w_gills + w_kidney + w_viscera + w_lumen)
    
    # Calculate the regional blood flows - ml/h
    Q_liver = fb_Liver*Q_total     # Liver blood flow - ml/h
    Q_skin = fb_Skin*Q_total       # Skin blood flow - ml/h
    Q_muscle = fb_Muscle*Q_total   # Muscle blood flow - ml/h
    Q_gills = Q_total              # Gills blood flow - ml/h
    Q_kidney = fb_Kidney*Q_total   # Kidney blood flow - ml/h
    Q_viscera = fb_Viscera*Q_total # Viscera blood flow - ml/h
    Q_carcass = Q_total - (Q_liver + Q_skin + Q_muscle + 
                              Q_kidney + Q_viscera)
    
    # Calculate the absolute bile flow rate - ml/h
    Q_bile = Q_bile_coef*BW
    # Calculate Urinary flow rate - ml/h
    Q_urine = Q_urine_coef*BW
    
    # Calculate urine volume  - ml 
    v_urine = V_urine_coef*BW
    
    # Calculate f_reab_urine based on Cl_urine and K_urine - 1/h
    f_reab_urine = Cl_urine*CLU_coef/K_urine
    
    # Tissue concentrations ug PFAS/g tissue
    C_gills = M_gills/w_gills
    C_viscera = M_viscera/w_viscera
    C_liver = M_liver/w_liver
    C_kidney = M_kidney/w_kidney
    C_muscle = M_muscle/w_muscle 
    C_skin = M_skin/w_skin
    C_carcass = M_carcass/w_carcass
    C_lumen = (M_lumen+M_lumen_2)/w_lumen
    C_art = M_art/w_art
    C_venous = M_venous/w_venous
    C_blood = (M_art + M_venous)/w_blood
    C_storage = M_storage/v_urine
    
    # Arterial Blood
    dM_art_rs = Q_gills*C_gills/P_gills - \
                (Q_viscera + Q_liver + Q_kidney +
                 Q_muscle + Q_skin + Q_carcass)*C_art
        
    # Venous blood    
    dM_venous_rs = - Q_total*C_venous + \
                    (Q_liver + Q_viscera)*C_liver/P_liver + \
                    (Q_kidney + a_muscle*Q_muscle + a_skin*Q_skin)*C_kidney/P_kidney + \
                    (1-a_muscle)*Q_muscle*C_muscle/P_muscle + \
                    (1-a_skin)*Q_skin*C_skin/P_skin + Q_carcass*C_carcass/P_carcass
    
    dM_blood_rs = (dM_art_rs + dM_venous_rs)*plasma
    
    # Gills 
    dM_gills_rs = Q_gills*(C_venous - C_gills/P_gills) 
    
    # Viscera Lumen - Available PFAS for absorption and elimination
    dM_lumen_rs = - Ku*a*M_lumen - Cl_feces*(1-a)*M_lumen + ex
    
    # Viscera Lumen 2 - Unavailable PFAS for absorption. Can be only eliminated.
    dM_lumen_2_rs = (1-f_reab_hep)*Q_bile*C_liver - Cl_feces*M_lumen_2 
    
    
    # Viscera Tissue
    dM_viscera_rs = Q_viscera*(C_art - C_viscera/P_viscera) + Ku*a*M_lumen + \
                      f_reab_hep*Q_bile*C_liver
    
    # Liver
    dM_liver_rs = Q_liver*C_art + Q_viscera*C_viscera/P_viscera -    \
                      (Q_liver + Q_viscera)*C_liver/P_liver - Q_bile*C_liver
        
    # Kidney
    dM_kidney_rs = Q_kidney*C_art -   \
                  (Q_kidney + a_muscle*Q_muscle + a_skin*Q_skin)*C_kidney/P_kidney + \
                  a_muscle*Q_muscle*C_muscle/P_muscle +   \
                  a_skin*Q_skin*C_skin/P_skin - Cl_urine*CLU_coef*M_kidney + f_reab_urine*M_storage
    
                
    # Muscle 
    dM_muscle_rs = Q_muscle*(C_art - C_muscle/P_muscle)

    # Skin
    dM_skin_rs = Q_skin*(C_art - C_skin/P_skin)
    
    # Carcass 
    dM_carcass_rs = Q_carcass*(C_art - C_carcass/P_carcass)
    
    # Urine Storage
    dM_storage_rs = Cl_urine*CLU_coef*M_kidney - f_reab_urine*M_storage - Q_urine*C_storage
    
    # Urine
    dM_urine_rs = Q_urine*C_storage
    
    # Feces
    dM_feces_rs = Cl_feces*((1-a)*M_lumen + M_lumen_2)
    
    return [
        dM_art_ls - dM_art_rs,
        dM_venous_ls - dM_venous_rs,
        dM_gills_ls - dM_gills_rs,
        dM_lumen_ls - dM_lumen_rs,
        dM_lumen_2_ls - dM_lumen_2_rs,
        dM_viscera_ls - dM_viscera_rs,
        dM_liver_ls - dM_liver_rs,
        dM_kidney_ls - dM_kidney_rs,
        dM_muscle_ls - dM_muscle_rs,
        dM_skin_ls - dM_skin_rs,
        dM_carcass_ls - dM_carcass_rs,
        dM_storage_ls - dM_storage_rs,
        dM_urine_ls - dM_urine_rs,
        dM_feces_ls - dM_feces_rs,
        dM_blood_ls - dM_blood_rs,
        M_blood - (M_art + M_venous)
    ]

# %% [markdown]
# Next, we consider the initial conditions. We need to implement a function, which should return True for points inside the subdomain and False for the points outside.

# %%
def boundary(_, on_initial):
    return on_initial

# %%
# Initial conditions

ic1 = dde.icbc.IC(geom, lambda X: 0, boundary, component=0) # M_art
ic2 = dde.icbc.IC(geom, lambda X: 0, boundary, component=1) # M_venous
ic3 = dde.icbc.IC(geom, lambda X: 0, boundary, component=2) # M_gills
ic4 = dde.icbc.IC(geom, lambda X: 0, boundary, component=3) # M_lumen <<--- The initial added PFAS amount.
ic5 = dde.icbc.IC(geom, lambda X: 0, boundary, component=4) # M_lumen_2
ic6 = dde.icbc.IC(geom, lambda X: 0, boundary, component=5) # M_viscera
ic7 = dde.icbc.IC(geom, lambda X: 0, boundary, component=6) # M_liver
ic8 = dde.icbc.IC(geom, lambda X: 0, boundary, component=7) # M_kidney
ic9 = dde.icbc.IC(geom, lambda X: 0, boundary, component=8) # M_muscle
ic10 = dde.icbc.IC(geom, lambda X: 0, boundary, component=9) # M_skin
ic11 = dde.icbc.IC(geom, lambda X: 0, boundary, component=10) # M_carcass
ic12 = dde.icbc.IC(geom, lambda X: 0, boundary, component=11) # M_storage
ic13 = dde.icbc.IC(geom, lambda X: 0, boundary, component=12) # M_urine
ic14 = dde.icbc.IC(geom, lambda X: 0, boundary, component=13) # M_feces
ic15 = dde.icbc.IC(geom, lambda X: 0, boundary, component=14) # M_blood

# %%
def gen_traindata():
    #data = np.load('PFOS_dataset.npy')
    data = pd.read_csv('PFOS_Mass_dataset.csv')
    return np.vstack(data["Time"]), np.vstack(data["Liver"]), np.vstack(data["Blood"]), np.vstack(data["Skin"]), \
            np.vstack(data["Muscle"]), np.vstack(data["Gills"]), np.vstack(data["Kidney"]), np.vstack(data["Carcass"])

# %%
pd.read_csv('PFOS_Mass_dataset.csv')
# Out:
#    Unnamed: 0 Substance  Time  Cumulative_added_PFAS  Feeding_period  \
# 0           2      PFOS   168               31.89875             168
# 1           3      PFOS   336               71.55525             336
# 2           4      PFOS   672              174.14150             672
# 3           5      PFOS   744              174.14150               0
# 4           6      PFOS   840              174.14150               0
# 5           7      PFOS  1008              174.14150               0
# 6           8      PFOS  1344              174.14150               0
#
#    Depuration_period     Liver     Blood      Skin     Muscle     Gills  \
# 0                  0  0.830824  1.387634  0.902924   6.333805  0.282163
# 1                  0  1.008226  1.683928  1.095722   7.686233  0.342411
# 2                  0  1.363029  2.276518  1.481316  10.391089  0.462909
# 3                 72  1.397142  2.333493  1.518390  10.651149  0.474495
# 4                168  1.442626  2.409460  1.567821  10.997896  0.489942
# 5                336  1.522223  2.542402  1.654325  11.604704  0.516974
# 6                672  1.681416  2.808285  1.827334  12.818320  0.571039
#
#      Kidney   Carcass
# 0  0.387887  1.211752
# 1  0.470711  1.470492
# 2  0.636358  1.987972
# 3  0.652284  2.037726
# 4  0.673519  2.104064
# 5  0.710681  2.220155
# 6  0.785003  2.452338

# %%
# data = pd.read_csv('PFOS_dataset_2.csv')
# data = data[["Time", 'Liver', 'Blood', 'Skin', 'Muscle', 'Gills', 'Kidney', 'Carcass']]
# data[['Time']] = (data[['Time']] - data[['Time']].min()) / (data[['Time']].max() - data[['Time']].min())
# data
# #data_norm = (data - data.min()) / (data.max() - data.min())
# #data_norm

# %%
observe_t, Obs_liver, Obs_blood, Obs_skin, Obs_muscle, Obs_gills, Obs_kidney, Obs_carcass = gen_traindata()
# observe_t, C_liver, C_blood, C_skin, C_muscle, C_gills, C_kidney, C_carcass = np.vstack(data["Time"]), np.vstack(data["Liver"]), np.vstack(data["Blood"]), np.vstack(data["Skin"]), \
#             np.vstack(data["Muscle"]), np.vstack(data["Gills"]), np.vstack(data["Kidney"]), np.vstack(data["Carcass"])

observe_Blood = dde.icbc.PointSetBC(observe_t, Obs_blood, component=14, shuffle=False) 
observe_Gills = dde.icbc.PointSetBC(observe_t, Obs_gills, component=2, shuffle=False)
observe_Liver = dde.icbc.PointSetBC(observe_t, Obs_liver, component=6, shuffle=False)
observe_Kidney = dde.icbc.PointSetBC(observe_t, Obs_kidney, component=7, shuffle=False)
observe_Muscle = dde.icbc.PointSetBC(observe_t, Obs_muscle, component=8, shuffle=False)
observe_Skin = dde.icbc.PointSetBC(observe_t, Obs_skin, component=9, shuffle=False)
observe_Carcass = dde.icbc.PointSetBC(observe_t, Obs_carcass, component=10,shuffle=False)

# %% [markdown]
# Import the data for events.

# %%
events_data = pd.read_csv('events_simplified.csv')
time_points = np.vstack(events_data['time'])
added_amount = np.vstack(events_data['value'])

# Create an interpolation function to approximate the events_data governing function

# def ex_func(t):
#     spline = sp.interpolate.RBFInterpolator(time_points, added_amount, kernel = 'thin_plate_spline')
#     return spline(t[:, 0:])

def ex_func(t): 
    added_pfas = []
    for time_i in t:
        if np.isin(time_i, time_points):
            index = np.where(np.isin(time_points, time_i))
            added_pfas.append(added_amount[index])
        else:
            added_pfas.append(0)
    return(np.vstack(added_pfas))

# def ex_func(t): 
#     added_pfas = []
#     for time_i in t:
#         if time_i <= 648:
#             added_pfas.append(6.449685/24)
#         else:
#             added_pfas.append(0)
#     return(np.vstack(added_pfas))

# %%
print(events_data.shape)
print(time_points.shape)
print(added_amount.shape)
# Out:
# (28, 2)
# (28, 1)
# (28, 1)

# %%
np.array([[0]])
# Out:
# array([[0]])

# %%
# events_time_points = time_points

# anchors = np.concatenate((events_time_points, observe_t))
anchors = np.vstack((np.array([0]), observe_t))
anchors = np.sort(anchors, axis=0)
anchors = np.vstack(np.unique(anchors))
anchors
# Out:
# array([[   0],
#        [ 168],
#        [ 336],
#        [ 672],
#        [ 744],
#        [ 840],
#        [1008],
#        [1344]])

# %%
# Now that the problem is fully setup, we define the PDE as:
# ic1, ic2, ic3, ic4, ic5, ic6, ic7, ic8, ic9, ic10, ic11,
#            ic12, ic13, ic14, ic15
# data = dde.data.PDE(
#     geometry = geom, # Instance of Geometry
#     pde = PBK_model, # A global PDE or a list of PDEs. None if no global PDE.
#     bcs = [observe_Blood, observe_Gills, observe_Liver, observe_Kidney,
#            observe_Muscle, observe_Skin, observe_Carcass], #A boundary condition or a list of boundary conditions. Use [] if no boundary condition.
#     num_domain=1000, # The number of training points sampled inside the domain.
#     num_test= 100, 
#     num_boundary=2, # The number of training points sampled on the boundary.
#     train_distribution = 'uniform', # The distribution to sample training points.
#     anchors=anchors, # A Numpy array of training points, in addition to the num_domain and num_boundary sampled points.
#     auxiliary_var_function = ex_func)

data = dde.data.PDE(
    geometry = geom, # Instance of Geometry
    pde = PBK_model, # A global PDE or a list of PDEs. None if no global PDE.
    bcs = [observe_Blood, observe_Gills, observe_Liver, observe_Kidney,
           observe_Muscle, observe_Skin, observe_Carcass], #A boundary condition or a list of boundary conditions. Use [] if no boundary condition.
    num_domain=200, # The number of training points sampled inside the domain.
    num_test= 50, 
    num_boundary=7, # The number of training points sampled on the boundary.
    #train_distribution = 'uniform', # The distribution to sample training points.
    anchors=anchors, # A Numpy array of training points, in addition to the num_domain and num_boundary sampled points.
    auxiliary_var_function = ex_func)

# %%
# data = dde.data.PDE(
#     geometry = geom, # Instance of Geometry
#     pde = PBK_model, # A global PDE or a list of PDEs. None if no global PDE.
#     bcs = [observe_Blood, observe_Gills, observe_Liver, observe_Kidney,
#            observe_Muscle, observe_Skin, observe_Carcass], #A boundary condition or a list of boundary conditions. Use [] if no boundary condition.
#     num_domain=50, # The number of training points sampled inside the domain.
#     num_boundary=2, # The number of training points sampled on the boundary.
#     train_distribution = 'uniform', # The distribution to sample training points.
#     anchors=anchors, # A Numpy array of training points, in addition to the num_domain and num_boundary sampled points.
#     auxiliary_var_function = ex_func)

# %%
def output_transform(t, netout):
    netout1 = netout[:, 0:1]
    netout2 = netout[:, 1:2]
    netout3 = netout[:, 2:3]
    netout4 = netout[:, 3:4]
    netout5 = netout[:, 4:5]
    netout6 = netout[:, 5:6]
    netout7 = netout[:, 6:7]
    netout8 = netout[:, 7:8]
    netout9 = netout[:, 8:9]
    netout10 = netout[:, 9:10]
    netout11 = netout[:, 10:11]
    netout12 = netout[:, 11:12]
    netout13 = netout[:, 12:13]
    netout14 = netout[:, 13:14]
    netout15 = netout[:, 14:15]
    
    return tf.concat(
        [netout1 * tf.tanh(t) , netout2 * tf.tanh(t), netout3 * tf.tanh(t),
         netout4 * tf.tanh(t), 
         netout5 * tf.tanh(t), netout6 * tf.tanh(t),
         netout7 * tf.tanh(t) , netout8 * tf.tanh(t), netout9 * tf.tanh(t),
         netout10 * tf.tanh(t), netout11 * tf.tanh(t), netout12 * tf.tanh(t),
         netout13 * tf.tanh(t), netout14 * tf.tanh(t), netout15 * tf.tanh(t)
        ], axis=1
    )

# %%
# Next, we choose the network. 

initializer = tf.keras.initializers.GlorotNormal(seed = 1)
net = dde.nn.FNN([1] + [30] * 3 + [15], "tanh", initializer)
net.apply_output_transform(output_transform)


model = dde.Model(data, net)

external_trainable_variables=[P_liver,P_muscle,P_kidney,P_skin,P_gills,P_carcass,P_viscera]
fnamevar = "variables.dat"
variable = dde.callbacks.VariableValue(external_trainable_variables, period=1000, filename="variables.dat")

# %%
loss_weights = np.concatenate((np.repeat([0.1], 16), np.repeat([10],7)) )

# %%
optimizer = tf.keras.optimizers.Adam()
lr=0.001
loss = dde.losses.mean_squared_error

model.compile(optimizer = optimizer, lr=lr, loss = loss, loss_weights = loss_weights.tolist(),
              external_trainable_variables=external_trainable_variables)
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# Compiling model...
# 'compile' took 0.000899 s

# %%
losshistory, train_state = model.train(iterations=10000, callbacks=[variable])
# Out:
# Training model...
# 2023-09-19 12:07:25.124137: W tensorflow/tsl/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# Step      Train loss                                                                                                                                                                                                                                Test loss                                                                                                                                                                                                                                 Test metric
# 0         [2.40e+01, 7.48e+01, 2.97e+02, 1.29e-01, 1.02e-02, 5.56e-02, 2.12e+01, 1.61e+02, 1.33e+01, 9.12e-02, 1.58e+00, 4.98e-03, 5.66e-03, 1.62e-02, 2.28e+01, 1.24e-01, 1.89e+01, 1.09e+00, 3.74e+01, 8.90e+00, 1.12e+03, 1.19e+01, 8.10e+01]    [2.36e+01, 7.66e+01, 2.91e+02, 1.14e-02, 1.04e-02, 4.65e-02, 2.17e+01, 1.65e+02, 1.04e+01, 5.92e-02, 1.45e+00, 5.11e-03, 5.83e-03, 1.66e-02, 2.16e+01, 1.29e-01, 1.89e+01, 1.09e+00, 3.74e+01, 8.90e+00, 1.12e+03, 1.19e+01, 8.10e+01]    []
# 2023-09-19 12:07:39.610261: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/gradients/fnn/strided_slice_grad/StridedSliceGrad_grad/StridedSlice/gradients/fnn/strided_slice_grad/StridedSliceGrad/strides' with dtype int32 and shape [2]
# 	 [[{{node gradients/gradients/fnn/strided_slice_grad/StridedSliceGrad_grad/StridedSlice/gradients/fnn/strided_slice_grad/StridedSliceGrad/strides}}]]
# 2023-09-19 12:07:39.611141: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/gradients/fnn/strided_slice_1_grad/StridedSliceGrad_grad/StridedSlice/gradients/fnn/strided_slice_1_grad/StridedSliceGrad/strides' with dtype int32 and shape [2]
# 	 [[{{node gradients/gradients/fnn/strided_slice_1_grad/StridedSliceGrad_grad/StridedSlice/gradients/fnn/strided_slice_1_grad/StridedSliceGrad/strides}}]]
# 2023-09-19 12:07:39.611658: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/gradients/fnn/strided_slice_2_grad/StridedSliceGrad_grad/StridedSlice/gradients/fnn/strided_slice_2_grad/StridedSliceGrad/strides' with dtype int32 and shape [2]
# 	 [[{{node gradients/gradients/fnn/strided_slice_2_grad/StridedSliceGrad_grad/StridedSlice/gradients/fnn/strided_slice_2_grad/StridedSliceGrad/strides}}]]
# 2023-09-19 12:07:39.612230: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/gradients/fnn/strided_slice_3_grad/StridedSliceGrad_grad/StridedSlice/gradients/fnn/strided_slice_3_grad/StridedSliceGrad/strides' with dtype int32 and shape [2]
# 	 [[{{node gradients/gradients/fnn/strided_slice_3_grad/StridedSliceGrad_grad/StridedSlice/gradients/fnn/strided_slice_3_grad/StridedSliceGrad/strides}}]]
# 2023-09-19 12:07:39.612889: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/gradients/fnn/strided_slice_4_grad/StridedSliceGrad_grad/StridedSlice/gradients/fnn/strided_slice_4_grad/StridedSliceGrad/strides' with dtype int32 and shape [2]
# 	 [[{{node gradients/gradients/fnn/strided_slice_4_grad/StridedSliceGrad_grad/StridedSlice/gradients/fnn/strided_slice_4_grad/StridedSliceGrad/strides}}]]
# 2023-09-19 12:07:39.613512: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/gradients/fnn/strided_slice_5_grad/StridedSliceGrad_grad/StridedSlice/gradients/fnn/strided_slice_5_grad/StridedSliceGrad/strides' with dtype int32 and shape [2]
# 	 [[{{node gradients/gradients/fnn/strided_slice_5_grad/StridedSliceGrad_grad/StridedSlice/gradients/fnn/strided_slice_5_grad/StridedSliceGrad/strides}}]]
# 2023-09-19 12:07:39.614101: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/gradients/fnn/strided_slice_6_grad/StridedSliceGrad_grad/StridedSlice/gradients/fnn/strided_slice_6_grad/StridedSliceGrad/strides' with dtype int32 and shape [2]
# 	 [[{{node gradients/gradients/fnn/strided_slice_6_grad/StridedSliceGrad_grad/StridedSlice/gradients/fnn/strided_slice_6_grad/StridedSliceGrad/strides}}]]
# 2023-09-19 12:07:39.614681: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/gradients/fnn/strided_slice_7_grad/StridedSliceGrad_grad/StridedSlice/gradients/fnn/strided_slice_7_grad/StridedSliceGrad/strides' with dtype int32 and shape [2]
# 	 [[{{node gradients/gradients/fnn/strided_slice_7_grad/StridedSliceGrad_grad/StridedSlice/gradients/fnn/strided_slice_7_grad/StridedSliceGrad/strides}}]]
# 2023-09-19 12:07:39.615257: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/gradients/fnn/strided_slice_8_grad/StridedSliceGrad_grad/StridedSlice/gradients/fnn/strided_slice_8_grad/StridedSliceGrad/strides' with dtype int32 and shape [2]
# 	 [[{{node gradients/gradients/fnn/strided_slice_8_grad/StridedSliceGrad_grad/StridedSlice/gradients/fnn/strided_slice_8_grad/StridedSliceGrad/strides}}]]
# 2023-09-19 12:07:39.615830: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/gradients/fnn/strided_slice_9_grad/StridedSliceGrad_grad/StridedSlice/gradients/fnn/strided_slice_9_grad/StridedSliceGrad/strides' with dtype int32 and shape [2]
# 	 [[{{node gradients/gradients/fnn/strided_slice_9_grad/StridedSliceGrad_grad/StridedSlice/gradients/fnn/strided_slice_9_grad/StridedSliceGrad/strides}}]]
# 2023-09-19 12:07:39.616414: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/gradients/fnn/strided_slice_10_grad/StridedSliceGrad_grad/StridedSlice/gradients/fnn/strided_slice_10_grad/StridedSliceGrad/strides' with dtype int32 and shape [2]
# 	 [[{{node gradients/gradients/fnn/strided_slice_10_grad/StridedSliceGrad_grad/StridedSlice/gradients/fnn/strided_slice_10_grad/StridedSliceGrad/strides}}]]
# 2023-09-19 12:07:39.617050: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/gradients/fnn/strided_slice_11_grad/StridedSliceGrad_grad/StridedSlice/gradients/fnn/strided_slice_11_grad/StridedSliceGrad/strides' with dtype int32 and shape [2]
# 	 [[{{node gradients/gradients/fnn/strided_slice_11_grad/StridedSliceGrad_grad/StridedSlice/gradients/fnn/strided_slice_11_grad/StridedSliceGrad/strides}}]]
# 2023-09-19 12:07:39.617576: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/gradients/fnn/strided_slice_12_grad/StridedSliceGrad_grad/StridedSlice/gradients/fnn/strided_slice_12_grad/StridedSliceGrad/strides' with dtype int32 and shape [2]
# 	 [[{{node gradients/gradients/fnn/strided_slice_12_grad/StridedSliceGrad_grad/StridedSlice/gradients/fnn/strided_slice_12_grad/StridedSliceGrad/strides}}]]
# 2023-09-19 12:07:39.618182: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/gradients/fnn/strided_slice_13_grad/StridedSliceGrad_grad/StridedSlice/gradients/fnn/strided_slice_13_grad/StridedSliceGrad/strides' with dtype int32 and shape [2]
# 	 [[{{node gradients/gradients/fnn/strided_slice_13_grad/StridedSliceGrad_grad/StridedSlice/gradients/fnn/strided_slice_13_grad/StridedSliceGrad/strides}}]]
# 2023-09-19 12:07:39.618760: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/gradients/fnn/strided_slice_14_grad/StridedSliceGrad_grad/StridedSlice/gradients/fnn/strided_slice_14_grad/StridedSliceGrad/strides' with dtype int32 and shape [2]
# 	 [[{{node gradients/gradients/fnn/strided_slice_14_grad/StridedSliceGrad_grad/StridedSlice/gradients/fnn/strided_slice_14_grad/StridedSliceGrad/strides}}]]
# 2023-09-19 12:07:39.619438: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/gradients_1/fnn/strided_slice_grad/StridedSliceGrad_grad/StridedSlice/gradients_1/fnn/strided_slice_grad/StridedSliceGrad/strides' with dtype int32 and shape [2]
# 	 [[{{node gradients/gradients_1/fnn/strided_slice_grad/StridedSliceGrad_grad/StridedSlice/gradients_1/fnn/strided_slice_grad/StridedSliceGrad/strides}}]]
# 2023-09-19 12:07:39.620115: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/gradients_1/fnn/strided_slice_1_grad/StridedSliceGrad_grad/StridedSlice/gradients_1/fnn/strided_slice_1_grad/StridedSliceGrad/strides' with dtype int32 and shape [2]
# 	 [[{{node gradients/gradients_1/fnn/strided_slice_1_grad/StridedSliceGrad_grad/StridedSlice/gradients_1/fnn/strided_slice_1_grad/StridedSliceGrad/strides}}]]
# 2023-09-19 12:07:39.620643: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/gradients_1/fnn/strided_slice_2_grad/StridedSliceGrad_grad/StridedSlice/gradients_1/fnn/strided_slice_2_grad/StridedSliceGrad/strides' with dtype int32 and shape [2]
# 	 [[{{node gradients/gradients_1/fnn/strided_slice_2_grad/StridedSliceGrad_grad/StridedSlice/gradients_1/fnn/strided_slice_2_grad/StridedSliceGrad/strides}}]]
# 2023-09-19 12:07:39.621312: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/gradients_1/fnn/strided_slice_3_grad/StridedSliceGrad_grad/StridedSlice/gradients_1/fnn/strided_slice_3_grad/StridedSliceGrad/strides' with dtype int32 and shape [2]
# 	 [[{{node gradients/gradients_1/fnn/strided_slice_3_grad/StridedSliceGrad_grad/StridedSlice/gradients_1/fnn/strided_slice_3_grad/StridedSliceGrad/strides}}]]
# 2023-09-19 12:07:39.621907: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/gradients_1/fnn/strided_slice_4_grad/StridedSliceGrad_grad/StridedSlice/gradients_1/fnn/strided_slice_4_grad/StridedSliceGrad/strides' with dtype int32 and shape [2]
# 	 [[{{node gradients/gradients_1/fnn/strided_slice_4_grad/StridedSliceGrad_grad/StridedSlice/gradients_1/fnn/strided_slice_4_grad/StridedSliceGrad/strides}}]]
# 2023-09-19 12:07:39.622537: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/gradients_1/fnn/strided_slice_5_grad/StridedSliceGrad_grad/StridedSlice/gradients_1/fnn/strided_slice_5_grad/StridedSliceGrad/strides' with dtype int32 and shape [2]
# 	 [[{{node gradients/gradients_1/fnn/strided_slice_5_grad/StridedSliceGrad_grad/StridedSlice/gradients_1/fnn/strided_slice_5_grad/StridedSliceGrad/strides}}]]
# 2023-09-19 12:07:39.623133: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/gradients_1/fnn/strided_slice_6_grad/StridedSliceGrad_grad/StridedSlice/gradients_1/fnn/strided_slice_6_grad/StridedSliceGrad/strides' with dtype int32 and shape [2]
# 	 [[{{node gradients/gradients_1/fnn/strided_slice_6_grad/StridedSliceGrad_grad/StridedSlice/gradients_1/fnn/strided_slice_6_grad/StridedSliceGrad/strides}}]]
# 2023-09-19 12:07:39.623755: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/gradients_1/fnn/strided_slice_7_grad/StridedSliceGrad_grad/StridedSlice/gradients_1/fnn/strided_slice_7_grad/StridedSliceGrad/strides' with dtype int32 and shape [2]
# 	 [[{{node gradients/gradients_1/fnn/strided_slice_7_grad/StridedSliceGrad_grad/StridedSlice/gradients_1/fnn/strided_slice_7_grad/StridedSliceGrad/strides}}]]
# 2023-09-19 12:07:39.624343: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/gradients_1/fnn/strided_slice_8_grad/StridedSliceGrad_grad/StridedSlice/gradients_1/fnn/strided_slice_8_grad/StridedSliceGrad/strides' with dtype int32 and shape [2]
# 	 [[{{node gradients/gradients_1/fnn/strided_slice_8_grad/StridedSliceGrad_grad/StridedSlice/gradients_1/fnn/strided_slice_8_grad/StridedSliceGrad/strides}}]]
# 2023-09-19 12:07:39.624942: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/gradients_1/fnn/strided_slice_9_grad/StridedSliceGrad_grad/StridedSlice/gradients_1/fnn/strided_slice_9_grad/StridedSliceGrad/strides' with dtype int32 and shape [2]
# 	 [[{{node gradients/gradients_1/fnn/strided_slice_9_grad/StridedSliceGrad_grad/StridedSlice/gradients_1/fnn/strided_slice_9_grad/StridedSliceGrad/strides}}]]
# 2023-09-19 12:07:39.625516: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/gradients_1/fnn/strided_slice_10_grad/StridedSliceGrad_grad/StridedSlice/gradients_1/fnn/strided_slice_10_grad/StridedSliceGrad/strides' with dtype int32 and shape [2]
# 	 [[{{node gradients/gradients_1/fnn/strided_slice_10_grad/StridedSliceGrad_grad/StridedSlice/gradients_1/fnn/strided_slice_10_grad/StridedSliceGrad/strides}}]]
# 2023-09-19 12:07:39.626111: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/gradients_1/fnn/strided_slice_11_grad/StridedSliceGrad_grad/StridedSlice/gradients_1/fnn/strided_slice_11_grad/StridedSliceGrad/strides' with dtype int32 and shape [2]
# 	 [[{{node gradients/gradients_1/fnn/strided_slice_11_grad/StridedSliceGrad_grad/StridedSlice/gradients_1/fnn/strided_slice_11_grad/StridedSliceGrad/strides}}]]
# 2023-09-19 12:07:39.626682: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/gradients_1/fnn/strided_slice_12_grad/StridedSliceGrad_grad/StridedSlice/gradients_1/fnn/strided_slice_12_grad/StridedSliceGrad/strides' with dtype int32 and shape [2]
# 	 [[{{node gradients/gradients_1/fnn/strided_slice_12_grad/StridedSliceGrad_grad/StridedSlice/gradients_1/fnn/strided_slice_12_grad/StridedSliceGrad/strides}}]]
# 2023-09-19 12:07:39.627257: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/gradients_1/fnn/strided_slice_13_grad/StridedSliceGrad_grad/StridedSlice/gradients_1/fnn/strided_slice_13_grad/StridedSliceGrad/strides' with dtype int32 and shape [2]
# 	 [[{{node gradients/gradients_1/fnn/strided_slice_13_grad/StridedSliceGrad_grad/StridedSlice/gradients_1/fnn/strided_slice_13_grad/StridedSliceGrad/strides}}]]
# 2023-09-19 12:07:39.627823: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/gradients_1/fnn/strided_slice_14_grad/StridedSliceGrad_grad/StridedSlice/gradients_1/fnn/strided_slice_14_grad/StridedSliceGrad/strides' with dtype int32 and shape [2]
# 	 [[{{node gradients/gradients_1/fnn/strided_slice_14_grad/StridedSliceGrad_grad/StridedSlice/gradients_1/fnn/strided_slice_14_grad/StridedSliceGrad/strides}}]]
# 2023-09-19 12:07:39.628408: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/gradients_2/fnn/strided_slice_grad/StridedSliceGrad_grad/StridedSlice/gradients_2/fnn/strided_slice_grad/StridedSliceGrad/strides' with dtype int32 and shape [2]
# 	 [[{{node gradients/gradients_2/fnn/strided_slice_grad/StridedSliceGrad_grad/StridedSlice/gradients_2/fnn/strided_slice_grad/StridedSliceGrad/strides}}]]
# 2023-09-19 12:07:39.629044: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/gradients_2/fnn/strided_slice_1_grad/StridedSliceGrad_grad/StridedSlice/gradients_2/fnn/strided_slice_1_grad/StridedSliceGrad/strides' with dtype int32 and shape [2]
# 	 [[{{node gradients/gradients_2/fnn/strided_slice_1_grad/StridedSliceGrad_grad/StridedSlice/gradients_2/fnn/strided_slice_1_grad/StridedSliceGrad/strides}}]]
# 2023-09-19 12:07:39.629615: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/gradients_2/fnn/strided_slice_2_grad/StridedSliceGrad_grad/StridedSlice/gradients_2/fnn/strided_slice_2_grad/StridedSliceGrad/strides' with dtype int32 and shape [2]
# 	 [[{{node gradients/gradients_2/fnn/strided_slice_2_grad/StridedSliceGrad_grad/StridedSlice/gradients_2/fnn/strided_slice_2_grad/StridedSliceGrad/strides}}]]
# 2023-09-19 12:07:39.630191: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/gradients_2/fnn/strided_slice_3_grad/StridedSliceGrad_grad/StridedSlice/gradients_2/fnn/strided_slice_3_grad/StridedSliceGrad/strides' with dtype int32 and shape [2]
# 	 [[{{node gradients/gradients_2/fnn/strided_slice_3_grad/StridedSliceGrad_grad/StridedSlice/gradients_2/fnn/strided_slice_3_grad/StridedSliceGrad/strides}}]]
# 2023-09-19 12:07:39.630760: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/gradients_2/fnn/strided_slice_4_grad/StridedSliceGrad_grad/StridedSlice/gradients_2/fnn/strided_slice_4_grad/StridedSliceGrad/strides' with dtype int32 and shape [2]
# 	 [[{{node gradients/gradients_2/fnn/strided_slice_4_grad/StridedSliceGrad_grad/StridedSlice/gradients_2/fnn/strided_slice_4_grad/StridedSliceGrad/strides}}]]
# 2023-09-19 12:07:39.631395: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/gradients_2/fnn/strided_slice_5_grad/StridedSliceGrad_grad/StridedSlice/gradients_2/fnn/strided_slice_5_grad/StridedSliceGrad/strides' with dtype int32 and shape [2]
# 	 [[{{node gradients/gradients_2/fnn/strided_slice_5_grad/StridedSliceGrad_grad/StridedSlice/gradients_2/fnn/strided_slice_5_grad/StridedSliceGrad/strides}}]]
# 2023-09-19 12:07:39.632036: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/gradients_2/fnn/strided_slice_6_grad/StridedSliceGrad_grad/StridedSlice/gradients_2/fnn/strided_slice_6_grad/StridedSliceGrad/strides' with dtype int32 and shape [2]
# 	 [[{{node gradients/gradients_2/fnn/strided_slice_6_grad/StridedSliceGrad_grad/StridedSlice/gradients_2/fnn/strided_slice_6_grad/StridedSliceGrad/strides}}]]
# 2023-09-19 12:07:39.632614: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/gradients_2/fnn/strided_slice_7_grad/StridedSliceGrad_grad/StridedSlice/gradients_2/fnn/strided_slice_7_grad/StridedSliceGrad/strides' with dtype int32 and shape [2]
# 	 [[{{node gradients/gradients_2/fnn/strided_slice_7_grad/StridedSliceGrad_grad/StridedSlice/gradients_2/fnn/strided_slice_7_grad/StridedSliceGrad/strides}}]]
# 2023-09-19 12:07:39.633195: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/gradients_2/fnn/strided_slice_8_grad/StridedSliceGrad_grad/StridedSlice/gradients_2/fnn/strided_slice_8_grad/StridedSliceGrad/strides' with dtype int32 and shape [2]
# 	 [[{{node gradients/gradients_2/fnn/strided_slice_8_grad/StridedSliceGrad_grad/StridedSlice/gradients_2/fnn/strided_slice_8_grad/StridedSliceGrad/strides}}]]
# 2023-09-19 12:07:39.633802: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/gradients_2/fnn/strided_slice_9_grad/StridedSliceGrad_grad/StridedSlice/gradients_2/fnn/strided_slice_9_grad/StridedSliceGrad/strides' with dtype int32 and shape [2]
# 	 [[{{node gradients/gradients_2/fnn/strided_slice_9_grad/StridedSliceGrad_grad/StridedSlice/gradients_2/fnn/strided_slice_9_grad/StridedSliceGrad/strides}}]]
# 2023-09-19 12:07:39.634366: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/gradients_2/fnn/strided_slice_10_grad/StridedSliceGrad_grad/StridedSlice/gradients_2/fnn/strided_slice_10_grad/StridedSliceGrad/strides' with dtype int32 and shape [2]
# 	 [[{{node gradients/gradients_2/fnn/strided_slice_10_grad/StridedSliceGrad_grad/StridedSlice/gradients_2/fnn/strided_slice_10_grad/StridedSliceGrad/strides}}]]
# 2023-09-19 12:07:39.634940: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/gradients_2/fnn/strided_slice_11_grad/StridedSliceGrad_grad/StridedSlice/gradients_2/fnn/strided_slice_11_grad/StridedSliceGrad/strides' with dtype int32 and shape [2]
# 	 [[{{node gradients/gradients_2/fnn/strided_slice_11_grad/StridedSliceGrad_grad/StridedSlice/gradients_2/fnn/strided_slice_11_grad/StridedSliceGrad/strides}}]]
# 2023-09-19 12:07:39.635541: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/gradients_2/fnn/strided_slice_12_grad/StridedSliceGrad_grad/StridedSlice/gradients_2/fnn/strided_slice_12_grad/StridedSliceGrad/strides' with dtype int32 and shape [2]
# 	 [[{{node gradients/gradients_2/fnn/strided_slice_12_grad/StridedSliceGrad_grad/StridedSlice/gradients_2/fnn/strided_slice_12_grad/StridedSliceGrad/strides}}]]
# 2023-09-19 12:07:39.636138: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/gradients_2/fnn/strided_slice_13_grad/StridedSliceGrad_grad/StridedSlice/gradients_2/fnn/strided_slice_13_grad/StridedSliceGrad/strides' with dtype int32 and shape [2]
# 	 [[{{node gradients/gradients_2/fnn/strided_slice_13_grad/StridedSliceGrad_grad/StridedSlice/gradients_2/fnn/strided_slice_13_grad/StridedSliceGrad/strides}}]]
# 2023-09-19 12:07:39.636724: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/gradients_2/fnn/strided_slice_14_grad/StridedSliceGrad_grad/StridedSlice/gradients_2/fnn/strided_slice_14_grad/StridedSliceGrad/strides' with dtype int32 and shape [2]
# 	 [[{{node gradients/gradients_2/fnn/strided_slice_14_grad/StridedSliceGrad_grad/StridedSlice/gradients_2/fnn/strided_slice_14_grad/StridedSliceGrad/strides}}]]
# 2023-09-19 12:07:39.637342: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/gradients_3/fnn/strided_slice_grad/StridedSliceGrad_grad/StridedSlice/gradients_3/fnn/strided_slice_grad/StridedSliceGrad/strides' with dtype int32 and shape [2]
# 	 [[{{node gradients/gradients_3/fnn/strided_slice_grad/StridedSliceGrad_grad/StridedSlice/gradients_3/fnn/strided_slice_grad/StridedSliceGrad/strides}}]]
# 2023-09-19 12:07:39.637972: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/gradients_3/fnn/strided_slice_1_grad/StridedSliceGrad_grad/StridedSlice/gradients_3/fnn/strided_slice_1_grad/StridedSliceGrad/strides' with dtype int32 and shape [2]
# 	 [[{{node gradients/gradients_3/fnn/strided_slice_1_grad/StridedSliceGrad_grad/StridedSlice/gradients_3/fnn/strided_slice_1_grad/StridedSliceGrad/strides}}]]
# 2023-09-19 12:07:39.638590: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/gradients_3/fnn/strided_slice_2_grad/StridedSliceGrad_grad/StridedSlice/gradients_3/fnn/strided_slice_2_grad/StridedSliceGrad/strides' with dtype int32 and shape [2]
# 	 [[{{node gradients/gradients_3/fnn/strided_slice_2_grad/StridedSliceGrad_grad/StridedSlice/gradients_3/fnn/strided_slice_2_grad/StridedSliceGrad/strides}}]]
# 2023-09-19 12:07:39.639193: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/gradients_3/fnn/strided_slice_3_grad/StridedSliceGrad_grad/StridedSlice/gradients_3/fnn/strided_slice_3_grad/StridedSliceGrad/strides' with dtype int32 and shape [2]
# 	 [[{{node gradients/gradients_3/fnn/strided_slice_3_grad/StridedSliceGrad_grad/StridedSlice/gradients_3/fnn/strided_slice_3_grad/StridedSliceGrad/strides}}]]
# 2023-09-19 12:07:39.639795: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/gradients_3/fnn/strided_slice_4_grad/StridedSliceGrad_grad/StridedSlice/gradients_3/fnn/strided_slice_4_grad/StridedSliceGrad/strides' with dtype int32 and shape [2]
# 	 [[{{node gradients/gradients_3/fnn/strided_slice_4_grad/StridedSliceGrad_grad/StridedSlice/gradients_3/fnn/strided_slice_4_grad/StridedSliceGrad/strides}}]]
# 2023-09-19 12:07:39.640410: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/gradients_3/fnn/strided_slice_5_grad/StridedSliceGrad_grad/StridedSlice/gradients_3/fnn/strided_slice_5_grad/StridedSliceGrad/strides' with dtype int32 and shape [2]
# 	 [[{{node gradients/gradients_3/fnn/strided_slice_5_grad/StridedSliceGrad_grad/StridedSlice/gradients_3/fnn/strided_slice_5_grad/StridedSliceGrad/strides}}]]
# 2023-09-19 12:07:39.641024: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/gradients_3/fnn/strided_slice_6_grad/StridedSliceGrad_grad/StridedSlice/gradients_3/fnn/strided_slice_6_grad/StridedSliceGrad/strides' with dtype int32 and shape [2]
# 	 [[{{node gradients/gradients_3/fnn/strided_slice_6_grad/StridedSliceGrad_grad/StridedSlice/gradients_3/fnn/strided_slice_6_grad/StridedSliceGrad/strides}}]]
# 2023-09-19 12:07:39.641670: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/gradients_3/fnn/strided_slice_7_grad/StridedSliceGrad_grad/StridedSlice/gradients_3/fnn/strided_slice_7_grad/StridedSliceGrad/strides' with dtype int32 and shape [2]
# 	 [[{{node gradients/gradients_3/fnn/strided_slice_7_grad/StridedSliceGrad_grad/StridedSlice/gradients_3/fnn/strided_slice_7_grad/StridedSliceGrad/strides}}]]
# 2023-09-19 12:07:39.642277: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/gradients_3/fnn/strided_slice_8_grad/StridedSliceGrad_grad/StridedSlice/gradients_3/fnn/strided_slice_8_grad/StridedSliceGrad/strides' with dtype int32 and shape [2]
# 	 [[{{node gradients/gradients_3/fnn/strided_slice_8_grad/StridedSliceGrad_grad/StridedSlice/gradients_3/fnn/strided_slice_8_grad/StridedSliceGrad/strides}}]]
# 2023-09-19 12:07:39.642864: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/gradients_3/fnn/strided_slice_9_grad/StridedSliceGrad_grad/StridedSlice/gradients_3/fnn/strided_slice_9_grad/StridedSliceGrad/strides' with dtype int32 and shape [2]
# 	 [[{{node gradients/gradients_3/fnn/strided_slice_9_grad/StridedSliceGrad_grad/StridedSlice/gradients_3/fnn/strided_slice_9_grad/StridedSliceGrad/strides}}]]
# 2023-09-19 12:07:39.643464: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/gradients_3/fnn/strided_slice_10_grad/StridedSliceGrad_grad/StridedSlice/gradients_3/fnn/strided_slice_10_grad/StridedSliceGrad/strides' with dtype int32 and shape [2]
# 	 [[{{node gradients/gradients_3/fnn/strided_slice_10_grad/StridedSliceGrad_grad/StridedSlice/gradients_3/fnn/strided_slice_10_grad/StridedSliceGrad/strides}}]]
# 2023-09-19 12:07:39.644069: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/gradients_3/fnn/strided_slice_11_grad/StridedSliceGrad_grad/StridedSlice/gradients_3/fnn/strided_slice_11_grad/StridedSliceGrad/strides' with dtype int32 and shape [2]
# 	 [[{{node gradients/gradients_3/fnn/strided_slice_11_grad/StridedSliceGrad_grad/StridedSlice/gradients_3/fnn/strided_slice_11_grad/StridedSliceGrad/strides}}]]
# 2023-09-19 12:07:39.644675: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/gradients_3/fnn/strided_slice_12_grad/StridedSliceGrad_grad/StridedSlice/gradients_3/fnn/strided_slice_12_grad/StridedSliceGrad/strides' with dtype int32 and shape [2]
# 	 [[{{node gradients/gradients_3/fnn/strided_slice_12_grad/StridedSliceGrad_grad/StridedSlice/gradients_3/fnn/strided_slice_12_grad/StridedSliceGrad/strides}}]]
# 2023-09-19 12:07:39.645204: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/gradients_3/fnn/strided_slice_13_grad/StridedSliceGrad_grad/StridedSlice/gradients_3/fnn/strided_slice_13_grad/StridedSliceGrad/strides' with dtype int32 and shape [2]
# 	 [[{{node gradients/gradients_3/fnn/strided_slice_13_grad/StridedSliceGrad_grad/StridedSlice/gradients_3/fnn/strided_slice_13_grad/StridedSliceGrad/strides}}]]
# 2023-09-19 12:07:39.645800: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/gradients_3/fnn/strided_slice_14_grad/StridedSliceGrad_grad/StridedSlice/gradients_3/fnn/strided_slice_14_grad/StridedSliceGrad/strides' with dtype int32 and shape [2]
# 	 [[{{node gradients/gradients_3/fnn/strided_slice_14_grad/StridedSliceGrad_grad/StridedSlice/gradients_3/fnn/strided_slice_14_grad/StridedSliceGrad/strides}}]]
# 2023-09-19 12:07:39.646372: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/gradients_4/fnn/strided_slice_grad/StridedSliceGrad_grad/StridedSlice/gradients_4/fnn/strided_slice_grad/StridedSliceGrad/strides' with dtype int32 and shape [2]
# 	 [[{{node gradients/gradients_4/fnn/strided_slice_grad/StridedSliceGrad_grad/StridedSlice/gradients_4/fnn/strided_slice_grad/StridedSliceGrad/strides}}]]
# 2023-09-19 12:07:39.647004: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/gradients_4/fnn/strided_slice_1_grad/StridedSliceGrad_grad/StridedSlice/gradients_4/fnn/strided_slice_1_grad/StridedSliceGrad/strides' with dtype int32 and shape [2]
# 	 [[{{node gradients/gradients_4/fnn/strided_slice_1_grad/StridedSliceGrad_grad/StridedSlice/gradients_4/fnn/strided_slice_1_grad/StridedSliceGrad/strides}}]]
# 2023-09-19 12:07:39.647566: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/gradients_4/fnn/strided_slice_2_grad/StridedSliceGrad_grad/StridedSlice/gradients_4/fnn/strided_slice_2_grad/StridedSliceGrad/strides' with dtype int32 and shape [2]
# 	 [[{{node gradients/gradients_4/fnn/strided_slice_2_grad/StridedSliceGrad_grad/StridedSlice/gradients_4/fnn/strided_slice_2_grad/StridedSliceGrad/strides}}]]
# 2023-09-19 12:07:39.648151: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/gradients_4/fnn/strided_slice_3_grad/StridedSliceGrad_grad/StridedSlice/gradients_4/fnn/strided_slice_3_grad/StridedSliceGrad/strides' with dtype int32 and shape [2]
# 	 [[{{node gradients/gradients_4/fnn/strided_slice_3_grad/StridedSliceGrad_grad/StridedSlice/gradients_4/fnn/strided_slice_3_grad/StridedSliceGrad/strides}}]]
# 2023-09-19 12:07:39.648728: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/gradients_4/fnn/strided_slice_4_grad/StridedSliceGrad_grad/StridedSlice/gradients_4/fnn/strided_slice_4_grad/StridedSliceGrad/strides' with dtype int32 and shape [2]
# 	 [[{{node gradients/gradients_4/fnn/strided_slice_4_grad/StridedSliceGrad_grad/StridedSlice/gradients_4/fnn/strided_slice_4_grad/StridedSliceGrad/strides}}]]
# 2023-09-19 12:07:39.649325: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/gradients_4/fnn/strided_slice_5_grad/StridedSliceGrad_grad/StridedSlice/gradients_4/fnn/strided_slice_5_grad/StridedSliceGrad/strides' with dtype int32 and shape [2]
# 	 [[{{node gradients/gradients_4/fnn/strided_slice_5_grad/StridedSliceGrad_grad/StridedSlice/gradients_4/fnn/strided_slice_5_grad/StridedSliceGrad/strides}}]]
# 2023-09-19 12:07:39.649904: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/gradients_4/fnn/strided_slice_6_grad/StridedSliceGrad_grad/StridedSlice/gradients_4/fnn/strided_slice_6_grad/StridedSliceGrad/strides' with dtype int32 and shape [2]
# 	 [[{{node gradients/gradients_4/fnn/strided_slice_6_grad/StridedSliceGrad_grad/StridedSlice/gradients_4/fnn/strided_slice_6_grad/StridedSliceGrad/strides}}]]
# 2023-09-19 12:07:39.650489: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/gradients_4/fnn/strided_slice_7_grad/StridedSliceGrad_grad/StridedSlice/gradients_4/fnn/strided_slice_7_grad/StridedSliceGrad/strides' with dtype int32 and shape [2]
# 	 [[{{node gradients/gradients_4/fnn/strided_slice_7_grad/StridedSliceGrad_grad/StridedSlice/gradients_4/fnn/strided_slice_7_grad/StridedSliceGrad/strides}}]]
# 2023-09-19 12:07:39.651129: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/gradients_4/fnn/strided_slice_8_grad/StridedSliceGrad_grad/StridedSlice/gradients_4/fnn/strided_slice_8_grad/StridedSliceGrad/strides' with dtype int32 and shape [2]
# 	 [[{{node gradients/gradients_4/fnn/strided_slice_8_grad/StridedSliceGrad_grad/StridedSlice/gradients_4/fnn/strided_slice_8_grad/StridedSliceGrad/strides}}]]
# 2023-09-19 12:07:39.651715: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/gradients_4/fnn/strided_slice_9_grad/StridedSliceGrad_grad/StridedSlice/gradients_4/fnn/strided_slice_9_grad/StridedSliceGrad/strides' with dtype int32 and shape [2]
# 	 [[{{node gradients/gradients_4/fnn/strided_slice_9_grad/StridedSliceGrad_grad/StridedSlice/gradients_4/fnn/strided_slice_9_grad/StridedSliceGrad/strides}}]]
# 2023-09-19 12:07:39.652319: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/gradients_4/fnn/strided_slice_10_grad/StridedSliceGrad_grad/StridedSlice/gradients_4/fnn/strided_slice_10_grad/StridedSliceGrad/strides' with dtype int32 and shape [2]
# 	 [[{{node gradients/gradients_4/fnn/strided_slice_10_grad/StridedSliceGrad_grad/StridedSlice/gradients_4/fnn/strided_slice_10_grad/StridedSliceGrad/strides}}]]
# 2023-09-19 12:07:39.652906: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/gradients_4/fnn/strided_slice_11_grad/StridedSliceGrad_grad/StridedSlice/gradients_4/fnn/strided_slice_11_grad/StridedSliceGrad/strides' with dtype int32 and shape [2]
# 	 [[{{node gradients/gradients_4/fnn/strided_slice_11_grad/StridedSliceGrad_grad/StridedSlice/gradients_4/fnn/strided_slice_11_grad/StridedSliceGrad/strides}}]]
# 2023-09-19 12:07:39.653468: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/gradients_4/fnn/strided_slice_12_grad/StridedSliceGrad_grad/StridedSlice/gradients_4/fnn/strided_slice_12_grad/StridedSliceGrad/strides' with dtype int32 and shape [2]
# 	 [[{{node gradients/gradients_4/fnn/strided_slice_12_grad/StridedSliceGrad_grad/StridedSlice/gradients_4/fnn/strided_slice_12_grad/StridedSliceGrad/strides}}]]
# 2023-09-19 12:07:39.654072: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/gradients_4/fnn/strided_slice_13_grad/StridedSliceGrad_grad/StridedSlice/gradients_4/fnn/strided_slice_13_grad/StridedSliceGrad/strides' with dtype int32 and shape [2]
# 	 [[{{node gradients/gradients_4/fnn/strided_slice_13_grad/StridedSliceGrad_grad/StridedSlice/gradients_4/fnn/strided_slice_13_grad/StridedSliceGrad/strides}}]]
# 2023-09-19 12:07:39.654666: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/gradients_4/fnn/strided_slice_14_grad/StridedSliceGrad_grad/StridedSlice/gradients_4/fnn/strided_slice_14_grad/StridedSliceGrad/strides' with dtype int32 and shape [2]
# 	 [[{{node gradients/gradients_4/fnn/strided_slice_14_grad/StridedSliceGrad_grad/StridedSlice/gradients_4/fnn/strided_slice_14_grad/StridedSliceGrad/strides}}]]
# 2023-09-19 12:07:39.655282: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/gradients_5/fnn/strided_slice_grad/StridedSliceGrad_grad/StridedSlice/gradients_5/fnn/strided_slice_grad/StridedSliceGrad/strides' with dtype int32 and shape [2]
# 	 [[{{node gradients/gradients_5/fnn/strided_slice_grad/StridedSliceGrad_grad/StridedSlice/gradients_5/fnn/strided_slice_grad/StridedSliceGrad/strides}}]]
# 2023-09-19 12:07:39.655860: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/gradients_5/fnn/strided_slice_1_grad/StridedSliceGrad_grad/StridedSlice/gradients_5/fnn/strided_slice_1_grad/StridedSliceGrad/strides' with dtype int32 and shape [2]
# 	 [[{{node gradients/gradients_5/fnn/strided_slice_1_grad/StridedSliceGrad_grad/StridedSlice/gradients_5/fnn/strided_slice_1_grad/StridedSliceGrad/strides}}]]
# 2023-09-19 12:07:39.656437: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/gradients_5/fnn/strided_slice_2_grad/StridedSliceGrad_grad/StridedSlice/gradients_5/fnn/strided_slice_2_grad/StridedSliceGrad/strides' with dtype int32 and shape [2]
# 	 [[{{node gradients/gradients_5/fnn/strided_slice_2_grad/StridedSliceGrad_grad/StridedSlice/gradients_5/fnn/strided_slice_2_grad/StridedSliceGrad/strides}}]]
# ...
# 	 [[{{node gradients/gradients_13/fnn/strided_slice_11_grad/StridedSliceGrad_grad/StridedSlice/gradients_13/fnn/strided_slice_11_grad/StridedSliceGrad/strides}}]]
# 2023-09-19 12:07:39.734302: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/gradients_13/fnn/strided_slice_12_grad/StridedSliceGrad_grad/StridedSlice/gradients_13/fnn/strided_slice_12_grad/StridedSliceGrad/strides' with dtype int32 and shape [2]
# 	 [[{{node gradients/gradients_13/fnn/strided_slice_12_grad/StridedSliceGrad_grad/StridedSlice/gradients_13/fnn/strided_slice_12_grad/StridedSliceGrad/strides}}]]
# 2023-09-19 12:07:39.734855: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/gradients_13/fnn/strided_slice_13_grad/StridedSliceGrad_grad/StridedSlice/gradients_13/fnn/strided_slice_13_grad/StridedSliceGrad/strides' with dtype int32 and shape [2]
# 	 [[{{node gradients/gradients_13/fnn/strided_slice_13_grad/StridedSliceGrad_grad/StridedSlice/gradients_13/fnn/strided_slice_13_grad/StridedSliceGrad/strides}}]]
# 2023-09-19 12:07:39.735411: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/gradients_13/fnn/strided_slice_14_grad/StridedSliceGrad_grad/StridedSlice/gradients_13/fnn/strided_slice_14_grad/StridedSliceGrad/strides' with dtype int32 and shape [2]
# 	 [[{{node gradients/gradients_13/fnn/strided_slice_14_grad/StridedSliceGrad_grad/StridedSlice/gradients_13/fnn/strided_slice_14_grad/StridedSliceGrad/strides}}]]
# 2023-09-19 12:07:39.736084: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/gradients_14/fnn/strided_slice_grad/StridedSliceGrad_grad/StridedSlice/gradients_14/fnn/strided_slice_grad/StridedSliceGrad/strides' with dtype int32 and shape [2]
# 	 [[{{node gradients/gradients_14/fnn/strided_slice_grad/StridedSliceGrad_grad/StridedSlice/gradients_14/fnn/strided_slice_grad/StridedSliceGrad/strides}}]]
# 2023-09-19 12:07:39.736650: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/gradients_14/fnn/strided_slice_1_grad/StridedSliceGrad_grad/StridedSlice/gradients_14/fnn/strided_slice_1_grad/StridedSliceGrad/strides' with dtype int32 and shape [2]
# 	 [[{{node gradients/gradients_14/fnn/strided_slice_1_grad/StridedSliceGrad_grad/StridedSlice/gradients_14/fnn/strided_slice_1_grad/StridedSliceGrad/strides}}]]
# 2023-09-19 12:07:39.737254: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/gradients_14/fnn/strided_slice_2_grad/StridedSliceGrad_grad/StridedSlice/gradients_14/fnn/strided_slice_2_grad/StridedSliceGrad/strides' with dtype int32 and shape [2]
# 	 [[{{node gradients/gradients_14/fnn/strided_slice_2_grad/StridedSliceGrad_grad/StridedSlice/gradients_14/fnn/strided_slice_2_grad/StridedSliceGrad/strides}}]]
# 2023-09-19 12:07:39.737868: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/gradients_14/fnn/strided_slice_3_grad/StridedSliceGrad_grad/StridedSlice/gradients_14/fnn/strided_slice_3_grad/StridedSliceGrad/strides' with dtype int32 and shape [2]
# 	 [[{{node gradients/gradients_14/fnn/strided_slice_3_grad/StridedSliceGrad_grad/StridedSlice/gradients_14/fnn/strided_slice_3_grad/StridedSliceGrad/strides}}]]
# 2023-09-19 12:07:39.738449: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/gradients_14/fnn/strided_slice_4_grad/StridedSliceGrad_grad/StridedSlice/gradients_14/fnn/strided_slice_4_grad/StridedSliceGrad/strides' with dtype int32 and shape [2]
# 	 [[{{node gradients/gradients_14/fnn/strided_slice_4_grad/StridedSliceGrad_grad/StridedSlice/gradients_14/fnn/strided_slice_4_grad/StridedSliceGrad/strides}}]]
# 2023-09-19 12:07:39.739021: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/gradients_14/fnn/strided_slice_5_grad/StridedSliceGrad_grad/StridedSlice/gradients_14/fnn/strided_slice_5_grad/StridedSliceGrad/strides' with dtype int32 and shape [2]
# 	 [[{{node gradients/gradients_14/fnn/strided_slice_5_grad/StridedSliceGrad_grad/StridedSlice/gradients_14/fnn/strided_slice_5_grad/StridedSliceGrad/strides}}]]
# 2023-09-19 12:07:39.739591: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/gradients_14/fnn/strided_slice_6_grad/StridedSliceGrad_grad/StridedSlice/gradients_14/fnn/strided_slice_6_grad/StridedSliceGrad/strides' with dtype int32 and shape [2]
# 	 [[{{node gradients/gradients_14/fnn/strided_slice_6_grad/StridedSliceGrad_grad/StridedSlice/gradients_14/fnn/strided_slice_6_grad/StridedSliceGrad/strides}}]]
# 2023-09-19 12:07:39.740170: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/gradients_14/fnn/strided_slice_7_grad/StridedSliceGrad_grad/StridedSlice/gradients_14/fnn/strided_slice_7_grad/StridedSliceGrad/strides' with dtype int32 and shape [2]
# 	 [[{{node gradients/gradients_14/fnn/strided_slice_7_grad/StridedSliceGrad_grad/StridedSlice/gradients_14/fnn/strided_slice_7_grad/StridedSliceGrad/strides}}]]
# 2023-09-19 12:07:39.740765: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/gradients_14/fnn/strided_slice_8_grad/StridedSliceGrad_grad/StridedSlice/gradients_14/fnn/strided_slice_8_grad/StridedSliceGrad/strides' with dtype int32 and shape [2]
# 	 [[{{node gradients/gradients_14/fnn/strided_slice_8_grad/StridedSliceGrad_grad/StridedSlice/gradients_14/fnn/strided_slice_8_grad/StridedSliceGrad/strides}}]]
# 2023-09-19 12:07:39.741353: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/gradients_14/fnn/strided_slice_9_grad/StridedSliceGrad_grad/StridedSlice/gradients_14/fnn/strided_slice_9_grad/StridedSliceGrad/strides' with dtype int32 and shape [2]
# 	 [[{{node gradients/gradients_14/fnn/strided_slice_9_grad/StridedSliceGrad_grad/StridedSlice/gradients_14/fnn/strided_slice_9_grad/StridedSliceGrad/strides}}]]
# 2023-09-19 12:07:39.741947: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/gradients_14/fnn/strided_slice_10_grad/StridedSliceGrad_grad/StridedSlice/gradients_14/fnn/strided_slice_10_grad/StridedSliceGrad/strides' with dtype int32 and shape [2]
# 	 [[{{node gradients/gradients_14/fnn/strided_slice_10_grad/StridedSliceGrad_grad/StridedSlice/gradients_14/fnn/strided_slice_10_grad/StridedSliceGrad/strides}}]]
# 2023-09-19 12:07:39.742523: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/gradients_14/fnn/strided_slice_11_grad/StridedSliceGrad_grad/StridedSlice/gradients_14/fnn/strided_slice_11_grad/StridedSliceGrad/strides' with dtype int32 and shape [2]
# 	 [[{{node gradients/gradients_14/fnn/strided_slice_11_grad/StridedSliceGrad_grad/StridedSlice/gradients_14/fnn/strided_slice_11_grad/StridedSliceGrad/strides}}]]
# 2023-09-19 12:07:39.743093: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/gradients_14/fnn/strided_slice_12_grad/StridedSliceGrad_grad/StridedSlice/gradients_14/fnn/strided_slice_12_grad/StridedSliceGrad/strides' with dtype int32 and shape [2]
# 	 [[{{node gradients/gradients_14/fnn/strided_slice_12_grad/StridedSliceGrad_grad/StridedSlice/gradients_14/fnn/strided_slice_12_grad/StridedSliceGrad/strides}}]]
# 2023-09-19 12:07:39.743662: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/gradients_14/fnn/strided_slice_13_grad/StridedSliceGrad_grad/StridedSlice/gradients_14/fnn/strided_slice_13_grad/StridedSliceGrad/strides' with dtype int32 and shape [2]
# 	 [[{{node gradients/gradients_14/fnn/strided_slice_13_grad/StridedSliceGrad_grad/StridedSlice/gradients_14/fnn/strided_slice_13_grad/StridedSliceGrad/strides}}]]
# 2023-09-19 12:07:39.744229: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/gradients_14/fnn/strided_slice_14_grad/StridedSliceGrad_grad/StridedSlice/gradients_14/fnn/strided_slice_14_grad/StridedSliceGrad/strides' with dtype int32 and shape [2]
# 	 [[{{node gradients/gradients_14/fnn/strided_slice_14_grad/StridedSliceGrad_grad/StridedSlice/gradients_14/fnn/strided_slice_14_grad/StridedSliceGrad/strides}}]]
# 1000      [2.35e-02, 1.62e-02, 6.99e-02, 2.10e-01, 2.20e-03, 1.94e-01, 2.04e-01, 5.27e-02, 7.37e-02, 4.57e-02, 6.58e-02, 2.69e-04, 4.67e-05, 2.21e-03, 1.33e-02, 4.06e-03, 5.50e-02, 3.15e-01, 5.39e-01, 5.42e-02, 1.36e+00, 1.79e-02, 5.12e-02]    [2.31e-02, 1.60e-02, 7.00e-02, 1.28e-01, 2.28e-03, 1.98e-01, 2.07e-01, 4.82e-02, 6.48e-02, 4.64e-02, 6.09e-02, 2.00e-04, 3.95e-05, 2.23e-03, 1.15e-02, 4.11e-03, 5.50e-02, 3.15e-01, 5.39e-01, 5.42e-02, 1.36e+00, 1.79e-02, 5.12e-02]    []
# 2000      [3.21e-03, 2.84e-03, 7.65e-03, 1.14e-01, 4.69e-04, 3.30e-02, 3.51e-02, 2.10e-02, 1.87e-02, 7.70e-03, 1.27e-02, 2.50e-04, 6.61e-05, 4.48e-04, 3.35e-03, 3.51e-04, 1.53e-02, 1.70e-01, 7.18e-02, 1.84e-03, 2.98e-01, 5.85e-03, 1.15e-02]    [2.91e-03, 2.66e-03, 7.43e-03, 3.10e-02, 4.71e-04, 3.32e-02, 3.54e-02, 2.18e-02, 1.88e-02, 7.62e-03, 1.16e-02, 1.61e-04, 6.40e-05, 4.47e-04, 3.21e-03, 3.65e-04, 1.53e-02, 1.70e-01, 7.18e-02, 1.84e-03, 2.98e-01, 5.85e-03, 1.15e-02]    []
# 3000      [3.54e-03, 5.49e-03, 3.77e-03, 8.86e-02, 1.08e-04, 8.15e-03, 7.60e-03, 6.31e-04, 1.46e-03, 1.42e-03, 2.25e-03, 8.77e-05, 6.39e-05, 1.33e-04, 6.97e-03, 5.74e-04, 1.44e-02, 6.12e-02, 8.71e-03, 7.74e-04, 2.45e-01, 5.37e-03, 1.07e-02]    [3.45e-03, 5.52e-03, 3.10e-03, 1.07e-02, 1.04e-04, 7.94e-03, 7.47e-03, 5.96e-04, 1.19e-03, 1.16e-03, 1.76e-03, 7.81e-05, 6.20e-05, 1.31e-04, 7.21e-03, 5.95e-04, 1.44e-02, 6.12e-02, 8.71e-03, 7.74e-04, 2.45e-01, 5.37e-03, 1.07e-02]    []
# 4000      [1.11e-01, 3.94e-02, 1.35e-01, 8.42e-02, 3.06e-05, 1.81e-03, 3.03e-03, 1.50e-02, 1.08e-03, 8.15e-04, 6.27e-04, 9.64e-05, 3.83e-05, 6.25e-05, 1.35e-01, 1.26e-03, 5.59e-02, 4.02e-02, 1.27e-02, 3.81e-03, 1.15e+00, 2.40e-02, 4.70e-02]    [1.14e-01, 4.08e-02, 1.38e-01, 5.83e-03, 2.86e-05, 1.57e-03, 2.73e-03, 1.52e-02, 1.10e-03, 5.74e-04, 4.85e-04, 9.36e-05, 3.64e-05, 6.29e-05, 1.39e-01, 1.30e-03, 5.59e-02, 4.02e-02, 1.27e-02, 3.81e-03, 1.15e+00, 2.40e-02, 4.70e-02]    []
# 5000      [1.36e-02, 6.06e-04, 2.12e-02, 8.39e-02, 1.94e-05, 6.43e-04, 6.61e-04, 9.94e-04, 9.28e-04, 5.26e-04, 1.42e-04, 4.29e-05, 5.37e-05, 2.85e-05, 8.63e-03, 2.14e-03, 8.86e-03, 7.90e-03, 2.78e-03, 6.09e-04, 1.71e-01, 3.58e-03, 6.34e-03]    [1.38e-02, 5.38e-04, 2.07e-02, 4.11e-03, 2.00e-05, 5.04e-04, 4.35e-04, 1.02e-03, 7.28e-04, 2.91e-04, 9.04e-05, 4.07e-05, 5.31e-05, 2.91e-05, 8.65e-03, 2.19e-03, 8.86e-03, 7.90e-03, 2.78e-03, 6.09e-04, 1.71e-01, 3.58e-03, 6.34e-03]    []
# 6000      [1.15e-01, 1.45e-02, 9.44e-02, 8.36e-02, 1.88e-05, 4.66e-04, 4.32e-04, 6.10e-03, 2.36e-03, 3.82e-04, 1.51e-04, 4.51e-05, 3.87e-05, 1.75e-05, 1.02e-01, 2.77e-03, 5.87e-03, 4.41e-03, 2.37e-03, 4.76e-04, 1.19e-01, 2.72e-03, 4.06e-03]    [1.19e-01, 1.51e-02, 9.71e-02, 3.60e-03, 1.98e-05, 3.85e-04, 2.76e-04, 6.04e-03, 2.39e-03, 2.07e-04, 1.18e-04, 4.50e-05, 3.87e-05, 1.74e-05, 1.06e-01, 2.83e-03, 5.87e-03, 4.41e-03, 2.37e-03, 4.76e-04, 1.19e-01, 2.72e-03, 4.06e-03]    []
# 7000      [2.59e-03, 5.62e-04, 4.60e-03, 8.34e-02, 1.38e-05, 2.66e-04, 3.69e-04, 4.28e-04, 2.76e-04, 2.94e-04, 1.16e-04, 3.31e-05, 4.34e-05, 1.80e-05, 1.78e-03, 3.15e-03, 5.01e-03, 2.03e-03, 2.12e-03, 3.95e-04, 1.00e-01, 2.27e-03, 3.34e-03]    [2.63e-03, 5.06e-04, 4.42e-03, 3.38e-03, 1.45e-05, 2.30e-04, 2.38e-04, 3.90e-04, 2.22e-04, 1.18e-04, 8.93e-05, 3.33e-05, 4.29e-05, 1.75e-05, 1.84e-03, 3.21e-03, 5.01e-03, 2.03e-03, 2.12e-03, 3.95e-04, 1.00e-01, 2.27e-03, 3.34e-03]    []
# 8000      [1.08e-01, 1.19e-02, 8.13e-02, 8.32e-02, 1.00e-05, 3.45e-04, 3.62e-04, 5.28e-03, 3.90e-03, 2.63e-04, 2.85e-04, 2.82e-05, 4.34e-05, 2.13e-05, 9.37e-02, 3.51e-03, 3.66e-03, 6.46e-04, 1.60e-03, 3.34e-04, 7.14e-02, 1.65e-03, 2.13e-03]    [1.11e-01, 1.22e-02, 8.20e-02, 3.46e-03, 1.03e-05, 3.30e-04, 2.56e-04, 5.40e-03, 4.11e-03, 1.14e-04, 2.87e-04, 2.82e-05, 4.34e-05, 2.16e-05, 9.59e-02, 3.58e-03, 3.66e-03, 6.46e-04, 1.60e-03, 3.34e-04, 7.14e-02, 1.65e-03, 2.13e-03]    []
# 9000      [1.30e-01, 2.93e-02, 7.99e-03, 8.27e-02, 1.39e-05, 6.64e-04, 2.97e-04, 1.45e-02, 5.18e-02, 6.88e-04, 1.95e-03, 3.29e-05, 3.59e-05, 1.96e-05, 1.38e-01, 4.06e-03, 4.53e-03, 4.37e-04, 1.63e-03, 2.19e-04, 7.29e-02, 1.73e-03, 2.24e-03]    [1.34e-01, 3.01e-02, 8.12e-03, 3.74e-03, 1.41e-05, 6.53e-04, 2.09e-04, 1.51e-02, 5.34e-02, 5.20e-04, 1.98e-03, 3.28e-05, 3.60e-05, 2.07e-05, 1.42e-01, 4.15e-03, 4.53e-03, 4.37e-04, 1.63e-03, 2.19e-04, 7.29e-02, 1.73e-03, 2.24e-03]    []
# 10000     [1.13e-03, 5.01e-04, 1.46e-03, 8.24e-02, 1.93e-05, 2.76e-04, 3.13e-04, 2.83e-04, 4.15e-04, 1.48e-04, 1.47e-04, 3.21e-05, 3.42e-05, 1.91e-05, 9.80e-04, 3.95e-03, 1.35e-03, 8.51e-04, 8.03e-04, 1.49e-04, 2.63e-02, 6.56e-04, 5.91e-04]    [1.13e-03, 4.99e-04, 1.32e-03, 3.95e-03, 1.97e-05, 2.68e-04, 2.41e-04, 2.46e-04, 3.33e-04, 2.49e-05, 1.04e-04, 3.21e-05, 3.36e-05, 1.98e-05, 9.87e-04, 4.03e-03, 1.35e-03, 8.51e-04, 8.03e-04, 1.49e-04, 2.63e-02, 6.56e-04, 5.91e-04]    []
#
# Best model at step 10000:
#   train loss: 1.23e-01
#   test loss: 4.39e-02
#   test metric: []
#
# 'train' took 174.909021 s

# %%
dde.saveplot(losshistory, train_state, issave=True, isplot=True)
# Out:
# Saving loss history to /Users/vassilis/Documents/GitHub/PFAS_PBK_models/PFAS Rainbow trout PBK/PINN/DeepXDE_implementation/loss.dat ...
# Saving training data to /Users/vassilis/Documents/GitHub/PFAS_PBK_models/PFAS Rainbow trout PBK/PINN/DeepXDE_implementation/train.dat ...
# Saving test data to /Users/vassilis/Documents/GitHub/PFAS_PBK_models/PFAS Rainbow trout PBK/PINN/DeepXDE_implementation/test.dat ...

# %%
model.state_dict()
# Out:
# {'external_trainable_variable:0': <tf.Variable 'Variable:0' shape=() dtype=float32, numpy=1.717123>,
#  'external_trainable_variable:1': <tf.Variable 'Variable:0' shape=() dtype=float32, numpy=0.28000808>,
#  'external_trainable_variable:2': <tf.Variable 'Variable:0' shape=() dtype=float32, numpy=0.6080553>,
#  'external_trainable_variable:3': <tf.Variable 'Variable:0' shape=() dtype=float32, numpy=0.35327858>,
#  'external_trainable_variable:4': <tf.Variable 'Variable:0' shape=() dtype=float32, numpy=0.35949036>,
#  'external_trainable_variable:5': <tf.Variable 'Variable:0' shape=() dtype=float32, numpy=0.14167123>,
#  'external_trainable_variable:6': <tf.Variable 'Variable:0' shape=() dtype=float32, numpy=0.4141297>,
#  'denses.0.kernel': <tf.Variable 'fnn/dense/kernel:0' shape=(1, 30) dtype=float32, numpy=
#  array([[ 0.00821015, -0.00765151,  0.16034117, -0.29963487, -0.07012183,
#          -0.0666461 , -0.00106321,  0.00585792, -0.00204428, -0.34374434,
#           0.51421577, -0.30597305,  0.1144396 ,  0.03976092, -0.03580924,
#          -0.1649676 , -0.08148369, -0.06206064, -0.00119734, -0.15545332,
#           0.11052337,  0.00266867, -0.07531507,  0.3206231 ,  0.2792782 ,
#           0.47039974,  0.0394985 ,  0.09761158,  0.00113987, -0.38959944]],
#        dtype=float32)>,
#  'denses.0.bias': <tf.Variable 'fnn/dense/bias:0' shape=(30,) dtype=float32, numpy=
#  array([ 0.05634662, -0.03269504,  0.50958395,  0.1477637 , -0.18803097,
#          0.11265697,  0.38455918, -0.24865733,  0.20593533,  0.39909816,
#          1.4364231 , -0.06899479,  0.09428404,  0.5004307 , -0.11252088,
#         -0.01995158, -0.03719607, -0.04654513,  0.47002804,  0.05287679,
#         -0.26602763, -0.6511385 , -0.09499587, -0.16643941,  0.05686937,
#         -0.23803014, -0.01200484, -0.21499294, -0.7792161 , -0.2747057 ],
#        dtype=float32)>,
#  'denses.1.kernel': <tf.Variable 'fnn/dense_1/kernel:0' shape=(30, 30) dtype=float32, numpy=
#  array([[ 2.65551899e-02, -9.44065526e-02,  1.65994361e-01,
#          -1.27026379e-01, -2.08951280e-01, -4.80206460e-02,
#          -1.84372604e-01,  8.98716375e-02,  3.88368219e-02,
#          -2.57767677e-01,  4.32232738e-01, -3.07105631e-01,
#           1.14322618e-01,  1.41251415e-01, -7.90138319e-02,
#          -1.46490484e-01, -9.36534349e-03, -1.74688771e-01,
#           1.91862881e-02, -4.77870069e-02,  6.37639835e-02,
#           3.22208107e-02, -4.09844592e-02,  2.95829922e-01,
#           1.31368339e-01,  2.20473975e-01,  2.42476761e-02,
#           1.19779520e-01,  4.81511913e-02, -2.78390676e-01],
#         [-3.17610577e-02, -5.23494370e-03,  7.78305754e-02,
#          -2.11624920e-01, -4.13694642e-02, -1.15035430e-01,
#          -5.14428318e-02, -1.70170441e-01, -1.64182976e-01,
#          -2.70271927e-01,  2.59630799e-01,  5.96453846e-02,
#           7.59523511e-02,  3.19000274e-01,  1.83371276e-01,
#          -2.45144200e-02,  1.27613574e-01, -9.19291452e-02,
#           6.98116198e-02, -7.12106079e-02,  5.85707463e-02,
#           8.09874833e-02, -2.89856613e-01, -1.57866642e-01,
#          -1.20701000e-01, -1.00051500e-01,  9.15880948e-02,
#          -7.80784190e-02, -3.01754236e-01,  9.58692729e-02],
#         [ 1.75196216e-01,  1.32167459e-01,  3.59848022e-01,
#           1.11949891e-02, -1.16207406e-01,  2.61196136e-01,
#           4.26717475e-02, -9.16148126e-02,  1.53996781e-01,
#          -2.89137334e-01, -1.53090665e-02, -1.13494441e-01,
#          -3.60674500e-01, -1.28719524e-01, -7.56455660e-02,
#          -1.29189432e-01,  1.73006251e-01, -1.53720811e-01,
#          -3.49953681e-01,  6.15818202e-02, -2.85892338e-01,
#          -2.67989468e-02,  3.07546973e-01,  1.01355277e-01,
#           3.97557855e-01, -2.24237796e-03,  2.69778401e-01,
#           2.70227417e-02,  1.82026535e-01,  1.55665958e-03],
#         [ 2.90434230e-02,  6.02783263e-02, -9.05225053e-03,
#          -2.17620701e-01, -1.58001363e-01, -9.64644328e-02,
#          -8.00041556e-02, -9.68323499e-02,  2.19642967e-01,
#          -9.93348733e-02,  4.89279665e-02,  5.14188036e-02,
#           3.43448967e-01,  1.76801324e-01,  6.73138127e-02,
#          -3.72487009e-01, -3.28057632e-02, -1.97268590e-01,
#          -1.79902613e-01,  4.15948965e-02,  3.22939306e-02,
#          -2.52008587e-01, -4.17028330e-02,  3.32290620e-01,
#           2.60696024e-01,  2.92566754e-02,  7.31775016e-02,
#           2.99218863e-01, -6.14865310e-02,  7.99492225e-02],
#         [-4.55871113e-02, -2.86853045e-01, -1.44747972e-01,
#           6.26361966e-02, -2.96595365e-01, -1.55795947e-01,
#           1.92058682e-01, -3.80506098e-01, -1.01645291e-01,
#           5.08797318e-02, -7.72736445e-02, -1.86282963e-01,
#          -2.23893508e-01,  1.92522347e-01,  2.13845938e-01,
#          -2.06534296e-01,  6.01839758e-02,  7.20003620e-02,
#           1.94112480e-01, -4.09006059e-01, -7.42393062e-02,
#          -1.41341670e-03,  2.04878449e-01,  1.22918330e-01,
#          -1.04722805e-01, -8.71366411e-02,  2.05993608e-01,
#           6.66882172e-02,  1.84035391e-01,  1.91249885e-02],
#         [-1.62471995e-01, -2.49000102e-01, -5.76974824e-02,
#          -2.98699401e-02,  2.98759967e-01,  7.81329423e-02,
#          -1.69798195e-01,  6.09572567e-02,  8.70973244e-03,
#          -1.79299548e-01, -5.21743782e-02, -1.44030854e-01,
#           1.92705780e-01,  2.38118507e-02,  1.83408871e-01,
#          -1.04067273e-01, -1.89449131e-01,  6.87251315e-02,
#          -1.55459762e-01,  1.62085921e-01,  9.92688388e-02,
#           7.82118440e-02, -2.43212476e-01,  2.75110602e-01,
#           2.88265616e-01, -7.80057907e-02,  4.10425812e-02,
#           7.67959431e-02, -9.42579284e-02, -5.81713878e-02],
#         [ 1.44506201e-01,  1.47512347e-01, -9.45465788e-02,
#          -6.87182471e-02, -1.18606031e-01,  1.51455775e-01,
#          -7.38527358e-01, -1.70755491e-01, -1.10067345e-01,
#          -1.04018405e-01, -2.92216148e-02,  1.16413467e-01,
#          -9.61475223e-02,  6.69605285e-02, -1.77070666e-02,
#           3.36741030e-01,  5.44457743e-03,  8.17825422e-02,
#           2.36700580e-01, -9.61288214e-02,  3.12663734e-01,
#           1.51614890e-01, -3.16324055e-01,  1.13793179e-01,
#           1.74368128e-01,  9.66118202e-02,  1.82231486e-01,
#          -1.08514957e-01,  2.61669219e-01, -1.60734449e-02],
#         [-3.30110222e-01, -1.51088297e-01, -2.97399182e-02,
#           1.92507878e-01, -2.03422636e-01, -2.75982614e-03,
#          -1.28784720e-02,  5.29318163e-03,  3.93442929e-01,
#           3.20933163e-02,  3.19581538e-01, -1.73739061e-01,
#           1.26253366e-01,  2.21221112e-02, -3.73729318e-01,
#          -2.04266042e-01, -2.03124911e-01, -1.95718452e-01,
#           1.59214914e-01, -1.63300615e-02,  5.66981733e-04,
#           1.13862716e-01,  2.86929101e-01,  2.75047366e-02,
#           1.76790416e-01,  2.18914583e-01, -5.02884164e-02,
#          -1.00963831e-01, -1.20655723e-01, -8.81135240e-02],
#         [-3.64932239e-01, -7.24240169e-02, -2.63648212e-01,
#           6.78727031e-02,  2.67717503e-02, -2.38556471e-02,
#          -4.05464977e-01,  6.34797476e-03,  1.65621415e-01,
#          -1.41356692e-01,  1.73017576e-01,  5.20289019e-02,
#          -7.76693895e-02, -2.72368252e-01,  2.99101084e-01,
#          -1.91529900e-01, -8.46867040e-02, -2.44579479e-01,
#           2.19300613e-01,  2.45189577e-01,  1.22293256e-01,
#           3.12569551e-02, -2.53007323e-01,  5.62705919e-02,
#           9.08755362e-02,  2.62892276e-01,  1.86210088e-02,
#           1.78287953e-01, -1.22990102e-01, -2.49358654e-01],
#         [ 1.30637899e-01, -1.23990983e-01,  1.90830693e-01,
#          -1.90659314e-01,  2.29522237e-03,  1.08879201e-01,
#           5.59602748e-04, -3.62881310e-02, -3.27971995e-01,
#          -2.05419362e-01,  1.10700347e-01, -1.19530270e-02,
#          -5.02093397e-02, -4.90142070e-02,  1.61601469e-01,
#          -2.15594754e-01,  1.02299161e-01,  1.61902055e-01,
#          -2.06999630e-01, -7.15012550e-02,  9.70364064e-02,
#           2.94557601e-01,  2.63793170e-01,  2.20803842e-01,
#           5.38695492e-02,  1.58369541e-01,  2.40605287e-02,
#           4.02672440e-01, -7.60066509e-03,  2.89246380e-01],
#         [-2.37996923e-03, -5.84484125e-03,  1.00749590e-01,
#          -2.43537799e-01,  1.24555893e-01,  1.18569084e-01,
#          -1.31255195e-01,  7.35273734e-02,  5.84235135e-03,
#          -8.28359872e-02,  3.66759300e-01,  1.27756819e-01,
#           1.18104346e-01,  3.14728171e-03, -1.12863243e-01,
#          -2.37404749e-01,  1.56548545e-01, -4.73754408e-05,
#          -9.73868966e-02,  3.25933367e-01, -1.77383497e-01,
#           3.35195847e-02,  3.50768894e-01,  1.74127936e-01,
#          -2.12326676e-01, -2.13478759e-01, -3.87721471e-02,
#          -3.43729019e-01,  2.36663416e-01,  2.47119799e-01],
#         [-1.39342144e-01, -2.80665636e-01, -2.46045187e-01,
#           1.22632578e-01,  1.71941519e-01, -2.48763874e-01,
#           3.07204694e-01, -8.44724625e-02, -3.45158763e-02,
#           3.87786962e-02, -1.96424440e-01, -1.70144215e-01,
#          -3.19106460e-01,  1.87818065e-01,  1.48144260e-01,
#           1.29316553e-01, -2.93711513e-01,  3.89022142e-01,
#           2.17750102e-01, -2.81211555e-01,  1.87678516e-01,
#           1.60681397e-01,  1.66972682e-01,  3.16052824e-01,
#           2.68055052e-01, -2.92275280e-01, -1.94891289e-01,
#          -1.56648844e-01,  8.76087472e-02, -1.30353078e-01],
#         [ 3.43744725e-01, -7.78125273e-03,  2.83216357e-01,
#          -2.11860090e-01,  1.33724287e-01,  1.09674692e-01,
#          -3.71432632e-01, -6.90624537e-03,  1.20728128e-01,
#           1.66283399e-01,  2.71920651e-01,  8.38835444e-03,
#           2.21936449e-01,  3.24674785e-01, -2.86259577e-02,
#          -3.25668275e-01,  1.78777259e-02, -3.25573771e-03,
#           3.57219167e-02,  5.52728921e-02, -3.34792174e-02,
#           1.07024327e-01, -2.22416356e-01,  2.38009050e-01,
#           1.78705722e-01,  2.38627955e-01,  1.88376889e-01,
#          -1.48007721e-01,  3.50698382e-02,  3.10224831e-01],
#         [ 1.99093716e-03, -3.20316374e-01,  1.71328709e-01,
#          -3.09721440e-01,  3.12886208e-01,  1.22883916e-01,
#          -1.14126042e-01, -5.49542271e-02,  1.82963237e-01,
#           6.30407333e-02,  6.21639425e-03,  3.36068988e-01,
#          -7.33601376e-02, -1.84529256e-02,  9.01053250e-02,
#          -1.69635296e-01, -8.01082402e-02, -1.43765099e-02,
#           1.13111800e-02, -2.15236798e-01, -1.34923279e-01,
#          -1.55540720e-01,  4.94486839e-02, -4.27797288e-02,
#           1.71545103e-01,  7.91739076e-02, -2.33857274e-01,
#           3.70912254e-02, -3.13149005e-01, -1.05593689e-01],
#         [-8.51203781e-03, -2.89248247e-02,  1.37217087e-03,
#           1.57223582e-01, -1.24959670e-01,  2.48421758e-01,
#           3.39190960e-02, -2.03156337e-01, -9.38662663e-02,
#          -9.09180939e-02, -2.69217908e-01,  8.05973485e-02,
#          -2.68291175e-01,  4.63546626e-02, -3.66876945e-02,
#           2.75648266e-01,  3.39832127e-01,  2.24724531e-01,
#          -3.32793206e-01,  1.23911992e-01,  8.04146528e-02,
#          -1.81582451e-01,  2.43220642e-01,  1.18963741e-01,
#          -1.03104658e-01, -2.51811236e-01, -3.03553184e-03,
#           1.29728258e-01,  2.49048937e-02, -3.42096567e-01],
#         [-1.56907588e-01,  8.71873647e-02,  8.78264606e-02,
#           2.94498563e-01,  8.10932815e-02,  8.29103962e-02,
#           3.30138683e-01, -1.94138184e-01, -3.96797359e-01,
#          -5.07068485e-02, -2.43220598e-01,  2.10614922e-03,
#           1.29996285e-01,  1.38175875e-01, -2.05208510e-01,
#          -1.37364045e-01, -2.07587048e-01, -4.86580841e-02,
#           2.73675881e-02,  7.33185979e-03,  1.34758458e-01,
#          -4.13756400e-01, -1.76341340e-01,  1.21084914e-01,
#           1.60129517e-01, -2.81148314e-01,  1.72050819e-01,
#           1.45815089e-01,  2.06241816e-01,  6.10716417e-02],
#         [ 2.55105585e-01, -7.54076317e-02,  5.12012653e-02,
#          -2.19756827e-01, -4.17272300e-02,  2.21747026e-01,
#           2.74036437e-01, -1.13155795e-02, -3.95981707e-02,
#          -1.24969944e-01, -1.82444036e-01, -5.33549003e-02,
#           3.50505076e-02,  3.42371821e-01, -9.29696560e-02,
#           2.12487429e-01,  2.62132823e-01, -3.58287424e-01,
#          -4.08571184e-01,  1.74489200e-01, -2.56520122e-01,
#          -1.06403045e-01, -1.49241149e-01,  1.13197908e-01,
#          -1.91817045e-01,  5.59558608e-02,  2.77381271e-01,
#           3.91292512e-01,  1.89688969e-02,  6.50957450e-02],
#         [-4.01328653e-01,  6.71879109e-03,  8.26922655e-02,
#           8.36970508e-02, -3.50146666e-02, -6.52407929e-02,
#           4.80061054e-01, -5.04225120e-02,  3.62380832e-01,
#          -2.28456348e-01, -1.27644435e-01, -2.46637776e-01,
#          -2.46428773e-01, -3.74075472e-01,  1.64362907e-01,
#           1.36683792e-01, -4.97620963e-02,  1.66406974e-01,
#          -7.59391710e-02, -3.21680933e-01, -2.91961849e-01,
#          -7.69141549e-03, -3.93489301e-01, -1.35016993e-01,
#           5.12793544e-04,  4.92963335e-03,  1.53740227e-01,
#           3.81601334e-01,  1.95803180e-01,  1.94351301e-01],
#         [-1.27462029e-01,  2.92759538e-01, -3.62200171e-01,
#           1.56972557e-01,  9.53452836e-04, -7.41938055e-02,
#          -1.11819637e+00, -8.64216313e-02, -4.33836319e-02,
#           1.27176434e-01, -1.05252014e-02, -2.17717037e-01,
#           7.98498616e-02, -2.45547161e-01, -1.51180699e-01,
#           3.98727916e-02, -1.69488847e-01,  1.49974719e-01,
#           5.73401302e-02,  3.42563778e-01,  1.22817673e-01,
#          -1.44197876e-02,  6.77587315e-02,  3.26298505e-01,
#          -3.30184162e-01, -2.23449573e-01,  3.19101065e-01,
#           8.85445699e-02, -7.12329149e-02,  3.42298113e-02],
#         [ 2.31747311e-02,  4.65967618e-02,  3.31991553e-01,
#          -3.58908683e-01, -1.19288377e-01, -1.58895612e-01,
#           6.27622232e-02, -3.95371765e-01, -3.87277126e-01,
#           5.61442710e-02,  4.29316759e-02, -2.72505507e-02,
#           1.37587607e-01, -1.13157421e-01,  2.96189059e-02,
#          -1.09618276e-01,  1.41319111e-01, -1.33421034e-01,
#          -2.07035527e-01,  5.32621443e-02, -2.89068192e-01,
#           1.31574303e-01,  5.42469807e-02, -9.15952399e-02,
#           3.13115686e-01, -6.65744320e-02, -1.31542057e-01,
#           2.02311993e-01, -1.59224465e-01, -8.87347944e-03],
#         [-1.15717828e-01,  4.64400277e-03,  2.22124740e-01,
#           3.56465727e-01,  1.65795431e-01, -7.70984963e-02,
#          -1.63667664e-01,  2.81609576e-02,  2.36521110e-01,
#          -7.64134079e-02,  4.83708233e-01, -2.47508585e-01,
#           1.18966103e-01,  9.33268964e-02,  1.03944644e-01,
#          -4.71124202e-02,  6.22520829e-03,  1.49027914e-01,
#          -2.83608198e-01,  3.10057074e-01,  4.67451811e-02,
#           1.73317567e-02,  1.43841013e-01, -2.51749188e-01,
#          -2.17673153e-01, -1.66956931e-01,  2.43527561e-01,
#           3.09679389e-01, -2.25908831e-01, -1.73891112e-01],
#         [-9.87343714e-02,  2.39841506e-01, -1.39191970e-01,
#           1.23137914e-01, -1.37437582e-01,  1.76592305e-01,
#           4.08849835e-01,  1.92772120e-01, -1.44544154e-01,
#          -3.33454251e-01, -1.48552418e-01, -1.49381146e-01,
#          -1.25038594e-01,  2.37904876e-01, -7.09807500e-02,
#           1.24251217e-01,  2.56910264e-01,  3.54412049e-02,
#           7.76510537e-02, -4.27810699e-01, -3.94200653e-01,
#           2.43604854e-01, -7.42518976e-02, -1.01537816e-01,
#          -3.01457822e-01,  1.06646968e-02, -1.95345193e-01,
#          -3.54131907e-01,  1.42398864e-01,  1.50481761e-01],
#         [ 1.25438079e-01,  8.38646367e-02, -5.13535552e-02,
#          -1.16873011e-02,  1.32183120e-01, -3.14649254e-01,
#           2.56353259e-01,  2.55678058e-01,  1.33310288e-01,
#           1.35880306e-01, -8.78799427e-03, -2.83686575e-02,
#          -2.41711759e-03,  2.84938335e-01, -1.78937718e-01,
#           2.20045492e-01, -1.50629848e-01, -2.88960189e-01,
#          -1.07237220e-01,  3.01544189e-01, -1.50670499e-01,
#          -1.19843185e-01,  1.06277555e-01, -3.74152601e-01,
#          -5.21011576e-02, -2.39293694e-01, -3.69309597e-02,
#           3.78603727e-01, -3.40600729e-01, -1.65976673e-01],
#         [ 3.16325754e-01,  3.73233221e-02, -3.01553339e-01,
#           1.39467090e-01,  1.04373001e-01, -9.50126797e-02,
#          -2.42845252e-01, -1.06753111e-01,  1.64138481e-01,
#          -2.62730420e-01, -9.05338526e-02, -5.66484109e-02,
#          -1.68484434e-01,  1.62298217e-01,  8.80104601e-02,
#           2.68794924e-01, -8.48848224e-02,  1.25108674e-01,
#           1.68058842e-01, -1.42322540e-01, -2.68741213e-02,
#          -4.73080054e-02,  7.85995647e-02,  9.53807607e-02,
#          -3.63975987e-02, -6.95535466e-02,  6.34966046e-02,
#           4.40322375e-03,  4.11182689e-03,  8.29774588e-02],
#         [-1.46168945e-02, -3.13460380e-01, -4.59038932e-03,
#           5.93846664e-03,  1.69266388e-01, -3.52858678e-02,
#          -2.88296819e-01,  1.09900482e-01, -2.18534634e-01,
#           1.81385547e-01, -5.37122879e-03, -2.08740503e-01,
#          -2.88535282e-03,  2.74002731e-01,  2.01027449e-02,
#          -2.29812488e-01,  1.87186301e-01, -1.07095586e-02,
#          -6.98024333e-02, -4.14538324e-01,  2.32983634e-01,
#          -8.77354816e-02,  2.32725054e-01, -1.08355567e-01,
#           1.13988899e-01,  7.55559206e-02, -1.81818724e-01,
#          -2.42851481e-01,  3.40740591e-01,  3.42424512e-01],
#         [-1.03899404e-01,  5.87476492e-02, -3.13011974e-01,
#           2.51713753e-01,  1.43699452e-01,  9.63614043e-03,
#          -1.74646974e-02,  9.64224190e-02,  4.18308713e-02,
#           2.18979586e-02,  8.85461643e-02, -3.18180859e-01,
#           1.62916556e-02, -1.28223792e-01, -3.88221025e-01,
#          -2.07189098e-01,  9.01496597e-03, -2.60032445e-01,
#           2.59940457e-02, -1.85090721e-01,  1.14479914e-01,
#          -5.75438002e-03,  3.26138176e-02,  2.33347952e-01,
#           1.98331270e-02,  7.65569955e-02, -1.97784618e-01,
#           1.48392856e-01,  2.30663925e-01,  1.65769294e-01],
#         [-1.64678529e-01,  2.25204095e-01,  2.48564214e-01,
#           5.33065647e-02, -1.67232454e-02,  4.16145861e-01,
#           1.34061158e-01, -1.93744391e-01, -3.07606667e-01,
#          -1.52795643e-01, -1.71891168e-01, -2.41950557e-01,
#           4.05040719e-02, -7.81759918e-02, -1.92698717e-01,
#          -1.30900145e-01,  2.25816350e-02, -2.72285193e-01,
#           1.35700241e-01,  9.49864537e-02,  6.63155178e-03,
#           4.91879396e-02, -1.16999693e-01,  3.99366677e-01,
#          -1.20441489e-01, -8.49475414e-02,  1.69252485e-01,
#          -1.69173740e-02, -1.73605606e-01, -7.88441971e-02],
#         [ 3.84470433e-01, -6.79159462e-02,  2.76333004e-01,
#          -5.55977710e-02, -7.41477907e-02,  5.09373210e-02,
#           4.97292988e-02, -1.53843269e-01,  2.41331071e-01,
#           3.68914120e-02, -7.63790011e-02, -6.55077696e-02,
#           4.17990327e-01, -3.23643655e-01, -9.96526331e-02,
#           8.98575410e-02,  3.83009434e-01, -1.29825562e-01,
#           2.39395499e-01, -2.41887402e-02,  1.33814469e-01,
#           1.98451683e-01, -1.14338892e-03, -1.20458111e-01,
#          -1.63249120e-01, -4.75389622e-02,  6.89373314e-02,
#          -1.92664206e-01, -1.50134847e-01, -4.08198714e-01],
#         [ 2.97538489e-01,  1.58782884e-01, -7.87640736e-02,
#          -1.64464429e-01, -2.86839962e-01,  1.80447102e-01,
#           1.85188091e+00, -1.57032475e-01,  7.05297245e-03,
#           1.58406585e-01,  7.28281662e-02, -1.26206696e-01,
#          -1.08488239e-01,  2.71228880e-01,  1.52010635e-01,
#           1.24646120e-01, -6.55145571e-02,  4.43098955e-02,
#          -2.25572497e-01,  4.85978536e-02,  1.19151764e-01,
#           5.04176691e-02, -4.72689383e-02, -9.98518765e-02,
#           8.10481831e-02,  1.08165681e-01,  3.43809456e-01,
#           1.62628174e-01,  2.00298429e-01,  1.22612841e-01],
#         [-3.00545722e-01, -2.28110075e-01,  1.17831185e-01,
#           1.07374169e-01,  1.37328263e-02, -6.43191263e-02,
#           4.12016213e-01,  2.34627366e-01,  2.51010150e-01,
#          -2.22855523e-01, -3.23254079e-01, -6.32886887e-02,
#          -1.58564925e-01, -6.25915229e-02,  9.38873142e-02,
#           3.70856941e-01,  4.67673615e-02,  3.08134079e-01,
#           2.61913478e-01, -1.49022564e-01, -6.63835630e-02,
#          -9.02725384e-02, -9.81385410e-02,  1.29434481e-01,
#           1.53150529e-01, -9.49337892e-03,  2.01609805e-01,
#           4.08886075e-02, -1.38569698e-01, -4.41536419e-02]], dtype=float32)>,
#  'denses.1.bias': <tf.Variable 'fnn/dense_1/bias:0' shape=(30,) dtype=float32, numpy=
#  array([ 2.81969947e-03,  2.01228354e-02,  3.72013897e-02,  3.44490185e-02,
#         -2.50547435e-02,  3.77324708e-02, -1.58546373e-01,  6.10162923e-03,
#          3.76373455e-02,  2.24000383e-02,  7.58189932e-02, -1.87950246e-02,
#          3.41479108e-02,  2.14366429e-03, -3.98250967e-02, -3.55598032e-02,
#          2.03533303e-02, -4.74033616e-02,  1.12547372e-02, -2.50333222e-03,
#          3.92081309e-03,  2.40266509e-02,  2.30276827e-02,  4.73831706e-02,
#         -6.00279681e-03,  1.18681565e-02, -1.35957859e-02, -5.90979643e-02,
#          4.20827493e-02,  1.80033494e-05], dtype=float32)>,
#  'denses.2.kernel': <tf.Variable 'fnn/dense_2/kernel:0' shape=(30, 30) dtype=float32, numpy=
#  array([[-3.88933979e-02, -1.12208743e-02,  8.49700347e-02,
#          -1.90372080e-01, -1.72839060e-01, -7.05085769e-02,
#           6.23171143e-02,  1.50484249e-01,  1.62572972e-02,
#          -3.04404199e-01,  3.69624138e-01, -2.59662151e-01,
#           4.73730341e-02,  1.73345059e-01,  2.96305660e-02,
#          -1.43365771e-01,  3.27134971e-03, -1.28912762e-01,
#          -5.21196611e-02,  1.12804836e-02,  1.02497842e-02,
#           5.44958599e-02, -6.08268268e-02,  2.85681635e-01,
#           1.63291559e-01,  2.36601800e-01,  7.86912069e-02,
#           1.06584884e-01, -3.58311012e-02, -2.19335839e-01],
#         [-1.27433330e-01,  1.28963247e-01,  4.43213321e-02,
#          -2.18167245e-01, -1.44922351e-02, -5.11581227e-02,
#          -1.19271316e-01, -1.14611588e-01, -9.78422388e-02,
#          -2.50108540e-01,  3.95549119e-01,  8.72154236e-02,
#           3.63015123e-02,  3.61971885e-01,  2.47703522e-01,
#          -1.43548802e-01,  2.27683142e-01, -1.78112209e-01,
#           1.13537302e-02,  4.26372606e-03, -4.76506539e-03,
#           1.93473846e-01, -3.60544562e-01, -3.87783162e-02,
#          -9.61289406e-02, -7.25434273e-02,  1.20680586e-01,
#          -1.71692774e-01, -3.30649972e-01,  1.68968096e-01],
#         [ 1.95096061e-02,  2.59587228e-01,  1.90630749e-01,
#          -8.07930008e-02, -4.42762598e-02,  2.90262997e-01,
#           2.92753100e-01, -1.83234513e-02,  1.21031046e-01,
#          -3.38155866e-01,  3.07870135e-02, -5.63074797e-02,
#          -4.72722203e-01, -9.77682620e-02,  6.30365461e-02,
#          -1.85624674e-01,  2.40098447e-01, -1.68477714e-01,
#          -4.98078585e-01,  1.63448647e-01, -3.92405421e-01,
#           8.41003060e-02,  2.08532721e-01,  1.50070801e-01,
#           4.47696447e-01, -1.37562752e-02,  3.50097656e-01,
#          -2.23362967e-02,  3.46160233e-02,  1.24030568e-01],
#         [ 7.47611672e-02,  2.38134116e-02,  5.34160919e-02,
#          -1.69086516e-01, -1.80070236e-01, -6.17663339e-02,
#          -3.22663754e-01, -9.90075022e-02,  2.29629666e-01,
#          -4.54052724e-02,  1.47924736e-01,  6.49689988e-04,
#           3.80739868e-01,  1.44898653e-01, -3.34924087e-03,
#          -3.95475805e-01, -1.00982385e-02, -2.48081118e-01,
#          -1.38553873e-01,  2.65621338e-02,  8.78962278e-02,
#          -2.24714071e-01, -6.93023438e-04,  3.66686672e-01,
#           2.00092509e-01,  2.38257255e-02,  4.91743088e-02,
#           3.25410098e-01,  3.30450665e-03,  2.77103484e-02],
#         [-6.32300377e-02, -2.08075583e-01, -1.31443262e-01,
#           8.63448381e-02, -3.14747632e-01, -1.29756704e-01,
#           5.53181842e-02, -3.42449009e-01, -5.15967831e-02,
#           7.06259459e-02, -1.10567575e-02, -2.07726836e-01,
#          -1.79417893e-01,  2.16992423e-01,  2.12500513e-01,
#          -2.57252693e-01,  8.18059593e-02,  3.35488804e-02,
#           1.81940451e-01, -3.76491070e-01, -8.67068470e-02,
#           3.86599861e-02,  2.05922335e-01,  1.82718918e-01,
#          -9.71257985e-02, -6.17012680e-02,  2.12798893e-01,
#           1.25086466e-02,  2.10102186e-01,  5.32232374e-02],
#         [-2.55891591e-01, -1.17218800e-01, -9.21470001e-02,
#          -3.00764646e-02,  2.98139751e-01,  1.44370958e-01,
#          -2.48170912e-01,  1.32548422e-01,  6.90643340e-02,
#          -1.68060720e-01,  5.74880019e-02, -1.19049683e-01,
#           1.71683848e-01,  6.49291649e-02,  2.47751191e-01,
#          -1.91355228e-01, -1.05282903e-01,  1.96439656e-03,
#          -2.10805923e-01,  2.44537443e-01,  2.81983092e-02,
#           1.65075451e-01, -2.72721380e-01,  3.80295306e-01,
#           3.07992488e-01, -4.02424559e-02,  8.50582346e-02,
#          -3.27967145e-02, -1.08746894e-01,  1.82561222e-02],
#         [ 7.37376437e-02,  2.24328846e-01, -9.99506339e-02,
#          -7.46942461e-02, -1.58689991e-01,  2.77324021e-01,
#          -9.16625187e-02, -8.71153027e-02, -6.07428141e-02,
#          -1.22104265e-01,  6.37864098e-02,  2.80025303e-01,
#          -1.63966119e-01,  1.14297464e-01,  4.39152718e-02,
#           2.82473415e-01,  8.03221464e-02,  7.09280651e-03,
#           1.60896659e-01, -1.16781704e-01,  1.44234732e-01,
#           2.12042660e-01, -3.63689572e-01,  2.50506461e-01,
#           2.35288054e-01,  1.80553183e-01,  2.47050583e-01,
#          -2.77765751e-01,  1.88965678e-01,  8.54888558e-02],
#         [-3.04162204e-01, -3.03694658e-04, -4.15753908e-02,
#           1.39954552e-01, -1.50194883e-01, -9.86666605e-03,
#           2.15097949e-01,  4.90151607e-02,  3.81539613e-01,
#           2.47330847e-03,  2.64193058e-01, -1.45153433e-01,
#           5.73790260e-02,  5.74373752e-02, -2.78548121e-01,
#          -2.08783716e-01, -1.36988550e-01, -1.69513226e-01,
#           8.17377344e-02, -4.16201167e-03, -8.13319534e-02,
#           1.38545513e-01,  2.78331071e-01,  3.42946537e-02,
#           1.10050127e-01,  2.33322635e-01, -2.02209167e-02,
#          -1.30518571e-01, -1.35643572e-01,  1.72083192e-02],
#         [-4.89402026e-01,  2.92377789e-02, -2.51547188e-01,
#           4.70751375e-02,  4.99028750e-02,  1.41206039e-02,
#          -2.25889891e-01,  6.74434006e-02,  2.20162153e-01,
#          -1.26994595e-01,  2.84576863e-01,  4.05225903e-02,
#          -7.87494779e-02, -2.31695056e-01,  3.74395818e-01,
#          -2.86588401e-01,  4.83311294e-03, -2.95570493e-01,
#           1.50798529e-01,  2.23202050e-01, -4.48226333e-02,
#           1.32150546e-01, -3.36071819e-01,  7.20890835e-02,
#           1.12947449e-01,  2.66166240e-01,  9.49598178e-02,
#           1.04296274e-01, -9.95366648e-02, -1.57143086e-01],
#         [ 1.42350137e-01, -1.64447993e-01,  2.57204503e-01,
#          -8.85679573e-02, -6.65668771e-02,  1.06915839e-01,
#          -2.61673778e-01, -4.80838194e-02, -2.60586351e-01,
#          -2.19986737e-01,  1.63020208e-01, -1.45620987e-01,
#           1.09161071e-01, -5.73129170e-02,  1.50264772e-02,
#          -2.48825878e-01,  5.15208058e-02,  1.80112824e-01,
#          -1.62910700e-01, -1.15001179e-01,  1.48645297e-01,
#           2.65346318e-01,  3.45613748e-01,  2.00577378e-01,
#          -9.22133494e-03,  1.13925077e-01, -3.39773074e-02,
#           4.22620267e-01,  1.06219083e-01,  2.39351094e-01],
#         [-1.09938227e-01,  1.13106504e-01, -3.54161598e-02,
#          -3.03165197e-01,  2.01679200e-01,  1.06285907e-01,
#           1.26953527e-01,  1.61084160e-01,  7.73969060e-03,
#          -1.34293124e-01,  3.28679293e-01,  2.08747014e-01,
#           3.54175270e-02,  6.49712086e-02,  3.93613912e-02,
#          -2.98681468e-01,  2.18028799e-01,  4.09695208e-02,
#          -2.10313872e-01,  4.24596757e-01, -2.64977664e-01,
#           9.57990959e-02,  2.60934174e-01,  2.12819740e-01,
#          -1.49071917e-01, -1.91273838e-01,  4.34833243e-02,
#          -3.63847166e-01,  1.27824485e-01,  3.39166045e-01],
#         [-3.65086794e-02, -3.65032554e-01, -1.49174929e-01,
#           2.03958452e-01,  9.10455287e-02, -2.35498577e-01,
#           4.24208529e-02, -1.24261118e-01, -2.19502766e-02,
#           7.85104632e-02, -1.75002337e-01, -2.49719232e-01,
#          -2.07706094e-01,  1.53816059e-01,  1.59096550e-02,
#           1.60393655e-01, -3.25414121e-01,  3.88491482e-01,
#           2.96987116e-01, -3.57103229e-01,  2.63752639e-01,
#           1.09530263e-01,  2.39248499e-01,  2.90008396e-01,
#           2.21348390e-01, -2.98401743e-01, -2.57585406e-01,
#          -1.19173609e-01,  1.69274032e-01, -1.82772502e-01],
#         [ 2.54338562e-01,  3.05427611e-02,  1.99796200e-01,
#          -2.28051320e-01,  1.91550910e-01,  7.81340674e-02,
#          -2.12954223e-01,  3.33704948e-02,  9.77148190e-02,
#           1.24391146e-01,  2.78903067e-01,  2.39666067e-02,
#           1.72162816e-01,  3.33096594e-01,  6.34795576e-02,
#          -3.48779470e-01,  4.67497259e-02,  4.57100607e-02,
#          -1.38216056e-02,  1.01023465e-01, -7.03125745e-02,
#           1.34497881e-01, -2.38840863e-01,  2.54040718e-01,
#           1.71518773e-01,  2.06469670e-01,  2.33169839e-01,
#          -9.00316834e-02, -6.58591883e-03,  3.43240529e-01],
#         [-1.98208138e-01, -1.67598441e-01, -1.59343872e-02,
#          -4.20923501e-01,  3.33304584e-01,  2.76215792e-01,
#           2.55651921e-01, -1.86761804e-02,  1.71702266e-01,
#          -2.55097970e-02,  2.64241733e-03,  4.36764479e-01,
#          -2.87197173e-01,  2.06773961e-03,  2.07781404e-01,
#          -1.76878780e-01,  6.95455680e-03, -8.50827545e-02,
#          -1.54978916e-01, -1.67074978e-01, -2.78056383e-01,
#          -9.75038484e-02, -8.12106505e-02, -2.33598147e-02,
#           2.72237837e-01,  6.53923675e-02, -1.63527563e-01,
#          -1.85277075e-01, -6.17459536e-01,  1.34539809e-02],
#         [ 6.79124743e-02, -1.09480448e-01,  8.86538923e-02,
#           2.18042210e-01, -1.70078591e-01,  2.75493681e-01,
#          -2.02484250e-01, -2.61100143e-01, -7.17848614e-02,
#          -5.19094914e-02, -2.15239301e-01,  3.48927118e-02,
#          -2.01148719e-01,  1.45826032e-02, -1.55316129e-01,
#           2.82928467e-01,  3.18608999e-01,  1.79543227e-01,
#          -2.61790454e-01,  6.37702048e-02,  1.35696739e-01,
#          -2.09126472e-01,  2.77951002e-01,  1.19444802e-01,
#          -1.30628735e-01, -2.53620982e-01, -3.47585678e-02,
#           1.33838788e-01,  9.89218876e-02, -3.99451673e-01],
#         [-7.49871060e-02,  1.01463664e-02,  1.78411588e-01,
#           3.50833207e-01,  3.01762279e-02,  1.12025619e-01,
#           9.72560048e-02, -2.43725970e-01, -3.79386276e-01,
#          -5.44941612e-03, -1.84038147e-01, -4.17751260e-02,
#           1.85677320e-01,  1.02458544e-01, -3.16686720e-01,
#          -1.28187761e-01, -2.19877541e-01, -8.98127481e-02,
#           9.57380682e-02, -5.22850417e-02,  1.98899940e-01,
#          -4.35400277e-01, -1.25736162e-01,  1.16804384e-01,
#           1.23796530e-01, -2.82849729e-01,  1.35127261e-01,
#           1.50790051e-01,  2.78310120e-01, -4.40409547e-03],
#         [ 1.31861433e-01,  8.57814178e-02, -3.01937070e-02,
#          -2.34241262e-01, -1.62385087e-02,  3.15861076e-01,
#           2.33333111e-01,  8.46252516e-02,  2.86796074e-02,
#          -1.27494246e-01, -6.87720478e-02,  7.16154557e-03,
#          -2.36683451e-02,  4.11958158e-01,  3.69334710e-03,
#           8.92837942e-02,  3.79162639e-01, -4.43162590e-01,
#          -5.05608380e-01,  2.89414376e-01, -3.61771733e-01,
#           8.26212578e-03, -2.03101203e-01,  2.62776226e-01,
#          -1.21016577e-01,  1.13454983e-01,  3.60344380e-01,
#           2.49468058e-01, -4.53425124e-02,  1.81313843e-01],
#         [-2.83609092e-01, -7.10636228e-02,  1.74035847e-01,
#           1.21575348e-01, -9.10383984e-02, -3.56805511e-02,
#           2.57672936e-01, -1.04718156e-01,  3.67608696e-01,
#          -1.71386361e-01, -1.39187619e-01, -2.91954130e-01,
#          -1.80103391e-01, -4.03478324e-01,  4.85779904e-02,
#           1.64015234e-01, -8.22517574e-02,  1.23222314e-01,
#          -6.54307194e-03, -3.78239930e-01, -2.06954941e-01,
#          -3.41703817e-02, -3.53030890e-01, -1.55767873e-01,
#          -2.33615283e-02,  1.60329640e-02,  1.05398960e-01,
#           3.85568827e-01,  2.61267751e-01,  1.26477376e-01],
#         [ 1.38462022e-01,  8.03288296e-02, -6.57454580e-02,
#           2.85681427e-01, -7.31575638e-02, -2.92716295e-01,
#          -5.57004333e-01, -7.30912685e-02, -1.54503465e-01,
#           2.52916306e-01, -3.85639183e-02, -4.14375067e-01,
#           3.06060016e-01, -3.30377102e-01, -3.24021280e-01,
#           1.24037012e-01, -3.29447985e-01,  2.62688965e-01,
#           2.30375871e-01,  1.78430691e-01,  1.91404685e-01,
#          -8.63138586e-02,  2.00574905e-01,  2.30297014e-01,
#          -5.02929270e-01, -2.31529683e-01,  2.09130600e-01,
#           3.29512089e-01,  2.86292970e-01, -1.29630432e-01],
#         [ 1.81488723e-01, -1.03233093e-02,  4.29984510e-01,
#          -2.85951048e-01, -2.34178677e-01, -2.28136092e-01,
#          -3.46794367e-01, -3.89248401e-01, -2.91324914e-01,
#           8.25333446e-02,  1.31132518e-04, -1.46052942e-01,
#           3.75860125e-01, -1.38476282e-01, -1.57717898e-01,
#          -5.41641489e-02,  2.33478900e-02, -7.01651052e-02,
#          -5.02349362e-02, -6.71850741e-02, -2.01805845e-01,
#           2.36581378e-02,  1.17785662e-01, -1.84955746e-01,
#           2.38127664e-01, -4.63065989e-02, -2.23158449e-01,
#           2.76291162e-01,  8.83466937e-03, -1.28150806e-01],
#         [ 1.35060817e-01, -1.23908386e-01,  3.76295358e-01,
#           4.54663873e-01,  6.71967641e-02, -3.64077210e-01,
#          -5.99669039e-01,  4.25843373e-02,  1.31693050e-01,
#          -1.89841650e-02,  2.20500261e-01, -4.02783394e-01,
#           4.86979932e-01,  5.47300130e-02,  1.28829973e-02,
#           1.55496240e-01, -1.16329826e-01,  4.10800308e-01,
#          -1.38965905e-01,  1.84698418e-01,  2.66994864e-01,
#          -1.28927827e-01,  1.04096197e-01, -4.14986700e-01,
#          -3.66173357e-01, -1.18336394e-01,  1.85535029e-01,
#           5.78601837e-01,  1.16144367e-01, -2.91014582e-01],
#         [-1.64188221e-01,  3.70577395e-01, -3.42082858e-01,
#           1.04058489e-01, -1.76992100e-02,  1.94533736e-01,
#           3.88086945e-01,  3.29211622e-01, -1.67400107e-01,
#          -3.54856700e-01, -1.37454703e-01, -3.11041679e-02,
#          -2.69093424e-01,  1.98720753e-01,  7.44514316e-02,
#           6.23603165e-02,  2.63109505e-01,  5.87769262e-02,
#           2.86898967e-02, -1.32605553e-01, -2.26585105e-01,
#           3.42947572e-01, -1.52183339e-01,  6.04932718e-02,
#          -2.58400351e-01,  4.87105139e-02, -1.49327904e-01,
#          -4.01737481e-01, -5.66666648e-02,  1.77411884e-01],
#         [ 5.66044897e-02,  1.89691693e-01, -6.21852465e-02,
#          -2.60949275e-03,  1.19949654e-01, -2.60883808e-01,
#           1.57900840e-01,  3.05893034e-01,  1.92387164e-01,
#           1.50031283e-01,  7.78233036e-02, -1.96138397e-02,
#           1.95021043e-03,  3.16807121e-01, -1.49680108e-01,
#           1.55357718e-01, -9.82438996e-02, -3.46236885e-01,
#          -1.42146990e-01,  3.56636941e-01, -2.07954973e-01,
#          -5.89120612e-02,  8.90704989e-02, -2.98206925e-01,
#          -3.96764763e-02, -2.07973465e-01, -1.49357412e-02,
#           2.76992500e-01, -3.31619680e-01, -1.17425933e-01],
#         [ 3.82268548e-01, -4.13554572e-02, -3.12894791e-01,
#           1.17474407e-01,  8.08425695e-02, -1.21441774e-01,
#          -2.44921923e-01, -1.09994926e-01,  1.31384879e-01,
#          -2.53723681e-01, -1.73701867e-01, -6.17205389e-02,
#          -1.71897948e-01,  1.28984630e-01,  7.72272721e-02,
#           3.42385888e-01, -7.92227983e-02,  2.04723880e-01,
#           1.95245087e-01, -1.92011595e-01,  1.37104457e-02,
#          -8.59348848e-02,  3.66075523e-02,  2.09700242e-02,
#          -7.09490925e-02, -6.98221996e-02,  5.83948791e-02,
#           9.86237898e-02, -1.43916195e-03,  1.75548866e-02],
#         [ 4.58521396e-02, -4.29869056e-01,  6.06351532e-03,
#           3.93803231e-03,  1.66579530e-01, -9.11883339e-02,
#          -2.06488922e-01,  5.84309399e-02, -2.71798611e-01,
#           1.65773109e-01, -1.05747908e-01, -2.24459723e-01,
#           1.33555522e-02,  2.41740078e-01, -1.84420180e-02,
#          -1.47530034e-01,  1.26067013e-01,  5.66383041e-02,
#          -3.08037344e-02, -4.76459801e-01,  2.74138331e-01,
#          -1.67231515e-01,  2.57718861e-01, -2.01971635e-01,
#           9.49277580e-02,  4.53169011e-02, -2.07353532e-01,
#          -1.53254852e-01,  3.51020366e-01,  2.82663107e-01],
#         [-1.69219360e-01,  1.19764552e-01, -3.90320420e-01,
#           1.98182195e-01,  1.87089771e-01, -1.94480736e-02,
#           1.98357284e-01,  1.41259700e-01,  2.02150736e-02,
#          -1.43332239e-02,  2.60845963e-02, -2.78527230e-01,
#          -3.56647596e-02, -1.02054261e-01, -2.84069002e-01,
#          -2.02582866e-01,  2.21784133e-02, -2.15921640e-01,
#          -3.08706518e-02, -1.32420808e-01,  6.38446882e-02,
#           6.53109560e-03, -3.76414740e-03,  2.26089105e-01,
#           4.26765308e-02,  8.09557959e-02, -1.65250391e-01,
#           1.57743558e-01,  1.61428720e-01,  2.14056343e-01],
#         [-8.80316570e-02,  1.16335861e-01,  2.69947559e-01,
#           5.95036075e-02, -1.80220939e-02,  3.49344045e-01,
#           2.21135974e-01, -2.45403543e-01, -3.56272876e-01,
#          -1.71829671e-01, -2.71044135e-01, -2.69908458e-01,
#           7.15364292e-02, -1.08319692e-01, -2.51254678e-01,
#          -6.26084879e-02, -4.59099859e-02, -1.89606398e-01,
#           1.76358700e-01,  2.52122823e-02,  7.25252628e-02,
#          -2.67480854e-02, -8.26406479e-02,  3.00017416e-01,
#          -1.42704189e-01, -1.26999959e-01,  1.31338373e-01,
#           8.89492184e-02, -1.62054315e-01, -1.42341033e-01],
#         [ 4.44941998e-01, -1.78538412e-01,  2.87269741e-01,
#          -6.68526739e-02, -6.23970702e-02,  2.19005370e-03,
#           1.46288216e-01, -2.09804848e-01,  1.82636976e-01,
#           2.40090247e-02, -1.65543526e-01, -6.89459518e-02,
#           4.09038246e-01, -3.56687814e-01, -1.33328184e-01,
#           1.60416543e-01,  3.27708185e-01, -7.79576004e-02,
#           2.75300711e-01, -8.05403963e-02,  1.78611785e-01,
#           1.34726137e-01,  1.20083066e-02, -1.98618680e-01,
#          -1.74768090e-01, -7.81780705e-02,  4.58220728e-02,
#          -1.04104944e-01, -1.56160802e-01, -4.61116344e-01],
#         [ 1.70719370e-01,  2.92689204e-01, -1.70728087e-01,
#          -2.35255048e-01, -1.87964439e-01,  1.82232931e-01,
#           4.98425424e-01, -1.31255656e-01,  3.73848081e-02,
#           1.31660506e-01,  9.58088636e-02, -8.11487511e-02,
#          -2.11684600e-01,  3.69346827e-01,  2.72418082e-01,
#           6.49444163e-02, -3.75059462e-04,  6.01625182e-02,
#          -2.80074328e-01,  1.85389981e-01,  1.01622283e-01,
#           9.81568545e-02, -6.49073869e-02, -1.00156374e-01,
#           1.11754932e-01,  1.14047050e-01,  3.98613602e-01,
#           1.35045260e-01,  1.28064930e-01,  1.76187009e-01],
#         [-3.85461092e-01, -1.38587788e-01,  1.17704518e-01,
#           7.15572909e-02,  3.20584700e-02,  1.04436288e-02,
#           3.95666808e-01,  2.36690655e-01,  2.74129719e-01,
#          -1.99902326e-01, -2.07182363e-01, -2.81648710e-02,
#          -2.49862954e-01, -4.04885896e-02,  1.66189313e-01,
#           2.96151072e-01,  1.27049774e-01,  1.78877205e-01,
#           2.28071243e-01, -7.62502030e-02, -1.27563015e-01,
#           2.88058026e-03, -1.07158564e-01,  2.48886660e-01,
#           1.71343371e-01,  2.43049450e-02,  2.34643921e-01,
#          -7.51841217e-02, -1.79791257e-01,  3.53441983e-02]], dtype=float32)>,
#  'denses.2.bias': <tf.Variable 'fnn/dense_2/bias:0' shape=(30,) dtype=float32, numpy=
#  array([-0.06343679,  0.08890797, -0.04549646, -0.02272118,  0.01564595,
#          0.00874555,  0.06429203,  0.05010309,  0.02075762, -0.01363922,
#          0.00970844,  0.0230813 , -0.02449549,  0.03293167,  0.06980246,
#         -0.03261849,  0.03354806, -0.00157042, -0.04850932,  0.05212247,
#         -0.05328304,  0.03801667, -0.02454204,  0.03861888,  0.02093265,
#          0.01746599,  0.02430777, -0.04391983, -0.03268633,  0.05494332],
#        dtype=float32)>,
#  'denses.3.kernel': <tf.Variable 'fnn/dense_3/kernel:0' shape=(30, 15) dtype=float32, numpy=
#  array([[ 1.16113182e-02, -1.56792611e-01,  1.50334209e-01,
#           5.78817248e-01, -2.85389006e-01, -2.49848403e-02,
#          -7.22298324e-02,  1.00467414e-01, -3.04560900e-01,
#          -3.26425403e-01,  3.06559950e-01, -2.35188991e-01,
#           9.81265485e-01, -8.53500068e-01, -9.98730958e-02],
#         [-5.78527115e-02,  5.58023080e-02, -1.29434943e-01,
#           3.89920585e-02, -1.00385569e-01,  2.09327802e-01,
#           3.98110822e-02, -4.29256335e-02,  6.34372175e-01,
#           1.09635890e-01,  4.04916734e-01,  1.11185588e-01,
#           2.86434746e+00,  3.08108735e+00, -2.35929817e-01],
#         [-7.72201270e-02, -5.23329377e-02,  1.33780062e-01,
#          -6.39892876e-01, -2.26382222e-02, -1.49010509e-01,
#          -3.10963750e-01, -2.19067648e-01, -4.84327942e-01,
#          -2.97059029e-01,  2.37813562e-01,  1.68004837e-02,
#          -2.00977731e+00, -2.66793942e+00,  6.48660436e-02],
#         [-1.94874585e-01,  2.90211979e-02, -1.37644932e-01,
#          -3.07182111e-02, -1.56755671e-01, -7.59841055e-02,
#           1.09094847e-02, -3.41201693e-01, -5.02856016e-01,
#          -1.32608697e-01, -2.57973522e-01,  6.69235960e-02,
#          -3.79310966e+00, -2.92263198e+00,  1.41967749e-02],
#         [ 2.15189874e-01,  1.56619117e-01,  3.39448363e-01,
#           7.51920044e-01, -2.23104924e-01,  4.01473224e-01,
#           1.59672216e-01, -1.12188749e-01,  6.52748197e-02,
#          -3.46810222e-01, -2.05547884e-01,  3.44808325e-02,
#           3.30323792e+00,  3.48230338e+00, -1.26462668e-01],
#         [-8.68323743e-02,  2.07402661e-01, -1.32765740e-01,
#          -8.85905862e-01, -1.56637907e-01, -2.85507411e-01,
#          -1.63881388e-02,  3.25454950e-01,  5.68251193e-01,
#           3.72233093e-01,  3.76032069e-02,  1.14738561e-01,
#           3.11551976e+00,  2.68016219e+00,  1.21489346e-01],
#         [ 7.59103969e-02,  1.19236767e-01,  4.56884392e-02,
#          -7.81906903e-01, -3.02445740e-02,  7.29651600e-02,
#          -1.24386743e-01, -6.49992973e-02,  6.73915923e-01,
#           3.70477065e-02,  2.36613676e-01,  3.25448029e-02,
#           8.61445427e-01,  2.90764761e+00,  1.00100353e-01],
#         [-4.30085123e-01,  4.10645306e-02, -2.93807149e-01,
#           1.61646664e-01,  4.52542789e-02,  7.78073370e-02,
#          -2.11432204e-01, -1.81781072e-02,  7.18225479e-01,
#           2.93522209e-01,  1.73533231e-01,  9.50004980e-02,
#           2.54992652e+00,  2.46014166e+00,  1.82765648e-01],
#         [-1.68623459e-02, -2.58261383e-01, -1.27466395e-01,
#           8.36362302e-01, -3.52122635e-01, -7.55243301e-02,
#           9.65507925e-02, -4.13834810e-01,  2.26936430e-01,
#           9.08202603e-02,  1.08241722e-01, -2.09049463e-01,
#           4.14488316e+00,  5.30766678e+00,  2.88627565e-01],
#         [-3.29884648e-01, -3.62250302e-03,  2.99098473e-02,
#           1.62976071e-01, -2.99689025e-01, -1.18392035e-01,
#          -4.33620438e-02,  2.35729262e-01, -2.36699969e-01,
#          -1.29175931e-01, -2.84426063e-01,  2.73766011e-01,
#          -6.30343533e+00, -4.10232210e+00, -1.57324806e-01],
#         [-1.52024284e-01, -2.15113431e-01, -3.78340147e-02,
#          -4.35598791e-01,  2.44586319e-01,  1.19531013e-01,
#          -3.38368505e-01,  7.79133886e-02,  3.18703890e-01,
#          -1.64402992e-01,  1.71594769e-01, -2.33957440e-01,
#           5.43542087e-01, -3.10701132e-01,  2.70073980e-01],
#         [-1.27169713e-01, -1.56579942e-01, -7.75513612e-03,
#           3.42990369e-01, -1.97503567e-02,  1.71258986e-01,
#           1.74184173e-01, -2.69407004e-01,  8.06722224e-01,
#           2.06571251e-01, -6.83023334e-02, -1.45563275e-01,
#           3.14605474e+00,  2.53156638e+00,  3.87741774e-02],
#         [ 7.96795636e-02,  2.31492706e-02, -9.99433640e-03,
#          -4.05473709e-01, -3.47153693e-02,  1.56804528e-02,
#          -3.64997953e-01, -1.61915198e-01, -6.59927964e-01,
#          -2.46112168e-01, -5.69602959e-02,  1.47288784e-01,
#          -3.35829377e+00, -3.27379823e+00, -1.93088859e-01],
#         [ 4.44257855e-01,  7.00972900e-02,  1.64462887e-02,
#           4.46559131e-01, -2.91045815e-01,  2.83492863e-01,
#           2.67753869e-01, -3.38682771e-01,  5.46358883e-01,
#           2.36455306e-01,  3.37720484e-01,  2.19583556e-01,
#           8.99871945e-01, -1.30819371e-02,  1.51363730e-01],
#         [-2.83806086e-01, -5.30062914e-02, -7.26827001e-03,
#           5.49873233e-01, -1.55534804e-01,  1.90011002e-02,
#           1.69202596e-01,  1.89405810e-02,  7.11359143e-01,
#          -1.29816923e-02,  3.29104215e-01, -1.34674832e-01,
#           1.15335655e+00,  1.50619316e+00, -4.35293704e-01],
#         [-2.77430117e-01, -3.02973986e-01, -1.66076288e-01,
#           1.13441873e+00,  3.89691279e-03, -1.55087803e-02,
#           5.70005141e-02,  3.45060527e-01, -5.11165679e-01,
#           8.67614299e-02, -2.38132104e-02, -3.87390256e-02,
#          -2.34965131e-01,  1.60860583e-01, -1.43237486e-01],
#         [-4.41472322e-01, -6.82880580e-02, -2.10983694e-01,
#           8.80633652e-01,  1.04949623e-01,  2.77519841e-02,
#          -3.50360096e-01,  3.35248362e-04,  4.31699753e-01,
#          -1.24235891e-01,  2.19763875e-01,  1.11724369e-01,
#           5.40212822e+00,  4.00406742e+00,  2.73690820e-01],
#         [-3.09508234e-01, -1.04822867e-01, -3.29599857e-01,
#           5.37575722e-01,  1.56584635e-01, -6.90860266e-04,
#           3.58255878e-02, -3.64342988e-01, -2.70202339e-01,
#           1.31130546e-01,  1.87209889e-01,  1.14994399e-01,
#          -2.86276340e-01, -1.08746529e+00, -3.32218528e-01],
#         [ 1.07059747e-01, -1.92314759e-01,  2.70895213e-01,
#          -2.57544369e-01, -1.92006957e-02,  6.97742254e-02,
#          -2.06314325e-01, -4.84916009e-02, -6.44549310e-01,
#          -1.93588614e-01,  7.76962116e-02, -6.49603009e-02,
#          -1.51265800e+00, -7.08705723e-01,  6.70158416e-02],
#         [-1.98583350e-01,  2.45021850e-01,  1.19714141e-01,
#          -1.83214769e-01, -1.74613014e-01,  1.62202567e-01,
#           4.18254226e-01,  3.15474451e-01,  6.36817813e-01,
#           5.49707487e-02,  3.81178588e-01,  2.85053011e-02,
#           6.38374507e-01,  2.74734467e-01,  4.57911491e-01],
#         [-4.87849191e-02, -9.39545482e-02,  8.29059109e-02,
#          -8.55146646e-01,  1.80483252e-01,  7.04342276e-02,
#          -2.29411274e-02,  6.72427565e-02, -3.60486269e-01,
#          -1.48132041e-01,  1.82970524e-01,  1.16192572e-01,
#          -1.08228493e+00, -1.16642332e+00, -1.90577015e-01],
#         [-1.96007878e-01,  2.18507931e-01,  4.62554656e-02,
#           6.25947416e-02,  3.17542613e-01, -2.10983083e-01,
#           5.90900779e-02,  3.83988023e-01,  5.03245771e-01,
#          -2.13507012e-01, -1.00077942e-01,  7.12599547e-04,
#           1.21608484e+00,  6.81373835e-01,  3.98549527e-01],
#         [-1.97122067e-01, -3.88572395e-01, -2.17045695e-01,
#           4.63585019e-01,  5.55395596e-02, -1.61191225e-01,
#           5.22932096e-04, -1.05884135e-01, -4.91945207e-01,
#           1.35634199e-01, -2.57418931e-01,  4.62971739e-02,
#          -2.19093347e+00, -1.78831685e+00, -3.59577686e-02],
#         [ 1.75254196e-01, -2.04255432e-01,  4.14602935e-01,
#          -1.35758829e+00, -4.01111484e-01,  1.09082542e-01,
#           2.30695263e-01,  2.14619070e-01,  8.89952004e-01,
#           2.44660676e-01, -1.28295243e-01, -2.80324310e-01,
#           1.00789413e-01, -3.04019428e-03, -2.24422127e-01],
#         [ 4.93940860e-01,  1.11923940e-01,  2.43318871e-01,
#          -1.41052678e-01,  8.16941261e-02,  2.27400243e-01,
#          -1.20611273e-01,  1.26933428e-02,  5.52630305e-01,
#           2.20462568e-02,  3.79473001e-01, -1.17685661e-01,
#           4.41067839e+00,  2.62387466e+00,  1.38272300e-01],
#         [-2.88152128e-01,  6.13395870e-02,  3.76354940e-02,
#          -1.23857044e-01,  1.12321414e-02,  9.61456168e-03,
#           1.50813878e-01, -2.64356792e-01,  5.40868044e-01,
#           1.98882312e-01,  3.85582387e-01,  1.84219018e-01,
#           1.40546834e+00,  1.69918621e+00,  4.51392293e-01],
#         [ 9.86486524e-02, -2.61310905e-01,  1.39452592e-01,
#          -6.75791502e-01,  2.97214717e-01,  1.19222410e-01,
#           1.48168638e-01, -6.26920685e-02,  5.84903002e-01,
#           1.92600098e-02,  1.36396781e-01,  3.63484293e-01,
#           2.04897070e+00,  2.16306019e+00,  2.90437788e-01],
#         [-1.45338356e-01, -9.74586084e-02,  3.79254605e-04,
#          -7.62802601e-01, -4.11738418e-02, -3.08618516e-01,
#          -2.83337921e-01,  5.31138200e-03, -5.98857880e-01,
#           1.81071281e-01, -1.82282906e-02, -2.02948198e-01,
#          -6.80193281e+00, -5.63572168e+00, -2.70963997e-01],
#         [-2.29324102e-02, -7.82562196e-02,  2.77214199e-02,
#           2.66792369e-03, -2.71807581e-01,  1.28490590e-02,
#          -2.60381520e-01, -2.48477638e-01, -6.24209523e-01,
#          -1.90682068e-01, -1.95819393e-01,  2.33996585e-02,
#          -4.86813021e+00, -5.58362770e+00, -1.84733450e-01],
#         [ 3.76640439e-01,  5.47238290e-01,  1.94768101e-01,
#          -4.48487997e-02,  3.61270346e-02,  2.06141293e-01,
#          -1.19013153e-01,  2.78652668e-01,  5.65061212e-01,
#          -1.27043292e-01, -7.72780925e-02,  5.07371649e-02,
#           2.00679183e+00,  2.07320905e+00, -2.68389553e-01]], dtype=float32)>,
#  'denses.3.bias': <tf.Variable 'fnn/dense_3/bias:0' shape=(15,) dtype=float32, numpy=
#  array([ 3.2502551e-02,  4.8456166e-02, -1.1725249e-02,  1.1103463e+00,
#         -6.9399755e-03, -3.4933607e-04,  4.3769371e-02,  6.2090638e-03,
#          2.4796930e-01,  3.8794979e-02,  1.3862523e-01,  7.2489172e-02,
#         -1.1978356e-01,  4.8523483e-01,  1.1000052e-01], dtype=float32)>}

# %%
model.predict(anchors)
# Out:
# array([[-0.0000000e+00,  0.0000000e+00, -0.0000000e+00,  0.0000000e+00,
#         -0.0000000e+00,  0.0000000e+00,  0.0000000e+00, -0.0000000e+00,
#          0.0000000e+00, -0.0000000e+00,  0.0000000e+00, -0.0000000e+00,
#          0.0000000e+00,  0.0000000e+00, -0.0000000e+00],
#        [ 4.1920212e-01,  8.3883303e-01,  2.8762442e-01,  2.7450567e-01,
#         -2.5126973e-02,  8.7155157e-01,  8.3533007e-01,  3.8759637e-01,
#          6.3230767e+00,  8.9732546e-01,  1.2084453e+00,  3.2635715e-02,
#          1.4329937e+01,  1.4279184e+01,  1.3809915e+00],
#        [ 5.1245219e-01,  1.0250597e+00,  3.5107270e-01,  2.4477065e-01,
#         -1.1474186e-02,  1.0578372e+00,  1.0211515e+00,  4.7532916e-01,
#          7.7372675e+00,  1.1064678e+00,  1.4815340e+00,  3.4350865e-02,
#          2.1873707e+01,  2.2136904e+01,  1.6971452e+00],
#        [ 6.8332899e-01,  1.3671435e+00,  4.6839553e-01,  5.5804953e-02,
#          4.0406594e-03,  1.3865484e+00,  1.3506449e+00,  6.3236630e-01,
#          1.0311738e+01,  1.4697469e+00,  1.9763300e+00,  3.7969969e-02,
#          3.5750259e+01,  3.6187820e+01,  2.2565682e+00],
#        [ 7.0590043e-01,  1.4126946e+00,  4.8381555e-01,  5.0710905e-02,
#          3.8833292e-03,  1.4319954e+00,  1.3971120e+00,  6.5370876e-01,
#          1.0658817e+01,  1.5191376e+00,  2.0395694e+00,  3.7787929e-02,
#          3.7750664e+01,  3.8081211e+01,  2.3322928e+00],
#        [ 7.3184288e-01,  1.4648077e+00,  5.0153375e-01,  4.9585927e-02,
#          3.5211258e-03,  1.4842331e+00,  1.4502140e+00,  6.7822146e-01,
#          1.1055411e+01,  1.5759087e+00,  2.1118798e+00,  3.7293088e-02,
#          4.0085911e+01,  4.0225040e+01,  2.4192135e+00],
#        [ 7.7363807e-01,  1.5471946e+00,  5.3009039e-01,  4.0421475e-02,
#          4.0748194e-03,  1.5661258e+00,  1.5320680e+00,  7.1681696e-01,
#          1.1676063e+01,  1.6648587e+00,  2.2291355e+00,  3.6809955e-02,
#          4.3807922e+01,  4.3474129e+01,  2.5563312e+00],
#        [ 8.4540302e-01,  1.6926922e+00,  5.7924449e-01, -2.7660124e-02,
#          1.0889309e-02,  1.7102642e+00,  1.6732404e+00,  7.8279549e-01,
#          1.2787795e+01,  1.8259450e+00,  2.4520345e+00,  3.7688430e-02,
#          5.0460785e+01,  4.8932785e+01,  2.8020742e+00]], dtype=float32)

# %%
test_data = np.genfromtxt('test.dat',
                     skip_header=0,
                     skip_footer=0,
                     names=None,
                     dtype=None,
                     delimiter=' ')
test_data
# Out:
# array([[1.68000000e+02, 4.19202119e-01, 8.38833034e-01, ...,
#         1.43299370e+01, 1.42791843e+01, 1.38099146e+00],
#        [3.36000000e+02, 5.12452185e-01, 1.02505970e+00, ...,
#         2.18737068e+01, 2.21369038e+01, 1.69714522e+00],
#        [6.72000000e+02, 6.83328986e-01, 1.36714351e+00, ...,
#         3.57502594e+01, 3.61878204e+01, 2.25656819e+00],
#        ...,
#        [1.26494116e+03, 8.32318783e-01, 1.66452217e+00, ...,
#         4.91396866e+01, 4.78673210e+01, 2.75324702e+00],
#        [1.29129407e+03, 8.37020159e-01, 1.67449665e+00, ...,
#         4.96042557e+01, 4.82425270e+01, 2.77042294e+00],
#        [1.31764709e+03, 8.41381431e-01, 1.68389094e+00, ...,
#         5.00449142e+01, 4.85978546e+01, 2.78670979e+00]])

# %%
columns_names=['Time', 'M_art', 'M_venous', 'M_gills', 'M_lumen', 'M_lumen_2', 'M_viscera', 'M_liver', 'M_kidney', \
                'M_muscle', 'M_skin', 'M_carcass', 'M_storage', 'M_urine', 'M_feces', 'M_blood']
test_df = pd.DataFrame(test_data, columns = columns_names)
test_df
# Out:
#            Time     M_art  M_venous   M_gills   M_lumen  M_lumen_2  M_viscera  \
# 0    168.000000  0.419202  0.838833  0.287624  0.274506  -0.025127   0.871552
# 1    336.000000  0.512452  1.025060  0.351073  0.244771  -0.011474   1.057837
# 2    672.000000  0.683329  1.367144  0.468396  0.055805   0.004041   1.386548
# 3    744.000000  0.705900  1.412695  0.483816  0.050711   0.003883   1.431995
# 4    840.000000  0.731843  1.464808  0.501534  0.049586   0.003521   1.484233
# ..          ...       ...       ...       ...       ...        ...        ...
# 94  1212.235352  0.821933  1.642953  0.563142  0.000816   0.007737   1.660444
# 95  1238.588257  0.827284  1.653994  0.566809 -0.005249   0.008357   1.671408
# 96  1264.941162  0.832319  1.664522  0.570261 -0.011201   0.008988   1.681906
# 97  1291.294067  0.837020  1.674497  0.573487 -0.016961   0.009624   1.691898
# 98  1317.647095  0.841381  1.683891  0.576481 -0.022463   0.010259   1.701355
#
#      M_liver  M_kidney   M_muscle    M_skin  M_carcass  M_storage    M_urine  \
# 0   0.835330  0.387596   6.323077  0.897325   1.208445   0.032636  14.329937
# 1   1.021152  0.475329   7.737267  1.106468   1.481534   0.034351  21.873707
# 2   1.350645  0.632366  10.311738  1.469747   1.976330   0.037970  35.750259
# 3   1.397112  0.653709  10.658817  1.519138   2.039569   0.037788  37.750664
# 4   1.450214  0.678221  11.055411  1.575909   2.111880   0.037293  40.085911
# ..       ...       ...        ...       ...        ...        ...        ...
# 94  1.624720  0.760643  12.398962  1.768897   2.373214   0.037452  48.144733
# 95  1.635425  0.765597  12.484052  1.781290   2.390439   0.037534  48.652534
# 96  1.645662  0.770302  12.565774  1.793238   2.407001   0.037600  49.139687
# 97  1.655393  0.774742  12.643784  1.804688   2.422822   0.037649  49.604256
# 98  1.664590  0.778907  12.717844  1.815600   2.437846   0.037678  50.044914
#
#       M_feces   M_blood
# 0   14.279184  1.380991
# 1   22.136904  1.697145
# 2   36.187820  2.256568
# 3   38.081211  2.332293
# 4   40.225040  2.419214
# ..        ...       ...
# 94  47.061081  2.716455
# 95  47.473064  2.735233
# 96  47.867321  2.753247
# 97  48.242527  2.770423
# 98  48.597855  2.786710
#
# [99 rows x 16 columns]

# %%
test_df.to_csv('predictions.csv', sep=',')
